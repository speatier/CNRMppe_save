# %% [markdown]
# # Importe modules

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas
from eofs.xarray import Eof
from eofs.multivariate.standard import MultivariateEof

# Plotting modules 
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import BoundaryNorm

# Scikit-learn
from sklearn import linear_model
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from scipy.optimize import minimize
from scipy.optimize import dual_annealing

# %% [markdown]
# # Functions definition

# %%
import sys
sys.path.append('/data/home/globc/peatier/CNRMppe')
import Fonctions
from Fonctions import get_wavg_budget_df
from Fonctions import wavg 
from Fonctions import plotlines_Xdf
from Fonctions import plotlines_1df
from Fonctions import Deltas_Lambda
from Fonctions import get_3D_budget_xarr
from Fonctions import get_3D_xarr
from Fonctions import get_3D_SW_xarr
from Fonctions import get_3D_LW_xarr

# %%
def Error_emulator(pc1, pc2, pc3, pc4, pc5, variable):
    if variable == 'tas' :
        U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_'+variable+'_'+product+'.npy')
    else :
        U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_'+variable+'.npy')
    
    E_tmp = (pc1-U_obs[0])**2 + (pc2-U_obs[1])**2 + (pc3-U_obs[2])**2 + (pc4-U_obs[3])**2 + (pc5-U_obs[4])**2
    E = sqrt(E_tmp/5)
    return E

# FONCTION MOYENNE NORMALISEE DES VARIABLES

def Norm_Average_df(Fdbck, variables, E_p1_df, name) :

    E_df = pd.DataFrame()
    E_df['Fdbck'] = Fdbck

    tmp = [0]*len(E_df) 

    for i in variables :
        E = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/'+name+'_'+i+'.npy')
        E_df['RMSE_'+i] = E

        E_df['RMSE_'+i+'_norm'] = E_df['RMSE_'+i]/E_p1_df['E_p1_'+i]

        tmp = tmp + E_df['RMSE_'+i+'_norm']
    
    E_df['RMSE_total'] = tmp/len(variables)
    return E_df

# %% [markdown]
# # Settings

# %%
variables = ['tas', 'pr', 'SW', 'LW']

variable_plot = 'total'
TITLE = 'Total Error (no unit)'
ylabel = 'RMSE'

product = 'ERAi'

# %% [markdown]
# # p1 RMSE and feedbacks

# %%
p1_feedbacks = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks_p1.npy')
E_p1_df = {}

for i in variables :
    E_p1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/E_p1_'+i+'.npy')
    E_p1_df['E_p1_'+i] = E_p1

E_p1_df
# Out:
# {'E_p1_tas': array(1.29920694),
#  'E_p1_pr': array(1.99300074),
#  'E_p1_SW': array(1.6664181),
#  'E_p1_LW': array(1.01012552)}

# %%
E_p1_tmp = E_p1_df['E_p1_tas']/E_p1_df['E_p1_tas'] + E_p1_df['E_p1_pr']/E_p1_df['E_p1_pr'] + E_p1_df['E_p1_SW']/E_p1_df['E_p1_SW']+E_p1_df['E_p1_LW']/E_p1_df['E_p1_LW']
E_p1 = E_p1_tmp/4
E_p1
# Out:
# 1.0

# %% [markdown]
# # Errors PPE

# %%
Fdbck_PPE = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy")

name = 'RMSE_PPE'
E_PPE_df = Norm_Average_df(Fdbck_PPE, variables, E_p1_df, name) 
E_PPE_df
# Out:
#         Fdbck  RMSE_tas  RMSE_tas_norm   RMSE_pr  RMSE_pr_norm   RMSE_SW  \
# 0   -0.825236  1.630197       1.254763  3.005870      1.508213  1.276688
# 1   -1.659636  1.782622       1.372085  2.451787      1.230199  1.787893
# 2   -1.215000  1.500472       1.154914  3.088631      1.549739  1.293988
# 3   -1.321641  1.876626       1.444440  2.539121      1.274019  1.961668
# 4   -0.750397  1.345349       1.035516  3.004392      1.507472  0.793997
# ..        ...       ...            ...       ...           ...       ...
# 97  -1.516367  1.442986       1.110666  2.503120      1.255955  2.020422
# 98  -1.584491  1.308427       1.007096  2.503540      1.256166  1.929570
# 99  -1.474525  1.147134       0.882950  2.457719      1.233175  1.731321
# 100 -1.445422  1.372532       1.056439  2.582264      1.295667  1.691727
# 101 -1.706865  1.573771       1.211332  1.804895      0.905617  2.231784
#
#      RMSE_SW_norm   RMSE_LW  RMSE_LW_norm  RMSE_total
# 0        0.766127  1.884203      1.865316    1.348605
# 1        1.072896  1.977491      1.957668    1.408212
# 2        0.776509  1.843335      1.824858    1.326505
# 3        1.177177  2.438853      2.414406    1.577510
# 4        0.476469  1.480472      1.465632    1.121272
# ..            ...       ...           ...         ...
# 97       1.212434  1.842843      1.824371    1.350857
# 98       1.157915  1.995217      1.975217    1.349099
# 99       1.038948  1.657734      1.641117    1.199047
# 100      1.015188  1.691218      1.674265    1.260389
# 101      1.339270  1.551300      1.535750    1.247992
#
# [102 rows x 10 columns]

# %% [markdown]
# # Emulator skill combined error

# %%
def MultiLinReg_RMSE_skill_eval(limit_train, x, EOF_nb, variable) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF"+str(EOF_nb)+"pc_"+variable+".npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X[0:limit_train], y[0:limit_train])
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta'+str(EOF_nb)+'_'+variable+'.npy', Coeffs)
    np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R'+str(EOF_nb)+'_'+variable+'.npy', R)
    
    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

def function_RMSE_emulator_std_skill_eval(limit_train, x, variable): 
    #mean = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_mean.npy')
    #std = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_std.npy')
    #x_std = (x-mean)/std
    pc1 = MultiLinReg_RMSE_skill_eval(limit_train,x, 1, variable)
    pc2 = MultiLinReg_RMSE_skill_eval(limit_train,x, 2, variable)
    pc3 = MultiLinReg_RMSE_skill_eval(limit_train,x, 3, variable)
    pc4 = MultiLinReg_RMSE_skill_eval(limit_train,x, 4, variable)
    pc5 = MultiLinReg_RMSE_skill_eval(limit_train,x, 5, variable)
    
    E = Error_emulator(pc1, pc2, pc3, pc4, pc5, variable)
    
    #E = sqrt(tmp_E)
    
    return E

def function_RMSE_total_skill_eval(limit_train, x, variables, E_p1_df):
    
    tmp_list = []
    for i in variables : 
            tmp = function_RMSE_emulator_std_skill_eval(limit_train, x,i)
            tmp_2 = tmp/E_p1_df['E_p1_'+i]
            tmp_list.append(tmp_2)
    
    E = sum(tmp_list)*1/len(variables)
    
    return E

# %%
# Set the X and Y : Y = f(X)
X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")

RMSE_skill_eval = []
for i in X :
    tmp = function_RMSE_total_skill_eval(80, i, variables, E_p1_df)
    RMSE_skill_eval.append(tmp)

Validation_RMSE_df = pd.DataFrame()
Validation_RMSE_df['RMSE_PPE_total'] = E_PPE_df['RMSE_total']
Validation_RMSE_df['RMSE_multilinreg_val_total'] = RMSE_skill_eval
Validation_RMSE_df
# Out:
#      RMSE_PPE_total  RMSE_multilinreg_val_total
# 0          1.348605                    1.195053
# 1          1.408212                    1.395381
# 2          1.326505                    1.314643
# 3          1.577510                    1.523845
# 4          1.121272                    1.225379
# ..              ...                         ...
# 97         1.350857                    1.413248
# 98         1.349099                    1.391680
# 99         1.199047                    1.189852
# 100        1.260389                    1.218031
# 101        1.247992                    1.404334
#
# [102 rows x 2 columns]

# %%
sum_diff=0
cpt=0
Test_set = Validation_RMSE_df[80:]
for i in Test_set['RMSE_multilinreg_val_total'] :
    j = Test_set['RMSE_PPE_total'].iloc[cpt]
    diff = (i-j)*(i-j)
    sum_diff = sum_diff+diff
    cpt+=1

n = len(Test_set)
OSE_Etot = sqrt(sum_diff/n)
OSE_Etot
# Out:
# 0.05888693968748801

# %%
plt.subplots(figsize=(8,20))

#########################
plt.subplot(311)
ax = plt.gca()

title="Total Error $E_{tot}$ (no unit)"
Validation_RMSE_df[0:80].plot(kind='scatter', x='RMSE_PPE_total', y='RMSE_multilinreg_val_total', color='blue',  
                     marker="o", ax = ax)
Validation_RMSE_df[80:].plot(kind='scatter', x='RMSE_PPE_total', y='RMSE_multilinreg_val_total', color='red',  
                     marker="o", ax = ax)

plt.text(1,0,r'$OSE = 0.09$',horizontalalignment='right',
     verticalalignment='bottom', transform = ax.transAxes, fontsize=18)

plt.xlabel('True $E_{tot}$', fontsize = 18)#, fontsize=18)
plt.ylabel('Predicted $E_{tot}$', fontsize = 18)#, fontsize=18)
plt.legend(['Training set', 'Test set'], fontsize = 16)
plt.title(title, fontsize = 22)#, fontsize=22)
plt.ylim(0.8,2)
plt.xlim(0.8,2)
ax.plot((0, 4), (0, 4), linewidth=1.0, color='gray', alpha=0.2)

# Enregistrer la figure ...........

plt.savefig("/data/home/globc/peatier/figures/total_emulator_skill.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Display the figure 
plt.show()

# %% [markdown]
# # Emulator skill combined error

# %%
# FONCTIONS FEEDBACKS

def em_fdb_std_skill_eval(limit_train, x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X[0:limit_train], y[0:limit_train])
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %%
# Set the X and Y : Y = f(X)
X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")

Fdbck_skill_eval = []
for i in X :
    tmp = em_fdb_std_skill_eval(80, i)
    Fdbck_skill_eval.append(tmp)

Validation_fdbck_df = pd.DataFrame()
Validation_fdbck_df['Fdbck_PPE'] = E_PPE_df['Fdbck']
Validation_fdbck_df['Fdbck_multilinreg_val'] = Fdbck_skill_eval
Validation_fdbck_df
# Out:
#      Fdbck_PPE  Fdbck_multilinreg_val
# 0    -0.825236              -1.180536
# 1    -1.659636              -1.594507
# 2    -1.215000              -1.068508
# 3    -1.321641              -1.363567
# 4    -0.750397              -1.140111
# ..         ...                    ...
# 97   -1.516367              -1.550227
# 98   -1.584491              -1.635200
# 99   -1.474525              -1.418686
# 100  -1.445422              -1.621942
# 101  -1.706865              -1.536423
#
# [102 rows x 2 columns]

# %%
sum_diff=0
cpt=0
Test_set_fdbck = Validation_fdbck_df[80:]
for i in Test_set_fdbck['Fdbck_multilinreg_val'] :
    j = Test_set_fdbck['Fdbck_PPE'].iloc[cpt]
    diff = (i-j)*(i-j)
    sum_diff = sum_diff+diff
    cpt+=1

n = len(Test_set_fdbck)
OSE_fdbck = sqrt(sum_diff/n)
OSE_fdbck
# Out:
# 0.18506045695913942

# %%
plt.subplots(figsize=(8,20))

#########################
plt.subplot(311)
ax = plt.gca()

title="Global Net Feedback $\lambda$ ($W.s^{-2}/K$)"
Validation_fdbck_df[0:80].plot(kind='scatter', x='Fdbck_PPE', y='Fdbck_multilinreg_val', color='blue',  
                     marker="o", ax = ax)
Validation_fdbck_df[80:].plot(kind='scatter', x='Fdbck_PPE', y='Fdbck_multilinreg_val', color='red',  
                     marker="o", ax = ax)

plt.text(1,0,r'$OSE = 0.19$',horizontalalignment='right',
     verticalalignment='bottom', transform = ax.transAxes, fontsize=18)

plt.xlabel('True $\lambda$', fontsize = 18)#, fontsize=18)
plt.ylabel('Predicted $\lambda$', fontsize = 18)#, fontsize=18)
plt.legend(['Training set', 'Test set'], fontsize = 16)
plt.title(title, fontsize = 22)#, fontsize=22)
plt.ylim(-2.0,-0.6)
plt.xlim(-2.0,-0.6)
ax.plot((-2.0,-0.6), (-2.0,-0.6), linewidth=1.0, color='gray', alpha=0.2)

# Enregistrer la figure ...........

plt.savefig("/data/home/globc/peatier/figures/Fdbck_emulator_skill.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Display the figure 
plt.show()

# %% [markdown]
# # Errors emulations

# %%
Fdbck_multilinreg_pred = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_FdbckN.npy")
name = 'RMSE_multilinreg_pred'

E_multilinreg_df = Norm_Average_df(Fdbck_multilinreg_pred, variables, E_p1_df, name) 
E_multilinreg_df
# Out:
#           Fdbck  RMSE_tas  RMSE_tas_norm   RMSE_pr  RMSE_pr_norm   RMSE_SW  \
# 0     -1.499698  0.735170       0.565861  2.735682      1.372645  1.448106
# 1     -1.339351  0.497397       0.382846  2.610231      1.309699  2.091175
# 2     -1.323732  1.447226       1.113930  2.376897      1.192622  1.711216
# 3     -1.541909  1.427061       1.098409  2.805251      1.407551  1.560492
# 4     -1.346961  1.927925       1.483924  2.261357      1.134649  1.646316
# ...         ...       ...            ...       ...           ...       ...
# 99995 -1.453679  1.543956       1.188383  2.103517      1.055452  2.579208
# 99996 -1.410350  1.355591       1.043399  3.081916      1.546370  2.082242
# 99997 -1.296397  1.184713       0.911874  2.417016      1.212752  1.274819
# 99998 -1.299809  0.965603       0.743225  2.599508      1.304319  1.365178
# 99999 -1.201982  1.558518       1.199592  2.615458      1.312322  1.783151
#
#        RMSE_SW_norm   RMSE_LW  RMSE_LW_norm  RMSE_total
# 0          0.868993  1.587103      1.571194    1.094673
# 1          1.254892  1.820720      1.802469    1.187477
# 2          1.026883  1.603968      1.587890    1.230331
# 3          0.936435  2.187358      2.165432    1.401957
# 4          0.987937  1.843415      1.824937    1.357862
# ...             ...       ...           ...         ...
# 99995      1.547755  1.644142      1.627661    1.354813
# 99996      1.249532  1.200948      1.188909    1.257052
# 99997      0.765006  1.641970      1.625511    1.128786
# 99998      0.819229  1.269682      1.256955    1.030932
# 99999      1.070050  1.394000      1.380026    1.240498
#
# [100000 rows x 10 columns]

# %% [markdown]
# # Search for best models : initial guess for optimization

# %%
E_multilinreg_df['Fdbck_round'] = E_multilinreg_df['Fdbck'].round(decimals=2)
E_multilinreg_df = E_multilinreg_df.set_index('Fdbck_round')
E_multilinreg_df['members'] = range(0,100000,1) 
E_multilinreg_df
# Out:
#                 Fdbck  RMSE_tas  RMSE_tas_norm   RMSE_pr  RMSE_pr_norm  \
# Fdbck_round
# -1.50       -1.499698  0.735170       0.565861  2.735682      1.372645
# -1.34       -1.339351  0.497397       0.382846  2.610231      1.309699
# -1.32       -1.323732  1.447226       1.113930  2.376897      1.192622
# -1.54       -1.541909  1.427061       1.098409  2.805251      1.407551
# -1.35       -1.346961  1.927925       1.483924  2.261357      1.134649
# ...               ...       ...            ...       ...           ...
# -1.45       -1.453679  1.543956       1.188383  2.103517      1.055452
# -1.41       -1.410350  1.355591       1.043399  3.081916      1.546370
# -1.30       -1.296397  1.184713       0.911874  2.417016      1.212752
# -1.30       -1.299809  0.965603       0.743225  2.599508      1.304319
# -1.20       -1.201982  1.558518       1.199592  2.615458      1.312322
#
#               RMSE_SW  RMSE_SW_norm   RMSE_LW  RMSE_LW_norm  RMSE_total  \
# Fdbck_round
# -1.50        1.448106      0.868993  1.587103      1.571194    1.094673
# -1.34        2.091175      1.254892  1.820720      1.802469    1.187477
# -1.32        1.711216      1.026883  1.603968      1.587890    1.230331
# -1.54        1.560492      0.936435  2.187358      2.165432    1.401957
# -1.35        1.646316      0.987937  1.843415      1.824937    1.357862
# ...               ...           ...       ...           ...         ...
# -1.45        2.579208      1.547755  1.644142      1.627661    1.354813
# -1.41        2.082242      1.249532  1.200948      1.188909    1.257052
# -1.30        1.274819      0.765006  1.641970      1.625511    1.128786
# -1.30        1.365178      0.819229  1.269682      1.256955    1.030932
# -1.20        1.783151      1.070050  1.394000      1.380026    1.240498
#
#              members
# Fdbck_round
# -1.50              0
# -1.34              1
# -1.32              2
# -1.54              3
# -1.35              4
# ...              ...
# -1.45          99995
# -1.41          99996
# -1.30          99997
# -1.30          99998
# -1.20          99999
#
# [100000 rows x 11 columns]

# %%
new_df=pd.DataFrame()
new_df['RMSE_total_best'] = E_multilinreg_df['RMSE_total'].groupby('Fdbck_round').min()
new_df = new_df.reset_index()
new_df
# Out:
#      Fdbck_round  RMSE_total_best
# 0          -1.99         1.474385
# 1          -1.95         1.609381
# 2          -1.93         1.537789
# 3          -1.91         1.819370
# 4          -1.90         1.444202
# ..           ...              ...
# 108        -0.86         1.156381
# 109        -0.85         1.082078
# 110        -0.82         1.377617
# 111        -0.80         1.258745
# 112        -0.78         1.299864
#
# [113 rows x 2 columns]

# %%
list_RMSE = new_df['RMSE_total_best']
n = len(list_RMSE)

tmp_fdbck = []
tmp_member = []
tmp_pc1 = []
cpt=0
ind=0
cpt_other=0
for i in E_multilinreg_df['RMSE_total'] :
    for j in list_RMSE :
        if i==j:
            #print(cpt)
            tmp_fdbck.append(E_multilinreg_df['Fdbck'].iloc[cpt])
            tmp_member.append(E_multilinreg_df['members'].iloc[cpt])
        else :
            cpt_other+=1
    cpt+=1

fdbck = [k for k in tmp_fdbck if k != 0]
members = [l for l in tmp_member if l != 0]
pc1 = [l for l in tmp_pc1 if l != 0]

df = pd.DataFrame()
df['fdbck'] = fdbck
df['members'] = members
df_sort = df.sort_values(by=['fdbck']).reset_index().drop('index', axis=1)
df_sort

new_df['Fdbck'] = df_sort['fdbck']
new_df['members'] = df_sort['members']
new_df
# Out:
#      Fdbck_round  RMSE_total_best     Fdbck  members
# 0          -1.99         1.474385 -1.985956    35649
# 1          -1.95         1.609381 -1.953341    47523
# 2          -1.93         1.537789 -1.927200    30599
# 3          -1.91         1.819370 -1.914973    74150
# 4          -1.90         1.444202 -1.902838     2836
# ..           ...              ...       ...      ...
# 108        -0.86         1.156381 -0.858778    47299
# 109        -0.85         1.082078 -0.852741    60906
# 110        -0.82         1.377617 -0.820649    57260
# 111        -0.80         1.258745 -0.803475    76973
# 112        -0.78         1.299864 -0.780000    77082
#
# [113 rows x 4 columns]

# %%
# CHECK OBJECTIVE FUNCTION

#x = x_best[4]
#y = function_RMSE_total(x, variables, E_p1_df)
#print(y)

# %% [markdown]
# # First Optimization

# %%
# FUNCTIONS EMULATORS

def MultiLinReg_pred(x, EOF_nb, variable) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF"+str(EOF_nb)+"pc_"+variable+".npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta'+str(EOF_nb)+'_'+variable+'.npy', Coeffs)
    np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R'+str(EOF_nb)+'_'+variable+'.npy', R)
    
    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# FONCTIONS ERROR

def Error_emulator(pc1, pc2, pc3, pc4, pc5, variable):
    if variable =='tas' :
        U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_'+variable+'_'+product+'.npy')
    else :
        U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_'+variable+'.npy')
    E_tmp = (pc1-U_obs[0])**2 + (pc2-U_obs[1])**2 + (pc3-U_obs[2])**2 + (pc4-U_obs[3])**2 + (pc5-U_obs[4])**2
    E = sqrt(E_tmp/5)
    return E


# FONCTIONS RMSE

def function_RMSE_emulator_std(x, variable): 
    #mean = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_mean.npy')
    #std = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_std.npy')
    #x_std = (x-mean)/std
    pc1 = MultiLinReg_pred(x, 1, variable)
    pc2 = MultiLinReg_pred(x, 2, variable)
    pc3 = MultiLinReg_pred(x, 3, variable)
    pc4 = MultiLinReg_pred(x, 4, variable)
    pc5 = MultiLinReg_pred(x, 5, variable)
    
    E = Error_emulator(pc1, pc2, pc3, pc4, pc5, variable)
    
    #E = sqrt(tmp_E)
    
    return E

def function_RMSE_emulator(x, variable): 
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    E = function_RMSE_emulator_std(x_std, variable)
    return E

def function_RMSE_total(x, variables, E_p1_df):
    
    tmp_list = []
    for i in variables : 
            tmp = function_RMSE_emulator(x,i)
            tmp_2 = tmp/E_p1_df['E_p1_'+i]
            tmp_list.append(tmp_2)
    
    E = sum(tmp_list)*1/len(variables)
    
    return E

# %%
# FONCTION JACOBIAN

def jacobian(x, variable) :
    
    if variable == 'tas' :
        U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_'+variable+'_'+product+'.npy')
    else :
        U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_'+variable+'.npy')
    
    Beta1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta1_'+variable+'.npy')
    Beta2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta2_'+variable+'.npy')
    Beta3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta3_'+variable+'.npy')
    Beta4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta4_'+variable+'.npy')
    Beta5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Beta5_'+variable+'.npy')
    
    R1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R1_'+variable+'.npy')
    R2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R2_'+variable+'.npy')
    R3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R3_'+variable+'.npy')
    R4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R4_'+variable+'.npy')
    R5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/R5_'+variable+'.npy')
    
    C1 = R1 - U_obs[0]
    C2 = R2 - U_obs[1]
    C3 = R3 - U_obs[2]
    C4 = R4 - U_obs[3]
    C5 = R5 - U_obs[4]
    
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    A = x_std*(Beta1**2 + Beta2**2 + Beta3**2 + Beta4**2 + Beta5**2) + (Beta1*C1 + Beta2*C2 + Beta3*C3 + 
                                                                    Beta4*C4 + Beta5*C5)
    
    tmp = x_std**2*(Beta1**2 + Beta2**2 + Beta3**2 + Beta4**2 + Beta5**2) + 2*x_std*(Beta1*C1 + Beta2*C2 + Beta3*C3 + Beta4*C4 + Beta5*C5) +(C1**2+C2**2+C3**2+C4**2+C5**2)
    B = sqrt(tmp)
    
    D = 1/sqrt(5)
    
    jac = (A/B)*D
    
    return jac

# FONCTION JACOBIAN OF TOTAL ERROR

def jacobian_total(x, variables, E_p1_df) :
    
    tmp = 0
    for i in variables : 
        tmp0 = jacobian(x, i)/E_p1_df['E_p1_'+i]
        tmp = tmp + tmp0
    
    jac = tmp/len(variables)
    
    return jac

# %%
# FONCTIONS FEEDBACKS

def em_fdb_std(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

def em_fdb(x) :
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    y_pred = em_fdb_std(x_std)
    return y_pred

# %%
# FONCTIONS CONTRAINTES

def constraint1(x, fdb_low, fdb_hi):
    tmp = (em_fdb(x))
    low = (fdb_low)
    hi = (fdb_hi)
    test = (tmp-fdb_low)
    return test

def constraint2(x, fdb_low, fdb_hi):
    tmp = (em_fdb(x))
    low = (fdb_low)
    hi = (fdb_hi)
    test = (fdb_hi-tmp)
    return test


# FONCTIONS OPTIMISATION

def Optimization(x_best, ind, xlim, variables, E_p1_df) :
    
    sol_list=[]
    sol_fdbck=[]
    sol_x=[]
    n = len(x_best)
    cpt=0
    
    for i in range(0, n, 1) :
        x0 = x_best[i]
        #if em_fdb(x0)<-1.8 : 
        #    ind = 0.0001
        #elif em_fdb(x0)>-1.0:
        #    ind = 0.0001
        #else:
        #    ind = 0.0001
   
        fdb_low = em_fdb(x0)-ind
        #print('low = '+str(fdb_low))
        fdb_hi = em_fdb(x0)+ind
        #print('hi = '+str(fdb_hi))

        fdb_x0 = em_fdb(x0)
        #print('fdb_x0 = '+str(fdb_x0))
        fun_x0 = function_RMSE_total(x0, variables, E_p1_df)
        #print('fun_x0 = '+str(fun_x0))

        cons1 = {'type': 'ineq', 'fun' : constraint1, 'args' : [fdb_low, fdb_hi]}
        cons2 = {'type': 'ineq', 'fun' : constraint2, 'args' : [fdb_low, fdb_hi]}
    
        sol = minimize(function_RMSE_total,  x0, args=(variables, E_p1_df), method='SLSQP', bounds=xlim, constraints=(cons1, cons2), 
                   jac = jacobian_total, options={'disp': True}, tol = 0.001)    
                        # , 'maxiter' : 250   jac = jacobian,
    

        tmp_fun = function_RMSE_total(sol.x, variables, E_p1_df)
        tmp_fdbck = em_fdb(sol.x)
        #print('fdb_x = '+str(tmp_fdbck))
    
        sol_list.append(tmp_fun)
        sol_fdbck.append(tmp_fdbck)
        sol_x.append(sol.x)
    
        #if tmp_fun<=fun_x0 and fdb_low<=tmp_fdbck<=fdb_hi:  
        #    sol_list.append(tmp_fun)
        #    sol_fdbck.append(tmp_fdbck)
        #else :
        #    print('\n ERROR \n')
    
    sol_df = pd.DataFrame()
    sol_df['sol_fun'] = sol_list[:]
    sol_df['Fdbck'] = sol_fdbck[:]
    j=1
    for i in range(0, 30, 1) :
        #print(j)
        sol_df['x'+str(j)+'_smth_0'] = (transpose(sol_x)[i])
        j+=1
    
    return sol_df

# %%
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param.npy")

x_best = []
for i in new_df['members']:
    #print(i)
    x_best.append(LHS[i])

x_best=np.array(x_best)
#x_best

# %%
param = pd.read_csv("/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/csv/param.csv",sep=' ', header=None)
param_int = param.set_index(0).transpose()
param_names = param[0]

N=len(param_names)
xlimits=[[1,1]]*N
i=0
while i<N:
    name = param_names[i]
    xmin = param_int[name].iloc[0]
    xmax = param_int[name].iloc[1]
    if xmin<xmax:
        limit = [xmin, xmax]
    else:
        limit = [xmax, xmin]
    xlimits[i] = limit
    i+=1
    
xlim = np.array(xlimits)
xlim
# Out:
# array([[ 6.0e-02,  2.8e-01],
#        [ 5.0e-01,  3.0e+00],
#        [ 5.0e-01,  3.0e+00],
#        [ 0.0e+00,  3.0e+01],
#        [-5.0e-01, -1.0e-02],
#        [ 0.0e+00,  1.0e+01],
#        [ 0.0e+00,  1.0e+01],
#        [ 5.0e-04,  1.0e-02],
#        [ 5.0e-05,  1.0e-03],
#        [ 5.0e-04,  1.0e-02],
#        [ 1.0e-08,  1.0e-06],
#        [ 5.0e-06,  1.0e-04],
#        [ 1.0e-03,  2.0e-01],
#        [ 1.0e-03,  2.0e-01],
#        [ 1.0e-01,  6.0e+00],
#        [ 1.0e-01,  6.0e+00],
#        [ 3.0e-05,  7.0e-05],
#        [ 8.0e-05,  6.0e-04],
#        [ 2.0e-06,  1.0e-05],
#        [ 3.0e-05,  1.2e-04],
#        [-5.0e+00, -1.0e+00],
#        [-5.0e+01, -2.5e+01],
#        [ 1.0e-02,  1.0e-01],
#        [ 0.0e+00,  2.0e+01],
#        [ 1.0e-05,  1.0e-04],
#        [ 5.0e-01,  1.0e+00],
#        [ 5.0e-01,  1.0e+00],
#        [ 5.0e-01,  1.0e+00],
#        [ 5.0e-01,  1.0e+00],
#        [ 2.0e-01,  1.0e+01]])

# %%
sol_df = Optimization(x_best, 0.0001, xlim, variables, E_p1_df)
sol_df
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4743836914970994
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.300644587674867
#             Iterations: 6
#             Function evaluations: 19
#             Gradient evaluations: 6
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.313873700955136
#             Iterations: 5
#             Function evaluations: 17
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4786540119028193
#             Iterations: 7
#             Function evaluations: 22
#             Gradient evaluations: 7
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3574192775393603
#             Iterations: 3
#             Function evaluations: 15
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3215389002371951
#             Iterations: 3
#             Function evaluations: 14
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2928421704356674
#             Iterations: 5
#             Function evaluations: 16
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.287539328517747
#             Iterations: 4
#             Function evaluations: 15
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2706242623898152
#             Iterations: 8
#             Function evaluations: 25
#             Gradient evaluations: 8
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3490043674766843
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2611953780859337
#             Iterations: 5
#             Function evaluations: 22
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.391353417806119
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1985542161952023
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3005148129519815
#             Iterations: 5
#             Function evaluations: 20
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1910745931212658
#             Iterations: 1
#             Function evaluations: 3
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2037464010957444
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2140572867690262
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2954112120740322
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1197092180574477
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1961531722896674
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1928971586891772
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1544567661511742
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.15955659305394
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0536634556078346
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0847944127770706
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0998433871293842
#             Iterations: 4
#             Function evaluations: 19
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0982834946201365
#             Iterations: 4
#             Function evaluations: 19
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1227081756548207
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9970226606473189
#             Iterations: 3
#             Function evaluations: 9
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0718877402513187
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0677245723125501
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0644079687369974
#             Iterations: 1
#             Function evaluations: 3
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0433298315182151
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0622814163151233
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0646266987211297
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0520425248661112
#             Iterations: 1
#             Function evaluations: 3
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0387083536602097
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0308514998519676
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0187843953223858
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0318286682530662
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0124836392492294
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0069117397984741
#             Iterations: 2
#             Function evaluations: 8
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9926258294484767
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.002322775307741
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.024455159555482
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9948817538573468
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.996173729915826
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9711948030073696
#             Iterations: 4
#             Function evaluations: 13
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9783255491839797
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9895136753297837
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9939422682873423
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9554659754143401
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9651595451880972
#             Iterations: 3
#             Function evaluations: 9
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9453317929264469
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9872409091984314
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9591586991627314
#             Iterations: 2
#             Function evaluations: 6
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9379319449469553
#             Iterations: 2
#             Function evaluations: 7
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9173567334100459
#             Iterations: 4
#             Function evaluations: 12
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9291292207541325
#             Iterations: 4
#             Function evaluations: 16
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9312187025554267
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.957134925122719
#             Iterations: 2
#             Function evaluations: 8
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9625504726605865
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.965494024218635
#             Iterations: 2
#             Function evaluations: 9
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9258014241637001
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9286250621817129
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9480247145421656
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9209829328048684
#             Iterations: 1
#             Function evaluations: 5
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9443645146821638
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8960625633034482
#             Iterations: 4
#             Function evaluations: 20
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9090984262118774
#             Iterations: 5
#             Function evaluations: 21
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9417768052560358
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9335134674027168
#             Iterations: 2
#             Function evaluations: 6
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9127423696880999
#             Iterations: 3
#             Function evaluations: 15
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9432347583935861
#             Iterations: 4
#             Function evaluations: 15
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8860979218885152
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8861534341501416
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8885059902182789
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9224585093667595
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8999590987187356
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9419094905866227
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.897463299420358
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9362535829067772
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8653679965691798
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8953279795661102
#             Iterations: 1
#             Function evaluations: 4
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8750292421753558
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8887617375034538
#             Iterations: 4
#             Function evaluations: 19
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8923547554175302
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8925501871816255
#             Iterations: 5
#             Function evaluations: 14
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9129526058572591
#             Iterations: 4
#             Function evaluations: 19
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.942048935369402
#             Iterations: 3
#             Function evaluations: 6
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.92741074802475
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8786016245183705
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8849276307883287
#             Iterations: 5
#             Function evaluations: 21
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9046508798796677
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9036989465347968
#             Iterations: 4
#             Function evaluations: 11
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9064737505994904
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8763040414583285
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.926739554058405
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8859840368504239
#             Iterations: 4
#             Function evaluations: 12
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9091276065940308
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.937728592807894
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.874151524943191
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9262365440737383
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9461901974867514
#             Iterations: 3
#             Function evaluations: 15
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9928868000284623
#             Iterations: 2
#             Function evaluations: 6
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0225760973906899
#             Iterations: 3
#             Function evaluations: 16
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.975240160414761
#             Iterations: 4
#             Function evaluations: 18
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9937534787552693
#             Iterations: 4
#             Function evaluations: 17
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0290839644188614
#             Iterations: 3
#             Function evaluations: 15
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.997876979925111
#             Iterations: 3
#             Function evaluations: 14
#             Gradient evaluations: 3
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2727731910826832
#             Iterations: 5
#             Function evaluations: 20
#             Gradient evaluations: 5
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1552805255355343
#             Iterations: 4
#             Function evaluations: 17
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9852048972017806
#             Iterations: 3
#             Function evaluations: 15
#             Gradient evaluations: 3
#       sol_fun     Fdbck  x1_smth_0  x2_smth_0  x3_smth_0  x4_smth_0  \
# 0    1.474384 -1.985956   0.101203   0.935234   2.308204  29.837948
# 1    1.300645 -1.953241   0.096086   0.524551   0.500000  18.849933
# 2    1.313874 -1.927100   0.126479   0.578987   0.500000  27.054741
# 3    1.478654 -1.914873   0.106738   0.500000   0.500000  18.448203
# 4    1.357419 -1.902738   0.060000   0.809660   0.992584  28.928788
# ..        ...       ...        ...        ...        ...        ...
# 108  1.029084 -0.858878   0.169761   2.382401   0.693381  19.351153
# 109  0.997877 -0.852841   0.060000   2.434131   0.804662  14.682510
# 110  1.272773 -0.820749   0.132399   2.412631   0.533043  17.697148
# 111  1.155281 -0.803575   0.153267   2.227170   1.451914  21.233786
# 112  0.985205 -0.779922   0.179813   2.630726   1.068963  29.407189
#
#      x5_smth_0  x6_smth_0  x7_smth_0  x8_smth_0  ...  x21_smth_0  x22_smth_0  \
# 0    -0.079668   8.934325   3.064546   0.005119  ...   -2.509367  -25.309509
# 1    -0.010000   3.970242   5.469928   0.000500  ...   -2.384683  -30.786112
# 2    -0.010000   6.062856   1.627925   0.000500  ...   -1.684148  -49.483486
# 3    -0.230510   4.169407   0.370155   0.000500  ...   -1.704989  -40.510840
# 4    -0.015604   6.491781   7.042460   0.000500  ...   -4.426427  -27.370043
# ..         ...        ...        ...        ...  ...         ...         ...
# 108  -0.345436   3.100564   5.013212   0.010000  ...   -2.609532  -27.201171
# 109  -0.010000   1.508788   7.909809   0.008617  ...   -2.600947  -49.573998
# 110  -0.349895   0.245181   4.371968   0.009646  ...   -1.149719  -25.775555
# 111  -0.104456   0.168784   4.013001   0.010000  ...   -2.824971  -44.684041
# 112  -0.392095   1.733019   6.253737   0.009446  ...   -2.508218  -47.395272
#
#      x23_smth_0  x24_smth_0  x25_smth_0  x26_smth_0  x27_smth_0  x28_smth_0  \
# 0      0.074946   14.089298    0.000044    0.911289    0.653067    0.507019
# 1      0.070305   16.976295    0.000010    1.000000    0.513916    0.584039
# 2      0.086449    9.137594    0.000010    1.000000    0.681991    0.840633
# 3      0.100000    2.334933    0.000010    0.876396    0.500000    0.658043
# 4      0.034045   16.146834    0.000010    1.000000    0.566421    0.887780
# ..          ...         ...         ...         ...         ...         ...
# 108    0.010000    1.818195    0.000100    0.713829    0.507342    0.866768
# 109    0.010000    0.166419    0.000100    0.841504    0.856469    0.854484
# 110    0.010000    1.366232    0.000100    0.737663    0.500501    0.990895
# 111    0.010000    5.189591    0.000100    0.919344    0.810967    0.630408
# 112    0.010000    9.414501    0.000100    0.559422    0.533668    0.977057
#
#      x29_smth_0  x30_smth_0
# 0      0.534699    6.132892
# 1      0.541625    2.904273
# 2      0.500000    6.921599
# 3      0.500000    1.061808
# 4      0.507647    0.235176
# ..          ...         ...
# 108    0.865197    4.286099
# 109    0.673200    6.142261
# 110    0.736708    1.603475
# 111    0.788760    1.294815
# 112    0.854370    7.780715
#
# [113 rows x 32 columns]

# %% [markdown]
# # Plotting

# %%
ax = plt.gca()

#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

#new_df.plot(kind='scatter', x='Fdbck', y='RMSE_total_best', color = 'darkgreen', 
#         marker = '^', linewidth=6,  ax = ax)

#sol_df.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkgreen', 
#         linewidth=3, ax = ax)

#E_multilinreg_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', 
#                           color='gray', alpha=0.2, figsize=(15, 12), marker='o', ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)



plt.hlines(E_p1,xmin = -4.0,xmax = 2.0,label='default simulation', colors='black', 
           linestyles='dashed')
plt.vlines(p1_feedbacks,ymin = -10,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed')


#'MRI model', 'CAN model', 'MIROC model', 'HadGEM3 model', 'IPSL model','BCC model', 
legend = ['CNRM PPE', 'CNRM default model']

plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel(ylabel, fontsize=22)
plt.legend(legend, fontsize=15)
plt.title(TITLE, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0.5,2.5)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_"+variable_plot+"_PPE_only.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
ax = plt.gca()

#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

#new_df.plot(kind='scatter', x='Fdbck', y='RMSE_total_best', color = 'darkgreen', 
#         marker = '^', linewidth=6,  ax = ax)

#sol_df.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkgreen', 
#         linewidth=3, ax = ax)

E_multilinreg_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', 
                           color='gray', alpha=0.2, figsize=(15, 12), marker='o', ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)



plt.hlines(E_p1,xmin = -4.0,xmax = 2.0,label='default simulation', colors='black', 
           linestyles='dashed')
plt.vlines(p1_feedbacks,ymin = -10,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed')


#'MRI model', 'CAN model', 'MIROC model', 'HadGEM3 model', 'IPSL model','BCC model', 
legend = ['Emulations MultiLinReg', 'CNRM PPE', 'CNRM default model']

plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel(ylabel, fontsize=22)
plt.legend(legend, fontsize=15)
plt.title(TITLE, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0.5,2.5)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_"+variable_plot+"_PPE.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
ax = plt.gca()

#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

new_df.plot(kind='scatter', x='Fdbck', y='RMSE_total_best', color = 'darkgreen', 
         marker = '^', linewidth=6,  ax = ax)

sol_df.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkgreen', 
         linewidth=3, ax = ax)

E_multilinreg_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', 
                           color='gray', alpha=0.2, figsize=(15, 12), marker='o', ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)



plt.hlines(E_p1,xmin = -4.0,xmax = 2.0,label='default simulation', colors='black', 
           linestyles='dashed')
plt.vlines(p1_feedbacks,ymin = -10,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed')


#'MRI model', 'CAN model', 'MIROC model', 'HadGEM3 model', 'IPSL model','BCC model', 
legend = ['Optimization 1', 'Initialization optimization 1', 'Emulations MultiLinReg', 'CNRM PPE', 'CNRM default model']

plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel(ylabel, fontsize=22)
plt.legend(legend, fontsize=15)
plt.title(TITLE, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0.5,2.5)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_"+variable_plot+"_PPE_optim1.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %% [markdown]
# # sol.x smoothing

# %%
def smooth(n, df1, df2):

    for i in range(1,31,1) :
        tmp_x =[df1['x'+str(i)+'_smth_'+str(n-1)][0]]

        for j in range(1,len(df1)-1, 1) : 
            tmp = 0.25*df1['x'+str(i)+'_smth_'+str(n-1)][j-1]+0.5* \
            df1['x'+str(i)+'_smth_'+str(n-1)][j]+0.25*df1['x'+str(i)+'_smth_'+str(n-1)][j+1]
            
            tmp_x.append(tmp)
    
        tmp_x.append(df1['x'+str(i)+'_smth_'+str(n-1)][(len(df1)-1)])
        
        df2['x'+str(i)+'_smth_'+str(n)] = tmp_x

    return df2

# %%
new_sol_df = pd.DataFrame()
new_sol_df['Fdbck'] = sol_df['Fdbck']

new_sol_df = smooth(1, sol_df, new_sol_df)

n = 151
for i in range(2,n,1) :
    new_sol_df = smooth(i, new_sol_df, new_sol_df)
    
new_sol_df
# Out:
#         Fdbck  x1_smth_1  x2_smth_1  x3_smth_1  x4_smth_1  x5_smth_1  \
# 0   -1.985956   0.101203   0.935234   2.308204  29.837948  -0.079668
# 1   -1.953241   0.104964   0.640831   0.952051  23.648139  -0.027417
# 2   -1.927100   0.113946   0.545631   0.500000  22.851905  -0.065128
# 3   -1.914873   0.099989   0.597162   0.623146  23.219984  -0.121656
# 4   -1.902738   0.079582   0.667261   0.991576  23.140709  -0.068151
# ..        ...        ...        ...        ...        ...        ...
# 108 -0.858878   0.138226   2.410994   0.739562  14.324410  -0.239298
# 109 -0.852841   0.105540   2.415824   0.708937  16.603330  -0.178833
# 110 -0.820749   0.119516   2.371641   0.830665  17.827648  -0.203562
# 111 -0.803575   0.154686   2.374424   1.126458  22.392977  -0.237726
# 112 -0.779922   0.179813   2.630726   1.068963  29.407189  -0.392095
#
#      x6_smth_1  x7_smth_1  x8_smth_1  x9_smth_1  ...  x21_smth_150  \
# 0     8.934325   3.064546   0.005119   0.000707  ...     -2.509367
# 1     5.734416   3.908082   0.001655   0.000927  ...     -2.589329
# 2     5.066340   2.273983   0.000500   0.001000  ...     -2.667938
# 3     5.223363   2.352674   0.000500   0.001000  ...     -2.743876
# 4     5.281717   3.767051   0.000500   0.001000  ...     -2.815900
# ..         ...        ...        ...        ...  ...           ...
# 108   2.555762   5.575254   0.009478   0.000287  ...     -2.690555
# 109   1.590830   6.301200   0.009220   0.000555  ...     -2.647495
# 110   0.541984   5.166687   0.009477   0.000348  ...     -2.602295
# 111   0.578942   4.662926   0.009773   0.000080  ...     -2.555629
# 112   1.733019   6.253737   0.009446   0.000050  ...     -2.508218
#
#      x22_smth_150  x23_smth_150  x24_smth_150  x25_smth_150  x26_smth_150  \
# 0      -25.309509      0.074946     14.089298      0.000044      0.911289
# 1      -26.118467      0.074135     14.004136      0.000043      0.910068
# 2      -26.914708      0.073335     13.920602      0.000041      0.908819
# 3      -27.686008      0.072558     13.840292      0.000040      0.907518
# 4      -28.421105      0.071813     13.764736      0.000039      0.906146
# ..            ...           ...           ...           ...           ...
# 108    -45.410510      0.012027      8.078521      0.000092      0.621625
# 109    -45.879249      0.011505      8.403836      0.000094      0.606494
# 110    -46.371059      0.010996      8.736582      0.000096      0.591008
# 111    -46.879012      0.010496      9.074297      0.000098      0.575278
# 112    -47.395272      0.010000      9.414501      0.000100      0.559422
#
#      x27_smth_150  x28_smth_150  x29_smth_150  x30_smth_150
# 0        0.653067      0.507019      0.534699      6.132892
# 1        0.658718      0.522141      0.534221      5.877048
# 2        0.664401      0.537093      0.533799      5.626077
# 3        0.670144      0.551714      0.533483      5.384628
# 4        0.675970      0.565866      0.533320      5.156921
# ..            ...           ...           ...           ...
# 108      0.574741      0.914024      0.810088      6.467751
# 109      0.564775      0.928980      0.820722      6.780230
# 110      0.554552      0.944615      0.831723      7.106064
# 111      0.544154      0.960717      0.842981      7.441059
# 112      0.533668      0.977057      0.854370      7.780715
#
# [113 rows x 4501 columns]

# %%
# SETTINGS ------------------

n = 150

colors = ['black', 'green', 'orange', 'red', 'blue', 'yellow', 'coral', 'pink', 'purple', 'white','red']*100

# Plot of lines from different dataframes
plt.subplots(figsize=(15,10)) 

plt.subplot(331)

ax1 = plt.gca()
title = 'parameter 1'

sol_df.plot(kind='line', x='Fdbck', y='x1_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax1)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x1_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax1)

plt.xlim(-2.2,-0.5)
plt.legend(['x1', 'x1_smth_1'])
plt.subplot(332)

ax2 = plt.gca()
title = 'parameter 2'

sol_df.plot(kind='line', x='Fdbck', y='x2_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax2)
for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x2_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax2)

plt.xlim(-2.2,-0.5)
plt.legend(['x2', 'x2_smth_1'])
plt.subplot(333)

ax3 = plt.gca()
title = 'parameter 3'

sol_df.plot(kind='line', x='Fdbck', y='x3_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax3)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x3_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax3)

plt.xlim(-2.2,-0.5)
plt.legend(['x3', 'x3_smth_1'])
plt.subplot(334)

ax4 = plt.gca()
title = 'parameter 4'

sol_df.plot(kind='line', x='Fdbck', y='x4_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax4)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x4_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax4)

plt.xlim(-2.2,-0.5)
plt.legend(['x4', 'x4_smth_1'])
plt.subplot(335)

ax5 = plt.gca()
title = 'parameter 5'

sol_df.plot(kind='line', x='Fdbck', y='x5_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax5)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x5_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax5)

plt.xlim(-2.2,-0.5)
plt.legend(['x5', 'x5_smth_1'])
plt.subplot(336)

ax6 = plt.gca()
title = 'parameter 6'

sol_df.plot(kind='line', x='Fdbck', y='x6_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax6)

for i in range(1,n,1) : 
    new_sol_df.plot(kind='line', x='Fdbck', y='x6_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax6)
    
plt.xlim(-2.2,-0.5)
plt.legend(['x6', 'x6_smth_1'])
plt.subplot(337)

ax7 = plt.gca()
title = 'parameter 7'

sol_df.plot(kind='line', x='Fdbck', y='x7_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax7)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x7_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax7)

plt.xlim(-2.2,-0.5)
plt.legend(['x7', 'x7_smth_1'])
plt.subplot(338)

ax8 = plt.gca()
title = 'parameter 8'

sol_df.plot(kind='line', x='Fdbck', y='x8_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax8)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x8_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax8)

plt.ylim(-0.005,0.0125)
plt.xlim(-2.2,-0.5)
plt.legend(['x8', 'x8_smth_1'])
plt.subplot(339)

ax9 = plt.gca()
title = 'parameter 9'

sol_df.plot(kind='line', x='Fdbck', y='x9_smth_0', color = 'black', 
         marker = '^', linewidth=1.5, ax=ax9)

for i in range(1,n,1) :
    new_sol_df.plot(kind='line', x='Fdbck', y='x9_smth_'+str(i), color = colors[i], linewidth=2.0, ax=ax9)

plt.ylim(-0.0001,0.0015)
plt.xlim(-2.2,-0.5)
plt.legend(['x9', 'x9_smth_1'])

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/longPPE_N_tas_future4K.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %% [markdown]
# # Second Optimization : initialized with smoothed sol.x

# %%
x_best_2 = pd.DataFrame()
for k in range(1,31,1) : 
    x_best_2['x'+str(k)+'_best'] = new_sol_df['x'+str(k)+'_smth_150']

x_best_2 = x_best_2.to_numpy()
x_best_2
# Out:
# array([[0.10120335, 0.93523392, 2.30820399, ..., 0.50701942, 0.53469907,
#         6.13289156],
#        [0.10168768, 0.91691192, 2.20778812, ..., 0.52214139, 0.53422137,
#         5.87704833],
#        [0.10218671, 0.89906241, 2.1090539 , ..., 0.53709299, 0.5337985 ,
#         5.62607736],
#        ...,
#        [0.17407485, 2.56835674, 1.03570768, ..., 0.94461517, 0.83172328,
#         7.10606355],
#        [0.17693432, 2.5994089 , 1.05216165, ..., 0.96071705, 0.84298077,
#         7.44105909],
#        [0.17981341, 2.63072564, 1.06896345, ..., 0.97705707, 0.85437027,
#         7.7807149 ]])

# %%
init_df = pd.DataFrame()
init_df['Fdbck'] = sol_df['Fdbck']

tmp_fun = []
for i in x_best_2 :
    tmp = function_RMSE_total(i, variables, E_p1_df)
    tmp_fun.append(tmp)
init_df['RMSE'] = tmp_fun
init_df
# Out:
#         Fdbck      RMSE
# 0   -1.985956  1.474384
# 1   -1.953241  1.437876
# 2   -1.927100  1.403884
# 3   -1.914873  1.372707
# 4   -1.902738  1.344473
# ..        ...       ...
# 108 -0.858878  0.932118
# 109 -0.852841  0.943329
# 110 -0.820749  0.955920
# 111 -0.803575  0.969897
# 112 -0.779922  0.985205
#
# [113 rows x 2 columns]

# %%
sol_df_2 = Optimization(x_best_2, 0.0001, xlim, variables, E_p1_df)
sol_df_2
# Out:
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4743820426374579
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.437876177185898
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.4038845458310458
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3727070712842457
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3444730756612429
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3191511764159443
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2965730108996314
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.27646825368254
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2585044386964976
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2423254116545501
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2275837893538113
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2139648573528414
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2012012743382852
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.189079409977133
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1774390162331487
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1661682724866727
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1551961784009803
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.144483941645285
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1340165586149773
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1237953278933508
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.113831644989846
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.1041421409363013
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0947450516266746
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0856576221994283
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0768943343387807
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.068465766926212
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0603779404785363
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0526320389402324
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.045224440404467
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0381470166201492
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.031387676680155
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0249311309439308
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.018759836715506
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0128550607816738
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.0071979636518802
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.001770587947695
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.996556630577628
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9915419027180064
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9867144289120707
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.982064202353791
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9775826719648535
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9732620813856432
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9690947939456717
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9650727222404405
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9611869427847621
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9574275281150408
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9537835842724711
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9502434511157103
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.94679501091263
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9434260555966667
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9401246787894872
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9368796769861769
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9336809576014404
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9305199550897761
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9273900491664123
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9242869641579308
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.921209111252704
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9181578223167977
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9151374203729824
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9121550807039761
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.909220457601503
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9063450818705429
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9035415680586045
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.900822701822511
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8982005009104185
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8956853532105797
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8932853295511507
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8910057474287099
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8888490275069083
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8868148431402565
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8849005217288486
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8831016231577224
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.88141260133662
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8798274534716286
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8783402779319661
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8769456913842353
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8756390923194297
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8744167928913253
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8732760663638444
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8722151680378107
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8712333816509144
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8703311234875137
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8695101091802449
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8687735616246801
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8681264206363305
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8675755110130535
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8671296362248258
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8667995859892623
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8665980701821909
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8665396109637716
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.86664043422229
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8669183996897023
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8673930006623323
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8680854566400815
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8690189224497299
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8702188483060909
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8717135427326455
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8735350035579634
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8757200768504292
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8783119664103065
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8813620404729712
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8849317707784434
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8890945060915365
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8939366499125851
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.89955770643468
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9060686065273222
#             Iterations: 1
#             Function evaluations: 12
#             Gradient evaluations: 1
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.911468937333897
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9099931221498219
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9131603379661573
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9151920653604915
#             Iterations: 2
#             Function evaluations: 14
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.917521337808999
#             Iterations: 2
#             Function evaluations: 8
#             Gradient evaluations: 2
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9517748062637641
#             Iterations: 4
#             Function evaluations: 15
#             Gradient evaluations: 4
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.9631147692524178
#             Iterations: 4
#             Function evaluations: 14
#             Gradient evaluations: 4
#       sol_fun     Fdbck  x1_smth_0  x2_smth_0  x3_smth_0  x4_smth_0  \
# 0    1.474382 -1.985956   0.101203   0.935225   2.308153  29.837944
# 1    1.437876 -1.971820   0.101688   0.916911   2.207785  28.892218
# 2    1.403885 -1.957738   0.102187   0.899062   2.109053  27.958392
# 3    1.372707 -1.943759   0.102715   0.882138   2.013607  27.047935
# 4    1.344473 -1.929932   0.103287   0.866552   1.922906  26.171461
# ..        ...       ...        ...        ...        ...        ...
# 108  0.913160 -0.833875   0.161023   2.491375   0.992896  23.711828
# 109  0.915192 -0.820522   0.160600   2.514806   1.003157  25.063750
# 110  0.917521 -0.807039   0.157484   2.531141   1.008663  26.475358
# 111  0.951775 -0.793457   0.136313   2.441663   0.941190  27.920045
# 112  0.963115 -0.779854   0.140123   2.467341   0.954784  29.393078
#
#      x5_smth_0  x6_smth_0  x7_smth_0  x8_smth_0  ...  x21_smth_0  x22_smth_0  \
# 0    -0.079652   8.934249   3.064541   0.005118  ...   -2.509364  -25.309510
# 1    -0.079348   8.455853   3.255414   0.004907  ...   -2.589329  -26.118467
# 2    -0.079063   7.982382   3.442933   0.004701  ...   -2.667938  -26.914708
# 3    -0.078839   7.518718   3.623885   0.004505  ...   -2.743876  -27.686008
# 4    -0.078704   7.069353   3.795316   0.004326  ...   -2.815900  -28.421105
# ..         ...        ...        ...        ...  ...         ...         ...
# 108  -0.303318   1.842845   5.672932   0.008748  ...   -2.689462  -45.407737
# 109  -0.320829   1.810408   5.808825   0.008785  ...   -2.646036  -45.875375
# 110  -0.335866   1.769818   5.950797   0.008748  ...   -2.600005  -46.364691
# 111  -0.313099   1.647182   6.085278   0.008448  ...   -2.545897  -46.850922
# 112  -0.333318   1.612349   6.235296   0.008351  ...   -2.498424  -47.365680
#
#      x23_smth_0  x24_smth_0  x25_smth_0  x26_smth_0  x27_smth_0  x28_smth_0  \
# 0      0.074928   14.089274    0.000044    0.911295    0.653061    0.507021
# 1      0.074134   14.004135    0.000043    0.910069    0.658717    0.522142
# 2      0.073335   13.920602    0.000041    0.908819    0.664401    0.537093
# 3      0.072558   13.840292    0.000040    0.907518    0.670144    0.551714
# 4      0.071813   13.764736    0.000039    0.906146    0.675970    0.565866
# ..          ...         ...         ...         ...         ...         ...
# 108    0.011530    8.074307    0.000094    0.626449    0.572041    0.913807
# 109    0.011003    8.397711    0.000096    0.613212    0.561124    0.928632
# 110    0.010525    8.726139    0.000098    0.601909    0.548989    0.944023
# 111    0.010000    9.026512    0.000100    0.618478    0.528232    0.960826
# 112    0.010000    9.362563    0.000100    0.603693    0.519325    0.977408
#
#      x29_smth_0  x30_smth_0
# 0      0.534690    6.132880
# 1      0.534221    5.877048
# 2      0.533798    5.626077
# 3      0.533483    5.384628
# 4      0.533320    5.156921
# ..          ...         ...
# 108    0.800401    6.463137
# 109    0.807228    6.773778
# 110    0.809908    7.095447
# 111    0.761823    7.394089
# 112    0.770923    7.731153
#
# [113 rows x 32 columns]

# %%
ax = plt.gca()

#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

new_df.plot(kind='scatter', x='Fdbck', y='RMSE_total_best', color = 'darkgreen', 
         marker = '^', linewidth=6,  ax = ax)

init_df.plot(kind='scatter', x='Fdbck', y='RMSE', color = 'darkred', 
         marker = '^', linewidth=6,  ax = ax)

sol_df.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkgreen', 
         linewidth=3, ax = ax)

sol_df_2.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkred', linewidth=3, ax = ax)

E_multilinreg_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', 
                           color='gray', alpha=0.2, figsize=(15, 12), marker='o', ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)



plt.hlines(E_p1,xmin = -4.0,xmax = 2.0,label='default simulation', colors='black', 
           linestyles='dashed')
plt.vlines(p1_feedbacks,ymin = -10,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed')


#'MRI model', 'CAN model', 'MIROC model', 'HadGEM3 model', 'IPSL model','BCC model',
legend = legend = [ 'Optimization 1', 'Optimization 2', 'Initialization optimization 1', 'Initializaiton optimization 2', 'Emulations MultiLinReg', 'CNRM PPE', 'CNRM default model']

plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel(ylabel, fontsize=22)
plt.legend(legend, fontsize=15)
plt.title(TITLE, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0.5,2.5)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_"+variable_plot+"_PPE_optim2.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
RMSE_optim2 = sol_df_2['sol_fun']
np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/RMSE_optim2_'+variable_plot+'.npy', RMSE_optim2)

Fdbck_optim2 = sol_df_2['Fdbck']
np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Fdbck_optim2_'+variable_plot+'.npy', Fdbck_optim2)

# %% [markdown]
# # Selection des parametrizations à tester

# %%
df_select = sol_df_2[sol_df_2.index % 15 == 0]
df_select = df_select.append(sol_df_2.iloc[len(sol_df_2)-1])
df_select
# Out:
#       sol_fun     Fdbck  x1_smth_0  x2_smth_0  x3_smth_0  x4_smth_0  \
# 0    1.474382 -1.985956   0.101203   0.935225   2.308153  29.837944
# 15   1.166168 -1.794256   0.115702   0.833457   1.406088  20.318411
# 30   1.031388 -1.639852   0.143251   1.021675   1.379236  20.576765
# 45   0.957428 -1.490317   0.140169   1.471687   1.237693  21.515622
# 60   0.909220 -1.340301   0.127407   1.983278   1.109665  19.819356
# 75   0.876946 -1.190097   0.126038   2.286483   1.069117  20.060781
# 90   0.866640 -1.039839   0.134793   2.289397   0.938304  16.052528
# 105  0.906069 -0.872845   0.160681   2.425698   0.968510  20.170884
# 112  0.963115 -0.779854   0.140123   2.467341   0.954784  29.393078
#
#      x5_smth_0  x6_smth_0  x7_smth_0  x8_smth_0  ...  x21_smth_0  x22_smth_0  \
# 0    -0.079652   8.934249   3.064541   0.005118  ...   -2.509364  -25.309510
# 15   -0.084166   3.741808   4.709102   0.003939  ...   -3.144628  -32.637889
# 30   -0.089955   2.448082   4.835399   0.005181  ...   -2.884467  -32.807439
# 45   -0.099083   2.048921   4.614565   0.004942  ...   -3.244286  -34.672121
# 60   -0.111277   1.735601   5.316499   0.005306  ...   -2.816886  -36.061406
# 75   -0.148243   1.517292   5.213614   0.005149  ...   -2.564921  -36.391296
# 90   -0.131528   1.730886   5.214507   0.006324  ...   -2.856477  -40.721297
# 105  -0.254623   1.918673   5.327109   0.008364  ...   -2.801256  -44.191274
# 112  -0.333318   1.612349   6.235296   0.008351  ...   -2.498424  -47.365680
#
#      x23_smth_0  x24_smth_0  x25_smth_0  x26_smth_0  x27_smth_0  x28_smth_0  \
# 0      0.074928   14.089274    0.000044    0.911295    0.653061    0.507021
# 15     0.066811   13.470059    0.000036    0.891211    0.739061    0.681981
# 30     0.066548   11.880104    0.000051    0.879703    0.755559    0.776851
# 45     0.063385    8.843160    0.000063    0.885298    0.707176    0.787271
# 60     0.047715    8.660162    0.000067    0.893635    0.669176    0.762977
# 75     0.034877    7.440284    0.000062    0.854603    0.669827    0.780772
# 90     0.025256    5.645495    0.000071    0.797712    0.668069    0.813183
# 105    0.013704    7.171226    0.000086    0.664014    0.602377    0.874915
# 112    0.010000    9.362563    0.000100    0.603693    0.519325    0.977408
#
#      x29_smth_0  x30_smth_0
# 0      0.534690    6.132880
# 15     0.545993    4.033860
# 30     0.579361    4.408228
# 45     0.609319    3.738949
# 60     0.621882    3.406587
# 75     0.630408    4.324735
# 90     0.683398    4.553385
# 105    0.781156    5.645199
# 112    0.770923    7.731153
#
# [9 rows x 32 columns]

# %%
ax = plt.gca()

#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

new_df.plot(kind='scatter', x='Fdbck', y='RMSE_total_best', color = 'darkgreen', 
         marker = '^', linewidth=6,  ax = ax)

init_df.plot(kind='scatter', x='Fdbck', y='RMSE', color = 'darkred', 
         marker = '^', linewidth=6,  ax = ax)

sol_df.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkgreen', 
         linewidth=3, ax = ax)

sol_df_2.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkred', linewidth=3, ax = ax)

df_select.plot(kind='scatter', x='Fdbck', y='sol_fun', color='blue', marker='o', linewidth=15, 
               zorder=10, ax=ax)

E_multilinreg_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', 
                           color='gray', alpha=0.2, figsize=(15, 12), marker='o', ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)

plt.hlines(E_p1,xmin = -4.0,xmax = 2.0,label='default simulation', colors='black', 
           linestyles='dashed')
plt.vlines(p1_feedbacks,ymin = -10,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed')


#'MRI model', 'CAN model', 'MIROC model', 'HadGEM3 model', 'IPSL model','BCC model',
legend = legend = [ 'Optimization 1', 'Optimization 2', 'Initialization optimization 1', 
                   'Initializaiton optimization 2', 'Selection', 'Emulations MultiLinReg', 'CNRM PPE', 'CNRM default model']

plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel(ylabel, fontsize=22)
plt.legend(legend, fontsize=15)
plt.title(TITLE, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0.5,2.5)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_"+variable_plot+"_PPE_optim2_select.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
list_index = df_select.columns.tolist()
list_index
# Out:
# ['sol_fun',
#  'Fdbck',
#  'x1_smth_0',
#  'x2_smth_0',
#  'x3_smth_0',
#  'x4_smth_0',
#  'x5_smth_0',
#  'x6_smth_0',
#  'x7_smth_0',
#  'x8_smth_0',
#  'x9_smth_0',
#  'x10_smth_0',
#  'x11_smth_0',
#  'x12_smth_0',
#  'x13_smth_0',
#  'x14_smth_0',
#  'x15_smth_0',
#  'x16_smth_0',
#  'x17_smth_0',
#  'x18_smth_0',
#  'x19_smth_0',
#  'x20_smth_0',
#  'x21_smth_0',
#  'x22_smth_0',
#  'x23_smth_0',
#  'x24_smth_0',
#  'x25_smth_0',
#  'x26_smth_0',
#  'x27_smth_0',
#  'x28_smth_0',
#  'x29_smth_0',
#  'x30_smth_0']

# %%
np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/RMSE_optim2_select.npy', df_select)
np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/RMSE_optim2_select_indexes.npy', list_index)

# %% [markdown]
# # Ecrire le document .txt avec les valeurs de parametres

# %%
df_select_tmp = df_select.drop(['sol_fun', 'Fdbck'], axis=1)

#np.savetxt('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/txt/selection_optim2_param.txt', df_select_tmp.values)
#np.savetxt('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/txt/selection_BIS_optim2_param.txt', df_select_tmp.values)
np.savetxt('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/txt/selection_TER_optim2_param.txt', df_select_tmp.values)

# %% [markdown]
# # Simulations ARPEGE-Climat de la selection

# %%
nb_p_list_selection = ['p801', 'p802', 'p803', 'p804','p805', 'p806', 'p807', 'p808']
len(nb_p_list_selection)
# Out:
# 8

# %%
PC_PPE_selection = {}

for j in variables :
    for i in nb_p_list_selection :
        PC_PPE_selection[i+'_'+j] = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/npy/U_'+i+'_'+j+'.npy')
    
PC_PPE_selection
# Out:
# {'p801_tas': array([ 1.2245613, -1.5081006,  1.9946977,  1.5230054,  1.2770219],
#        dtype=float32),
#  'p802_tas': array([ 0.77490926, -0.33094734,  1.1236016 ,  1.4312241 , -0.70678806],
#        dtype=float32),
#  'p803_tas': array([ 0.5520675 ,  0.62216014,  0.30210823,  0.6068284 , -1.2610977 ],
#        dtype=float32),
#  'p804_tas': array([-0.3746975 , -1.1988878 ,  0.4115676 ,  0.13284907, -0.84948814],
#        dtype=float32),
#  'p805_tas': array([-0.61672276, -0.45078278, -0.16771463,  0.2374061 , -2.0084932 ],
#        dtype=float32),
#  'p806_tas': array([-0.37829357,  0.02391997, -0.6139136 , -0.62732065, -2.0032966 ],
#        dtype=float32),
#  'p807_tas': array([-0.49082744, -0.5455982 , -1.1729612 , -1.0544798 , -0.47725782],
#        dtype=float32),
#  'p808_tas': array([-0.567737  , -1.5143274 , -1.6198429 ,  0.9685622 , -0.09063481],
#        dtype=float32),
#  'p801_pr': array([ 1.8165653,  0.9917649, -0.2827582, -1.5563715, -2.4366276],
#        dtype=float32),
#  'p802_pr': array([ 1.6523272, -0.0815805, -0.1174168,  1.2811812, -2.5652878],
#        dtype=float32),
#  'p803_pr': array([ 1.1723629 , -0.5234489 ,  0.13481285,  0.8080382 , -2.0983865 ],
#        dtype=float32),
#  'p804_pr': array([ 0.74210346, -0.3052711 , -1.5837662 ,  1.39578   , -2.7161582 ],
#        dtype=float32),
#  'p805_pr': array([ 0.5950918 , -0.83581877,  1.0557648 ,  1.4260693 , -0.39964262],
#        dtype=float32),
#  'p806_pr': array([ 0.17695005,  0.16751726,  1.0895597 , -0.48937473,  1.0697423 ],
#        dtype=float32),
#  'p807_pr': array([ 0.21582745, -0.01250869,  1.4810269 ,  0.07231275,  0.924797  ],
#        dtype=float32),
#  'p808_pr': array([ 0.10064358,  0.6016051 ,  0.83033985, -0.23961858, -0.35503814],
#        dtype=float32),
#  'p801_SW': array([ 1.3616395 , -0.52457273,  1.0554186 ,  0.26597387,  1.1682943 ],
#        dtype=float32),
#  'p802_SW': array([ 1.3939706 , -0.33743528,  0.8395116 ,  0.1432313 ,  0.7179734 ],
#        dtype=float32),
#  'p803_SW': array([ 0.8950516 , -0.2463418 ,  0.6480056 , -0.81668836,  0.02925075],
#        dtype=float32),
#  'p804_SW': array([ 0.8662798 , -0.7542461 ,  0.57292324, -0.91503197,  0.30029967],
#        dtype=float32),
#  'p805_SW': array([ 0.36059475, -1.3126425 ,  0.5829075 , -0.79355216,  0.17344746],
#        dtype=float32),
#  'p806_SW': array([ 0.06837877, -2.0768929 ,  0.46456373,  0.10365239,  0.1129638 ],
#        dtype=float32),
#  'p807_SW': array([-0.5259612 , -1.6533306 ,  0.34346813, -0.54594225, -0.65560406],
#        dtype=float32),
#  'p808_SW': array([-1.4640808 , -1.9428518 ,  0.65797096, -0.697569  , -0.30053827],
#        dtype=float32),
#  'p801_LW': array([ 1.1129823e+00,  1.8751550e+00, -6.9573231e-02,  9.8705292e-04,
#          5.9543926e-01], dtype=float32),
#  'p802_LW': array([ 1.4467537 ,  0.46642545, -0.16885053, -0.05695641,  0.15867765],
#        dtype=float32),
#  'p803_LW': array([ 0.943686  , -0.04533631, -0.87833476,  0.87616223, -0.03439978],
#        dtype=float32),
#  'p804_LW': array([ 0.64756966, -0.29611972, -0.8536919 ,  0.9279688 , -0.3595368 ],
#        dtype=float32),
#  'p805_LW': array([ 0.13178393, -0.24885413, -0.75910735,  1.6282461 ,  0.6308554 ],
#        dtype=float32),
#  'p806_LW': array([-0.04131892, -0.3796668 , -1.0127534 ,  2.0120413 , -0.35410663],
#        dtype=float32),
#  'p807_LW': array([-0.39199245, -0.68314207, -1.4245478 ,  2.507503  , -0.23018353],
#        dtype=float32),
#  'p808_LW': array([-0.9203766, -0.9467508, -1.1497848,  3.1652732, -1.3764693],
#        dtype=float32)}

# %%
E_PPE_selection = {}

for j in variables :
    list_tmp = []
    for i in nb_p_list_selection :
        pc1 = PC_PPE_selection[i+'_'+j][0]
        pc2 = PC_PPE_selection[i+'_'+j][1]
        pc3 = PC_PPE_selection[i+'_'+j][2]
        pc4 = PC_PPE_selection[i+'_'+j][3]
        pc5 = PC_PPE_selection[i+'_'+j][4]
    
        list_tmp.append(Error_emulator(pc1, pc2, pc3, pc4, pc5, j))
    list_tmp.append(10)
    E_PPE_selection[j] = list_tmp

E_PPE_selection[j]
# Out:
# [1.4293476307704556,
#  1.7157232000258877,
#  1.4596319625954715,
#  1.492195582262849,
#  1.3353420631225468,
#  1.347406341048816,
#  1.4355889436425084,
#  1.7746316539054965,
#  10]

# %%
E_PPE_selection_total=[0]*len(E_PPE_selection['tas'])

for i in range(0,len(E_PPE_selection['tas']),1) :
    E_PPE_selection_total[i] = E_PPE_selection['tas'][i]/E_p1_df['E_p1_tas']+E_PPE_selection['pr'][i]/E_p1_df['E_p1_pr']+E_PPE_selection['SW'][i]/E_p1_df['E_p1_SW']+E_PPE_selection['LW'][i]/E_p1_df['E_p1_LW']
    E_PPE_selection_total[i] = E_PPE_selection_total[i]/4

E_PPE_selection_total[-1] = 10
E_PPE_selection_total
# Out:
# [1.257100659300694,
#  1.327526995334092,
#  1.2083315652800724,
#  1.2507666483460282,
#  1.0719619751421923,
#  0.8668024333850816,
#  1.0898337556911308,
#  1.2398514619089664,
#  10]

# %%
Fdbck_tmp = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/npy/Net_feedbacks.npy").tolist()
Fdbck_PPE_selection = []
for i in Fdbck_tmp :
    Fdbck_PPE_selection.append(i)
    
Fdbck_PPE_selection.append(10)
Fdbck_PPE_selection
# Out:
# [-1.7078146537144978,
#  -1.751123030980428,
#  -1.6688634951909382,
#  -1.5909866491953533,
#  -1.4788317680358887,
#  -1.2614845037460327,
#  -0.9229870438575745,
#  -0.7231393257776896,
#  10]

# %%
df_select
# Out:
#       sol_fun     Fdbck  x1_smth_0  x2_smth_0  x3_smth_0  x4_smth_0  \
# 0    1.392645 -1.985756   0.077966   0.707847   1.342598  29.587336
# 15   1.194457 -1.793526   0.117211   0.780585   1.458628  15.797065
# 30   1.052248 -1.639356   0.152330   0.910553   1.595681  12.928419
# 45   0.956511 -1.489737   0.178820   1.042084   1.647094  15.107814
# 60   0.893206 -1.339177   0.200599   1.137667   1.700507  16.354994
# 75   0.848631 -1.189214   0.196247   1.476706   1.575335  13.113172
# 90   0.818728 -1.039710   0.192539   1.760590   1.285336  11.040241
# 105  0.855271 -0.873525   0.200238   2.194593   1.132844  18.420054
# 112  0.993225 -0.779930   0.227325   2.645311   1.087184  29.392837
#
#      x5_smth_0  x6_smth_0  x7_smth_0  x8_smth_0  ...  x21_smth_0  x22_smth_0  \
# 0    -0.010000   7.143065   2.921715   0.000500  ...   -2.446023  -25.226770
# 15   -0.062336   3.922113   3.921972   0.002777  ...   -3.082096  -33.126637
# 30   -0.067871   2.424977   4.610691   0.003616  ...   -2.911492  -32.347723
# 45   -0.075286   1.700242   4.785704   0.004851  ...   -2.623568  -34.081485
# 60   -0.085945   1.539973   4.211867   0.005679  ...   -2.505365  -35.850443
# 75   -0.106827   1.492097   4.501310   0.005567  ...   -2.544657  -37.133155
# 90   -0.143078   1.853451   4.159379   0.005265  ...   -2.641183  -39.145415
# 105  -0.279349   1.605363   4.910546   0.005240  ...   -2.763235  -42.810276
# 112  -0.387431   1.723334   6.251026   0.005191  ...   -2.508373  -47.390254
#
#      x23_smth_0  x24_smth_0  x25_smth_0  x26_smth_0  x27_smth_0  x28_smth_0  \
# 0      0.069563   13.385950    0.000010    0.812696    0.500000    0.637957
# 15     0.064929   12.024501    0.000035    0.815730    0.678061    0.744172
# 30     0.052422   10.015403    0.000052    0.858959    0.666443    0.791925
# 45     0.038990    9.026731    0.000065    0.817358    0.665495    0.812169
# 60     0.027654    8.276984    0.000072    0.789666    0.669841    0.804791
# 75     0.022707    5.488733    0.000077    0.734181    0.649595    0.799212
# 90     0.014204    4.295963    0.000080    0.651121    0.627593    0.789305
# 105    0.010739    6.170077    0.000091    0.584788    0.566298    0.890971
# 112    0.010000    9.405416    0.000100    0.526937    0.526760    0.986168
#
#      x29_smth_0  x30_smth_0
# 0      0.500000    5.638358
# 15     0.539215    4.417620
# 30     0.566553    4.202803
# 45     0.570474    3.401959
# 60     0.585565    3.290619
# 75     0.634754    3.707331
# 90     0.687241    4.482628
# 105    0.782048    5.819485
# 112    0.858967    7.763388
#
# [9 rows x 32 columns]

# %%
colors = ['coral','blue','orange','black','green','red','purple','yellow','cornflowerblue']
cpt=0

ax = plt.gca()

#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

new_df.plot(kind='scatter', x='Fdbck', y='RMSE_total_best', color = 'darkred', alpha=0.2,
         marker = '^', linewidth=6,  ax = ax)

init_df.plot(kind='scatter', x='Fdbck', y='RMSE', color = 'darkred', alpha=0.5,
         marker = '^', linewidth=6,  ax = ax)

sol_df.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkred', alpha=0.2,
         linewidth=3, ax = ax)

sol_df_2.plot(kind='line', x='Fdbck', y='sol_fun', color = 'darkred', alpha=0.5, linewidth=3, ax = ax)

E_multilinreg_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', 
                           color='gray', alpha=0.1, figsize=(15, 12), marker='o', ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='RMSE_total', color='black', figsize=(15, 12), alpha=0.5,
                     marker="o", ax = ax)

plt.hlines(E_p1,xmin = -10.0,xmax = 25.0,label='default simulation', colors='black', 
           linestyles='dashed')
plt.vlines(p1_feedbacks,ymin = -10,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed')
legend = [ 'Optimization 1', 'Optimization 2', 'Initialization optimization 1', 
                   'Initializaiton optimization 2', 'Emulations MultiLinReg','CNRM PPE', 'CNRM default model']
plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel(ylabel, fontsize=22)
plt.legend(legend, fontsize=15)

ax1 = plt.gca()

for i in colors :
    plt.plot(df_select['Fdbck'].iloc[cpt], df_select['sol_fun'].iloc[cpt], color=i, marker='o', linewidth=0, markersize=15, zorder=8)

    plt.plot(Fdbck_PPE_selection[cpt], E_PPE_selection_total[cpt], color=i, marker='^', linewidth=0, markersize=15, zorder=9)
    cpt+=1
    
#legend = ['Emulated selection', 'ARPEGE-Climat selection']
#plt.legend(legend, fontsize=15)

plt.title(TITLE, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0.5,2.5)
plt.xlim(-2.2,-0.6)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_"+variable_plot+"_PPE_optim2_select.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %% [markdown]
# # Retour aux paramètres

# %%
param_names = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy')
E_emulator_df = E_multilinreg_df.reset_index()

x_emulator = pd.DataFrame(LHS, columns= param_names)
x_emulator['RMSE_total'] = E_emulator_df['RMSE_total']

x_emulator['RMSE_total_round'] = x_emulator['RMSE_total'].round(decimals=1)
x_emulator['members'] = range(0,100000,1) 

#x_emulator = x_emulator.set_index('RMSE_total_round')
#x_emulator_new_df=pd.DataFrame()
#x_emulator_new_df['RMSE_total_best'] = x_emulator['RMSE_total'].groupby('RMSE_total_round').min()
#x_emulator_new_df = x_emulator_new_df.reset_index()
#x_emulator_new_df

# %%
x_emulator
# Out:
#             AKN    ALPHAT       ALD     ALMAVE     AGREF     AGRE1     AGRE2  \
# 0      0.237758  1.166405  0.880392  28.558061 -0.013007  5.622351  4.162592
# 1      0.126381  0.534863  1.789610  28.480600 -0.198482  4.866094  7.643592
# 2      0.161582  2.774511  1.700513  18.863644 -0.035909  1.940661  1.154684
# 3      0.269570  0.617033  1.287904  21.638356 -0.425201  1.031540  7.213933
# 4      0.152002  2.445601  1.837120  17.701181 -0.021411  9.066585  2.859292
# ...         ...       ...       ...        ...       ...       ...       ...
# 99995  0.153543  0.610786  2.065459  14.516229 -0.463268  8.471504  1.785016
# 99996  0.097080  2.208875  1.340062  10.473539 -0.304292  3.296326  1.022391
# 99997  0.259355  1.213350  1.786574  19.759766 -0.205054  1.078345  7.513847
# 99998  0.136834  1.283644  0.691964   9.627438 -0.064111  1.770910  6.090318
# 99999  0.273117  1.155501  1.385027   4.996543 -0.181567  4.706733  0.164435
#
#         RAUTEFR     RQLCR   RAUTEFS  ...      FNEBC    GCTURB  RLWINHF_ICE  \
# 0      0.003295  0.000736  0.003610  ...   5.612146  0.000024     0.753132
# 1      0.002512  0.000263  0.002387  ...  18.155762  0.000076     0.655943
# 2      0.002071  0.000726  0.007475  ...   0.206254  0.000061     0.794010
# 3      0.006568  0.000110  0.006095  ...  16.561323  0.000062     0.920107
# 4      0.001732  0.000786  0.004183  ...   5.099756  0.000026     0.555454
# ...         ...       ...       ...  ...        ...       ...          ...
# 99995  0.003410  0.000638  0.001517  ...   5.107703  0.000088     0.887371
# 99996  0.002612  0.000963  0.003046  ...  17.028286  0.000049     0.527949
# 99997  0.001859  0.000531  0.009371  ...   9.389115  0.000087     0.854778
# 99998  0.009920  0.000873  0.007538  ...  19.291965  0.000057     0.823763
# 99999  0.000597  0.000222  0.002823  ...  16.261407  0.000063     0.510950
#
#        RLWINHF_LIQ  RSWINHF_ICE  RSWINHF_LIQ  REFLCAPE  RMSE_total  \
# 0         0.692837     0.800605     0.649651  2.439231    1.180956
# 1         0.845886     0.712394     0.628513  9.773983    1.326596
# 2         0.880129     0.996989     0.713900  0.379772    1.209845
# 3         0.717110     0.717044     0.901268  9.714537    1.340831
# 4         0.882347     0.915713     0.653554  2.734065    1.277609
# ...            ...          ...          ...       ...         ...
# 99995     0.829693     0.874071     0.772201  2.832374    1.363864
# 99996     0.952927     0.519428     0.923016  2.204335    1.275086
# 99997     0.778580     0.562029     0.586887  1.455238    1.140803
# 99998     0.609284     0.856318     0.536784  1.115876    1.094331
# 99999     0.702040     0.506628     0.862903  9.175721    1.107138
#
#        RMSE_total_round  members
# 0                   1.2        0
# 1                   1.3        1
# 2                   1.2        2
# 3                   1.3        3
# 4                   1.3        4
# ...                 ...      ...
# 99995               1.4    99995
# 99996               1.3    99996
# 99997               1.1    99997
# 99998               1.1    99998
# 99999               1.1    99999
#
# [100000 rows x 33 columns]

# %%
x_init1 = pd.DataFrame(x_best, columns=[i+'_init1' for i in param_names])
x_init1['members'] = range(0, len(x_init1), 1)
x_init1 = x_init1.set_index('members')

#x_init1

x_optim1 = pd.DataFrame()
for i in range(0,len(param_names),1) :
    j = i+1
    x_optim1[param_names[i]+'_optim1'] = sol_df['x'+str(j)+'_smth_0']
x_optim1['members'] = range(0, len(x_init1), 1)
x_optim1 = x_optim1.set_index('members')
#x_optim1

x_init2 = pd.DataFrame()
for i in range(0,len(param_names),1) :
    j = i+1
    x_init2[param_names[i]+'_init2'] = new_sol_df['x'+str(j)+'_smth_150']
x_init2['members'] = range(0, len(x_init1), 1)
x_init2 = x_init2.set_index('members')
#x_init2

x_optim2 = pd.DataFrame()
for i in range(0,len(param_names),1) :
    j = i+1
    x_optim2[param_names[i]+'_optim2'] = sol_df_2['x'+str(j)+'_smth_0']
x_optim2['members'] = range(0, len(x_init1), 1)
x_optim2 = x_optim2.set_index('members')
#x_optim2

X = x_init1.merge(x_optim1, on = ['members']).merge(x_init2, on = ['members']).merge(x_optim2, on = ['members'])
X['Fdbck'] = sol_df_2['Fdbck']
X
# Out:
#          AKN_init1  ALPHAT_init1  ALD_init1  ALMAVE_init1  AGREF_init1  \
# members
# 0         0.101203      0.935243   2.308255     29.837952    -0.079684
# 1         0.130412      0.518184   2.873471     18.853142    -0.088696
# 2         0.060030      0.673590   0.982939     27.136969    -0.070644
# 3         0.100662      0.836307   2.654555     18.442719    -0.453594
# 4         0.196303      0.877569   1.289750     28.958626    -0.157403
# ...            ...           ...        ...           ...          ...
# 108       0.263189      2.489173   0.761064     19.351755    -0.389062
# 109       0.251494      2.884951   1.104804     14.670452    -0.110285
# 110       0.227409      2.734908   0.589627     17.694904    -0.472463
# 111       0.268083      2.483527   1.734056     21.239650    -0.176299
# 112       0.277147      2.743103   1.149887     29.416178    -0.433817
#
#          AGRE1_init1  AGRE2_init1  RAUTEFR_init1  RQLCR_init1  RAUTEFS_init1  \
# members
# 0           8.934402     3.064550       0.005121     0.000707       0.007420
# 1           7.830207     5.731744       0.007948     0.000727       0.009232
# 2           8.114980     1.743752       0.005571     0.000852       0.009832
# 3           9.505307     0.642719       0.005494     0.000176       0.009153
# 4           7.067111     7.084477       0.004569     0.000972       0.003017
# ...              ...          ...            ...          ...            ...
# 108         3.214550     5.025119       0.006128     0.000713       0.003799
# 109         1.809796     7.957505       0.008150     0.000587       0.001890
# 110         0.366991     4.404478       0.002448     0.000631       0.002425
# 111         0.270500     4.042389       0.006403     0.000738       0.000601
# 112         1.811955     6.265495       0.007767     0.000732       0.006875
#
#          ...  VVX_optim2  ALFX_optim2  FNEBC_optim2  GCTURB_optim2  \
# members  ...
# 0        ...  -25.226770     0.069563     13.385950       0.000010
# 1        ...  -26.114361     0.068199     13.346956       0.000012
# 2        ...  -26.983158     0.068074     13.269346       0.000013
# 3        ...  -27.824171     0.067952     13.190097       0.000015
# 4        ...  -28.624894     0.067832     13.108545       0.000016
# ...      ...         ...          ...           ...            ...
# 108      ...  -44.557292     0.010395      7.414493       0.000095
# 109      ...  -45.227721     0.010292      7.887913       0.000096
# 110      ...  -45.930026     0.010192      8.381916       0.000097
# 111      ...  -46.654468     0.010096      8.890064       0.000099
# 112      ...  -47.390254     0.010000      9.405416       0.000100
#
#          RLWINHF_ICE_optim2  RLWINHF_LIQ_optim2  RSWINHF_ICE_optim2  \
# members
# 0                  0.812696            0.500000            0.637957
# 1                  0.813301            0.515927            0.642226
# 2                  0.810558            0.531731            0.652548
# 3                  0.808015            0.547270            0.662634
# 4                  0.805766            0.562424            0.672378
# ...                     ...                 ...                 ...
# 108                0.562256            0.549901            0.929625
# 109                0.553821            0.544214            0.943399
# 110                0.545053            0.538444            0.957480
# 111                0.536054            0.532617            0.971771
# 112                0.526937            0.526760            0.986168
#
#          RSWINHF_LIQ_optim2  REFLCAPE_optim2     Fdbck
# members
# 0                  0.500000         5.638358 -1.985756
# 1                  0.502315         5.477447 -1.971657
# 2                  0.504647         5.293924 -1.957511
# 3                  0.507009         5.119654 -1.943472
# 4                  0.509416         4.958683 -1.929586
# ...                     ...              ...       ...
# 108                0.812983         6.570869 -0.834365
# 109                0.824130         6.854966 -0.820920
# 110                0.835573         7.150933 -0.807336
# 111                0.847219         7.455076 -0.793657
# 112                0.858967         7.763388 -0.779930
#
# [113 rows x 121 columns]

# %%
sol_df_2['RMSE'] = sol_df_2['sol_fun'].round(decimals=2)
sol_df_2
# Out:
#       sol_fun     Fdbck  x1_smth_0  x2_smth_0  x3_smth_0  x4_smth_0  \
# 0    1.392645 -1.985756   0.077966   0.707847   1.342598  29.587336
# 1    1.378591 -1.971657   0.076717   0.716532   1.382244  28.410715
# 2    1.363054 -1.957511   0.079979   0.717573   1.380875  27.229257
# 3    1.347927 -1.943472   0.083209   0.718839   1.379933  26.065955
# 4    1.333222 -1.929586   0.086392   0.720441   1.379640  24.929361
# ..        ...       ...        ...        ...        ...        ...
# 108  0.900105 -0.834365   0.210431   2.372874   1.114905  22.678511
# 109  0.919950 -0.820920   0.214415   2.438452   1.108305  24.280894
# 110  0.942226 -0.807336   0.218603   2.506176   1.101434  25.947742
# 111  0.966747 -0.793657   0.222929   2.575371   1.094362  27.658976
# 112  0.993225 -0.779930   0.227325   2.645311   1.087184  29.392837
#
#      x5_smth_0  x6_smth_0  x7_smth_0  x8_smth_0  ...  x22_smth_0  x23_smth_0  \
# 0    -0.010000   7.143065   2.921715   0.000500  ...  -25.226770    0.069563
# 1    -0.015355   6.930076   3.045646   0.000654  ...  -26.114361    0.068199
# 2    -0.020647   6.627855   3.159121   0.000808  ...  -26.983158    0.068074
# 3    -0.025810   6.332307   3.267822   0.000963  ...  -27.824171    0.067952
# 4    -0.030782   6.046480   3.369726   0.001119  ...  -28.624894    0.067832
# ..         ...        ...        ...        ...  ...         ...         ...
# 108  -0.323016   1.634808   5.432182   0.005231  ...  -44.557292    0.010395
# 109  -0.338658   1.653289   5.627965   0.005224  ...  -45.227721    0.010292
# 110  -0.354690   1.674856   5.831323   0.005214  ...  -45.930026    0.010192
# 111  -0.370992   1.698553   6.039860   0.005203  ...  -46.654468    0.010096
# 112  -0.387431   1.723334   6.251026   0.005191  ...  -47.390254    0.010000
#
#      x24_smth_0  x25_smth_0  x26_smth_0  x27_smth_0  x28_smth_0  x29_smth_0  \
# 0     13.385950    0.000010    0.812696    0.500000    0.637957    0.500000
# 1     13.346956    0.000012    0.813301    0.515927    0.642226    0.502315
# 2     13.269346    0.000013    0.810558    0.531731    0.652548    0.504647
# 3     13.190097    0.000015    0.808015    0.547270    0.662634    0.507009
# 4     13.108545    0.000016    0.805766    0.562424    0.672378    0.509416
# ..          ...         ...         ...         ...         ...         ...
# 108    7.414493    0.000095    0.562256    0.549901    0.929625    0.812983
# 109    7.887913    0.000096    0.553821    0.544214    0.943399    0.824130
# 110    8.381916    0.000097    0.545053    0.538444    0.957480    0.835573
# 111    8.890064    0.000099    0.536054    0.532617    0.971771    0.847219
# 112    9.405416    0.000100    0.526937    0.526760    0.986168    0.858967
#
#      x30_smth_0  RMSE
# 0      5.638358  1.39
# 1      5.477447  1.38
# 2      5.293924  1.36
# 3      5.119654  1.35
# 4      4.958683  1.33
# ..          ...   ...
# 108    6.570869  0.90
# 109    6.854966  0.92
# 110    7.150933  0.94
# 111    7.455076  0.97
# 112    7.763388  0.99
#
# [113 rows x 33 columns]

# %%
def plot_param(df, param_y, xlabel, ylabel, hue, colors, param_names, ax):
    
    sns.scatterplot(data=df, x="Fdbck", y=param_y+'_smth_0', hue=hue, legend = 'full', palette=colors, ax=ax)
    
    plt.plot(p1_feedbacks, p1_params[ylabel], color='black', marker='+', linewidth=0, markersize=50)
    
    plt.xlabel(xlabel, fontsize=20)
    plt.ylabel(ylabel, fontsize=20)
    #plt.legend(legend, fontsize=15)
    #plt.title('Param 1 et 2', fontsize=30)
    #ax.legend([None])
    ax.get_legend().remove()
    ax.tick_params(axis='both', which='major', labelsize=15)
    plt.xlim(-2.2,-0.5) 
    ind = df[param_y+'_smth_0'].max() - df[param_y+'_smth_0'].min()
    if p1_params[ylabel]<df[param_y+'_smth_0'].min() :
        lim_min = p1_params[ylabel]
    else :
        lim_min = df[param_y+'_smth_0'].min()
    
    if p1_params[ylabel]>df[param_y+'_smth_0'].max() :
        lim_max = p1_params[ylabel]
    else :
        lim_max = df[param_y+'_smth_0'].max()
        
    plt.ylim(lim_min-ind/10,lim_max+ind/10)

    # Show la figure .................
    #plt.show()

# %%
# READ FROM ROMAIN REF NAMELIST 

p1_params = {}
p1_params['AKN'] = 0.126
p1_params['ALPHAT'] = 1.13
p1_params['ALD'] = 1.18
p1_params['ALMAVE'] = 10.0
p1_params['AGREF'] = -0.36
p1_params['AGRE1'] = 5.5
p1_params['AGRE2'] = 0.0
p1_params['RAUTEFR'] = 0.001
p1_params['RQLCR'] = 0.0002
p1_params['RAUTEFS'] = 0.0052
p1_params['RQICRMIN'] = 0.0000001
p1_params['RQICRMAX'] = 0.000021
p1_params['TFVL'] = 0.02
p1_params['TFVI'] = 0.04
p1_params['TFVR'] = 3.0
p1_params['TFVS'] = 0.6
p1_params['RKDN'] = 0.00005
p1_params['RKDX'] = 0.0001
p1_params['TENTR'] = 0.000004
p1_params['TENTRX'] = 0.00006
p1_params['VVN'] = -2.0
p1_params['VVX'] = -35.0
p1_params['ALFX'] = 0.04
p1_params['FNEBC'] = 10.0
p1_params['GCTURB'] = 0.00005
p1_params['RLWINHF_ICE'] = 0.9
p1_params['RLWINHF_LIQ'] = 0.9
p1_params['RSWINHF_ICE'] = 0.71
p1_params['RSWINHF_LIQ'] = 0.71
p1_params['REFLCAPE'] = 2.0

np.save('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/p1_params', p1_params)
#p1_params

# %%
df=sol_df_2
hue = df['RMSE']
legend = df['RMSE']
xlabel = 'Fdbck'
colors = plt.cm.get_cmap('summer')

plt.subplots(figsize=(25,25)) 
ax={}

for i in range(0, 30, 1) :
    
    plt.subplot(6,5,(i+1))
    ax[str(i)] = plt.gca()
    param_y= 'x'+str(i+1)       
    ylabel = param_names[i]
    plot_param(df, param_y, xlabel, ylabel, hue, colors, param_names, ax[str(i)])
        

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)
plt.legend(fontsize=22, bbox_to_anchor=(1.05, 7.5), loc=2)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/param_fdbck_optim2.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

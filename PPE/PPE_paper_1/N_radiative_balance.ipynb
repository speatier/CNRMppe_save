# %% [markdown]
# # Importe modules

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas

# Plotting modules 
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# # Functions definition

# %%
import sys
sys.path.append('/data/home/globc/peatier/CNRMppe')
import Fonctions
from Fonctions import get_wavg_budget_df
from Fonctions import wavg 
from Fonctions import plotlines_Xdf
from Fonctions import plotlines_1df
from Fonctions import Deltas_Lambda
from Fonctions import Deltas_SW
from Fonctions import Deltas_LW

# %% [markdown]
# # Settings

# %%
ENSEMBLE = 'ENSEMBLE4_selection/'
path_official = '/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE_short = '/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# %% [markdown]
# # Read files : radiative budget, tas

# %% [markdown]
# ## Opimal selection : amip and amip-future4K

# %%
path = path_official
filename = '*_CNRM-CM6-1_amip_*.nc'
start_yr = 1979
drop = True
year_list = range(1982,2015,1)
official_amip = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
official_amip

path = path_official
filename = '*_CNRM-CM6-1_amip-future4K_*.nc'
start_yr = 1979
drop = True
year_list = range(1982,2015,1)
official_future4K = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
official_future4K
# Out:
#          rlut        rsut        rsdt         tas           F           H  \
# 0  246.033493  100.208107  340.698730  291.714813  340.698730  346.241608
# 1  246.036575  100.286873  340.691254  291.756744  340.691254  346.323456
# 2  246.216858  100.169746  340.688416  291.737305  340.688416  346.386597
#
#           N
# 0 -5.542877
# 1 -5.632202
# 2 -5.698181

# %%
path = path_PPE_short+'ENSEMBLE1/CNRM-CM6-1_amip_PPE/CNRM-CM6-1_amip_r1i1p1f2/'
filename = '*_CNRM-CM6-1_amip_*.nc'
start_yr = 1979
drop = False
year_list = None
p1_amip = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
p1_amip

start_yr = 1951
path = path_PPE_short+'ENSEMBLE1/CNRM-CM6-1_amip-future4K_PPE/CNRM-CM6-1_amip-future4K_r1i1p1f2/'
filename = '*_CNRM-CM6-1_amip-future4K_*.nc'
p1_future4K = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
p1_future4K
# Out:
#          rlut        rsut        rsdt         tas           F           H  \
# 0  245.847061   99.844887  340.496674  291.295715  340.496674  345.691956
# 1  245.930023  100.026192  340.500641  291.433716  340.500641  345.956207
# 2  246.320786   99.984657  340.466858  291.496887  340.466858  346.305450
# 3  246.335007   99.894569  340.467224  291.325195  340.467224  346.229584
# 4  246.418381   99.600266  340.520782  291.306335  340.520782  346.018646
#
#           N
# 0 -5.195282
# 1 -5.455566
# 2 -5.838593
# 3 -5.762360
# 4 -5.497864

# %%
nb_p_list_LHS500 = ['p860', 'p861', 'p862', 'p864', 'p865', 'p866', 'p867', 'p868', 'p869', 
                    'p870', 'p871', 'p872', 'p873','p874', 'p875', 'p876', 'p877', 'p878', 'p879',
                    'p880', 'p881', 'p882', 'p883']
len(nb_p_list_LHS500)
# Out:
# 23

# %%
path_PPE = path_PPE_short+ENSEMBLE

# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
N=len(nb_p_list_LHS500)
amip_LHS500={}
i = 0
while i<N:
    nb_p_LHS500 = nb_p_list_LHS500[i]
    print(nb_p_LHS500)
    path=path_PPE+'CNRM-CM6-1_amip_PPE_ENSEMBLE4_selection/CNRM-CM6-1_amip_r1i1'+nb_p_LHS500+'f2/'
    filename = '*_CNRM-CM6-1_amip_r1i1'+nb_p_LHS500+'f2*.nc'
    amip_LHS500[str(nb_p_LHS500) + "_amip"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# p860
# p861
# p862
# p864
# p865
# p866
# p867
# p868
# p869
# p870
# p871
# p872
# p873
# p874
# p875
# p876
# p877
# p878
# p879
# p880
# p881
# p882
# p883

# %%
# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
N=len(nb_p_list_LHS500)
future4K_LHS500={}
i = 0
while i<N:
    nb_p_LHS500 = nb_p_list_LHS500[i]
    print(nb_p_LHS500)
    path=path_PPE+'CNRM-CM6-1_amip-future4K_PPE_ENSEMBLE4_selection/CNRM-CM6-1_amip-future4K_r1i1'+nb_p_LHS500+'f2/'
    filename = '*_CNRM-CM6-1_amip-future4K_r1i1'+nb_p_LHS500+'f2*.nc'
    future4K_LHS500[str(nb_p_LHS500) + "_future4K"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# p860
# p861
# p862
# p864
# p865
# p866
# p867
# p868
# p869
# p870
# p871
# p872
# p873
# p874
# p875
# p876
# p877
# p878
# p879
# p880
# p881
# p882
# p883

# %%
p1_N = p1_amip['N'].mean()
p1_feedbacks = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks_p1.npy')

# %%
list_N=[]

for i in nb_p_list_LHS500 :
    tmp = amip_LHS500[i+'_amip']['N'].mean()
    list_N.append(tmp)
    
list_N
# Out:
# [1.9489542,
#  1.4087728,
#  1.1741842,
#  0.45031738,
#  0.37952676,
#  0.26816812,
#  0.14390056,
#  -0.13972981,
#  -0.78168744,
#  -1.3870951,
#  -1.9949951,
#  -2.6914978,
#  -3.5911763,
#  -4.8407493,
#  -6.137848,
#  -7.0177817,
#  -8.204407,
#  -10.028554,
#  -13.37794,
#  -18.201498,
#  -24.101868,
#  -30.62852,
#  -32.78258]

# %%
Fdbck = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/npy/SIX_Net_feedbacks.npy')

df_tmp = pd.DataFrame([list_N, Fdbck]).transpose()
df_N = pd.DataFrame()
df_N['N'] = df_tmp[0]
df_N['Fdbck'] = df_tmp[1]
df_N
# Out:
#             N     Fdbck
# 0    1.948954 -1.701829
# 1    1.408773 -1.646602
# 2    1.174184 -1.650679
# 3    0.450317 -1.573141
# 4    0.379527 -1.604805
# 5    0.268168 -1.594605
# 6    0.143901 -1.584928
# 7   -0.139730 -1.553765
# 8   -0.781687 -1.485347
# 9   -1.387095 -1.535616
# 10  -1.994995 -1.469184
# 11  -2.691498 -1.407259
# 12  -3.591176 -1.308760
# 13  -4.840749 -1.178502
# 14  -6.137848 -1.117529
# 15  -7.017782 -1.077129
# 16  -8.204407 -0.965792
# 17 -10.028554 -0.902485
# 18 -13.377940 -0.709846
# 19 -18.201498 -0.598867
# 20 -24.101868 -0.641005
# 21 -30.628519 -0.696281
# 22 -32.782581 -0.675996

# %% [markdown]
# ## Optim N

# %%
#nb_p_list_optimN = ['p830', 'p831', 'p832', 'p833', 'p834', 'p835']
#len(nb_p_list_optimN)

# %%
path_PPE = path_PPE_short+ENSEMBLE

# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
N=len(nb_p_list_optimN)
amip_LHS500={}
i = 0
while i<N:
    nb_p_LHS500 = nb_p_list_optimN[i]
    print(nb_p_LHS500)
    path=path_PPE+'CNRM-CM6-1_amip_PPE_ENSEMBLE4_selection/CNRM-CM6-1_amip_r1i1'+nb_p_LHS500+'f2/'
    filename = '*_CNRM-CM6-1_amip_r1i1'+nb_p_LHS500+'f2*.nc'
    amip_LHS500[str(nb_p_LHS500) + "_amip"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ea462bdcd5a8> in <module>
#       6 drop=False
#       7 year_list=None
# ----> 8 N=len(nb_p_list_optimN)
#       9 amip_LHS500={}
#      10 i = 0
#
# NameError: name 'nb_p_list_optimN' is not defined

# %%
# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
N=len(nb_p_list_optimN)
future4K_LHS500={}
i = 0
while i<N:
    nb_p_LHS500 = nb_p_list_optimN[i]
    print(nb_p_LHS500)
    path=path_PPE+'CNRM-CM6-1_amip-future4K_PPE_ENSEMBLE4_selection/CNRM-CM6-1_amip-future4K_r1i1'+nb_p_LHS500+'f2/'
    filename = '*_CNRM-CM6-1_amip-future4K_r1i1'+nb_p_LHS500+'f2*.nc'
    future4K_LHS500[str(nb_p_LHS500) + "_future4K"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1

# %%
list_N_optimN=[]

for i in nb_p_list_optimN :
    tmp = amip_LHS500[i+'_amip']['N'].mean()
    list_N_optimN.append(tmp)
    
list_N_optimN

# %%
Fdbck = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE4_selection/files/npy/Net_feedbacks_optimN.npy')

df_tmp = pd.DataFrame([list_N_optimN, Fdbck]).transpose()
df_N_optimN = pd.DataFrame()
df_N_optimN['N'] = df_tmp[0]
df_N_optimN['Fdbck'] = df_tmp[1]
df_N_optimN

# %% [markdown]
# ## PPE

# %%
nb_p_list = ['p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412',
                    'p414','p416',
                    'p413','p419','p424','p426','p428','p421','p423',
                    'p425','p427','p429','p430','p436','p438','p431','p433',
                    'p442','p446','p443','p445','p447',
                    'p452','p454','p456','p458','p457','p459',
                    'p460','p465','p467','p469',
                    'p470','p471']

len(nb_p_list)
# Out:
# 102

# %%
ENSEMBLE = 'ENSEMBLE2/'
path_PPE = path_PPE_short+ENSEMBLE

# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
N=len(nb_p_list)
amip={}
i = 0
while i<N:
    nb_p = nb_p_list[i]
    print(nb_p)
    path=path_PPE+'CNRM-CM6-1_amip_LHS500_PPE/CNRM-CM6-1_amip_r1i1'+nb_p+'f2/'
    filename = '*_CNRM-CM6-1_amip_r1i1'+nb_p+'f2*.nc'
    amip[str(nb_p) + "_amip"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# p311
# p312
# p314
# p316
# p317
# p319
# p320
# p321
# p322
# p324
# p325
# p326
# p329
# p330
# p331
# p332
# p335
# p336
# p337
# p338
# p340
# p341
# p343
# p344
# p346
# p347
# p348
# p349
# p350
# p353
# p355
# p357
# p359
# p360
# p361
# p363
# p365
# p367
# p368
# p369
# p372
# p373
# p374
# p375
# p376
# p378
# p381
# p382
# p384
# p386
# p388
# p389
# p391
# p392
# p393
# p394
# p395
# p396
# p398
# p399
# p400
# p404
# p406
# p407
# p409
# p410
# p411
# p412
# p414
# p416
# p413
# p419
# p424
# p426
# p428
# p421
# p423
# p425
# p427
# p429
# p430
# p436
# p438
# p431
# p433
# p442
# p446
# p443
# p445
# p447
# p452
# p454
# p456
# p458
# p457
# p459
# p460
# p465
# p467
# p469
# p470
# p471

# %%
# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
N=len(nb_p_list)
future4K={}
i = 0
while i<N:
    nb_p = nb_p_list[i]
    print(nb_p)
    path=path_PPE+'CNRM-CM6-1_amip-future4K_LHS500_PPE/CNRM-CM6-1_amip-future4K_r1i1'+nb_p+'f2/'
    filename = '*_CNRM-CM6-1_amip-future4K_r1i1'+nb_p+'f2*.nc'
    future4K[str(nb_p) + "_future4K"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# p311
# p312
# p314
# p316
# p317
# p319
# p320
# p321
# p322
# p324
# p325
# p326
# p329
# p330
# p331
# p332
# p335
# p336
# p337
# p338
# p340
# p341
# p343
# p344
# p346
# p347
# p348
# p349
# p350
# p353
# p355
# p357
# p359
# p360
# p361
# p363
# p365
# p367
# p368
# p369
# p372
# p373
# p374
# p375
# p376
# p378
# p381
# p382
# p384
# p386
# p388
# p389
# p391
# p392
# p393
# p394
# p395
# p396
# p398
# p399
# p400
# p404
# p406
# p407
# p409
# p410
# p411
# p412
# p414
# p416
# p413
# p419
# p424
# p426
# p428
# p421
# p423
# p425
# p427
# p429
# p430
# p436
# p438
# p431
# p433
# p442
# p446
# p443
# p445
# p447
# p452
# p454
# p456
# p458
# p457
# p459
# p460
# p465
# p467
# p469
# p470
# p471

# %%
PPE_list_N=[]

for i in nb_p_list :
    tmp = amip[i+'_amip']['N'].mean()
    PPE_list_N.append(tmp)
    
#PPE_list_N

# %%
Fdbck = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy')

PPE_df_tmp = pd.DataFrame([PPE_list_N, Fdbck]).transpose()
PPE_df_N = pd.DataFrame()
PPE_df_N['N'] = PPE_df_tmp[0]
PPE_df_N['Fdbck'] = PPE_df_tmp[1]
PPE_df_N
# Out:
#              N     Fdbck
# 0   -18.094126 -0.825236
# 1    -3.648834 -1.659636
# 2   -13.441487 -1.215000
# 3    -8.259552 -1.321641
# 4   -12.501689 -0.750397
# ..         ...       ...
# 97   -0.706187 -1.516367
# 98   11.323659 -1.584491
# 99    4.154989 -1.474525
# 100  -6.293488 -1.445422
# 101  14.699718 -1.706865
#
# [102 rows x 2 columns]

# %% [markdown]
# ## Create Figure

# %%
import matplotlib.colors as mcolors
import random

plt_colors = list(mcolors.CSS4_COLORS.keys())

# %%
# PARAMETERS :
st=30
colors=plt_colors[st:st+23]

fig = plt.figure(figsize=(14, 12))

ax = plt.gca()

cpt=0
for i in colors :
    if cpt == 0 :

        ax.plot(df_N['Fdbck'][cpt], df_N['N'][cpt], 
                markerfacecolor=i, color='black',
                marker='^', linewidth=0,  
                label='ARPEGE-Climat simulations', markersize=25, zorder=10)
        cpt+=1
    else :
        
        plt.plot(df_N['Fdbck'][cpt], df_N['N'][cpt], 
                 markerfacecolor=i, color='black',
                 marker='^', linewidth=0, markersize=25, 
                 label='_nolegend_', zorder=10)
        cpt+=1

PPE_df_N.plot(kind='scatter', x='Fdbck', y='N', color = 'grey', alpha=1, linewidth=2, figsize=(15, 12), 
          ax = ax)

        
#df_N_optimN.plot(kind='scatter', x='Fdbck', y='N', color = 'darkred', alpha=1, linewidth=8, figsize=(15, 12), 
#          ax = ax)

ax.fill_between(range(-10, 10, 1), -1, 1, color='forestgreen', alpha=0.2)

plt.hlines(p1_N,xmin = -10.0,xmax = 25.0,label='default simulation', colors='black', 
           linestyles='dashed', linewidth=2.5, zorder=1)
plt.vlines(p1_feedbacks,ymin = -50,ymax = 50,label='default simulation', colors='black', 
           linestyles='dashed', linewidth=2.5)



legend = [ 'CNRM-CM candidates', 'ARPEGE-Climat PPE ', 
          '$\pm 1\ W.m^2$','ARPEGE-Climat ref.']
plt.xlabel('Feedback parameter $\lambda$ ($W.m^{-2}.K^{-1}$)', fontsize=20)
plt.ylabel('TOA radiative balance N', fontsize=25)
plt.legend(legend, fontsize=20) #bbox_to_anchor=(1.05, 1)

plt.title('Runs selected with MLR optimization', fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=20)
plt.ylim(-35,10)
plt.xlim(-2.2,-0.4)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/N_amip_ENSEMBLE4_selection.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

plt.show()

# %% [markdown]
# # Feedbacks CERES via SW fluxes
#
# (1) Reconstruit les données avec les PCs et EOFs des flux SW.
#
# (2) Multi Linéaire Régression des PCs sur les feedbacks pour trouver les coefficients Beta.
#
# (3) Retrouver les PCs des observations CERES.
#
# (4) Prédire les feedbacks des observations.

# %% [markdown]
# # Importe modules

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas
from eofs.xarray import Eof
from eofs.multivariate.standard import MultivariateEof

# Plotting modules 
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import BoundaryNorm

# Scikit-learn
from sklearn import linear_model
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# # Functions definition

# %%
import sys
sys.path.append('/data/home/globc/peatier/CNRMppe')
import Fonctions
from Fonctions import get_wavg_budget_df
from Fonctions import wavg 
from Fonctions import plotlines_Xdf
from Fonctions import plotlines_1df
from Fonctions import Deltas_Lambda
from Fonctions import get_3D_budget_xarr
from Fonctions import get_3D_xarr
from Fonctions import get_3D_SW_xarr
from Fonctions import get_3D_LW_xarr

# %% [markdown]
# # EOF, SW_mean and PCs

# %%
SW_mean =  pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_SW_mean.npy').to_xarray().to_array()
SW_mean = SW_mean[0,:,:].rename({'variable':'mode'})
SW_mean
# Out:
# <xarray.DataArray (lat: 128, lon: 256)>
# array([[126.76994 , 126.76994 , 126.76994 , ..., 126.76994 , 126.76994 ,
#         126.76994 ],
#        [121.13958 , 121.13958 , 121.13958 , ..., 121.13958 , 121.13958 ,
#         121.13958 ],
#        [124.57382 , 124.57382 , 124.57382 , ..., 124.69056 , 124.57382 ,
#         124.57382 ],
#        ...,
#        [115.06742 , 115.06742 , 115.06742 , ..., 114.464325, 115.06742 ,
#         115.06742 ],
#        [115.30856 , 115.30856 , 115.30856 , ..., 115.30856 , 115.30856 ,
#         115.30856 ],
#        [115.79212 , 115.79212 , 115.79212 , ..., 115.79212 , 115.79212 ,
#         115.79212 ]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon      (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
#     mode     <U7 'SW_mean'

# %%
SW_anom =  pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_SW_anom.npy').to_xarray().to_array()
SW_anom = SW_anom[0,:,:].rename({'variable':'mode'})
SW_anom
# Out:
# <xarray.DataArray (time: 104, lat: 128, lon: 256)>
# array([[[ 1.0198593 ,  1.0198593 ,  1.0198593 , ...,  1.0198593 ,
#           1.0198593 ,  1.0198593 ],
#         [ 0.21433258,  0.21433258,  0.21433258, ...,  0.21433258,
#           0.21433258,  0.21433258],
#         [ 1.5374527 ,  1.5374527 ,  1.5374527 , ...,  1.343956  ,
#           1.5374527 ,  1.5374527 ],
#         ...,
#         [-0.77801514, -0.77801514, -0.77801514, ..., -0.97159576,
#          -0.77801514, -0.77801514],
#         [-1.1984177 , -1.1984177 , -1.1984177 , ..., -1.1984177 ,
#          -1.1984177 , -1.1984177 ],
#         [-1.3507843 , -1.3507843 , -1.3507843 , ..., -1.3507843 ,
#          -1.3507843 , -1.3507843 ]],
#
#        [[ 0.6755676 ,  0.6755676 ,  0.6755676 , ...,  0.6755676 ,
#           0.6755676 ,  0.6755676 ],
#         [ 0.6979904 ,  0.6979904 ,  0.6979904 , ...,  0.6979904 ,
#           0.6979904 ,  0.6979904 ],
#         [ 1.6893997 ,  1.6893997 ,  1.6893997 , ...,  1.2689056 ,
# ...

# %%
eof1 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOFmap1_SW.npy').to_xarray().to_array()
eof2 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOFmap2_SW.npy').to_xarray().to_array()
eof3 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOFmap3_SW.npy').to_xarray().to_array()
eof4 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOFmap4_SW.npy').to_xarray().to_array()
eof5 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOFmap5_SW.npy').to_xarray().to_array()

eof1 = eof1[0,:,:].rename({'variable':'mode'})
eof2 = eof2[0,:,:].rename({'variable':'mode'})
eof3 = eof3[0,:,:].rename({'variable':'mode'})
eof4 = eof4[0,:,:].rename({'variable':'mode'})
eof5 = eof5[0,:,:].rename({'variable':'mode'})

eofs = [eof1,eof2,eof3,eof4,eof5]

# %%
eofs_combined = xr.combine_nested(eofs, concat_dim='eofs')
#eofs_combined

# %%
pc1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOF1pc_SW.npy')
pc2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOF2pc_SW.npy')
pc3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOF3pc_SW.npy')
pc4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOF4pc_SW.npy')
pc5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOF5pc_SW.npy')

PC_df = pd.DataFrame(pc1)
PC_df['pc1'] = pc1
PC_df['pc2'] = pc2
PC_df['pc3'] = pc3
PC_df['pc4'] = pc4
PC_df['pc5'] = pc5
PC_df = PC_df.drop(labels = 0, axis=1)
#PC_df

PC_df
# Out:
#           pc1       pc2       pc3       pc4       pc5
# 0    2.047448 -1.880354  0.695999  0.411820  1.125474
# 1    0.089597  0.496123  0.467096  1.178996 -0.048062
# 2    0.116893 -1.046918  0.690331  0.520984 -0.466149
# 3    0.185766 -0.481640 -1.690326  1.516757 -1.070102
# 4    0.715678 -2.260945  0.754597  0.866218  0.442685
# ..        ...       ...       ...       ...       ...
# 97   0.171422  1.157356  1.041254  0.640260  0.379373
# 98  -1.242337  0.038289  0.261865 -0.553909 -1.030117
# 99  -0.690952  0.455630  0.653965  0.037837  0.280628
# 100  0.174499  0.459449  1.376661  0.565957  1.431853
# 101 -1.983235  0.545524  0.910201  0.150772 -1.478715
#
# [102 rows x 5 columns]

# %%
pc1_official = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/official_EOF1pc_SW.npy')
pc2_official = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/official_EOF2pc_SW.npy')
pc3_official = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/official_EOF3pc_SW.npy')
pc4_official = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/official_EOF4pc_SW.npy')
pc5_official = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/official_EOF5pc_SW.npy')

pc1_p1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/p1_EOF1pc_SW.npy')
pc2_p1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/p1_EOF2pc_SW.npy')
pc3_p1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/p1_EOF3pc_SW.npy')
pc4_p1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/p1_EOF4pc_SW.npy')
pc5_p1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/files/npy/p1_EOF5pc_SW.npy')

# %%
PCs = [0]*102
for i in range(0,102,1):
    tmp = PC_df.iloc[i].values
    PCs[i] = tmp

PCs
# Out:
# [array([ 2.0474484 , -1.8803537 ,  0.6959992 ,  0.41181964,  1.1254739 ],
#        dtype=float32),
#  array([ 0.08959693,  0.4961233 ,  0.46709573,  1.1789958 , -0.04806199],
#        dtype=float32),
#  array([ 0.11689255, -1.0469179 ,  0.690331  ,  0.52098364, -0.46614897],
#        dtype=float32),
#  array([ 0.18576612, -0.48164007, -1.6903259 ,  1.5167572 , -1.0701017 ],
#        dtype=float32),
#  array([ 0.7156776, -2.2609448,  0.7545966,  0.8662176,  0.442685 ],
#        dtype=float32),
#  array([-0.20384167, -0.46242234,  1.20255   ,  0.05924474, -0.01504447],
#        dtype=float32),
#  array([-0.18986619, -0.7870216 , -0.88251007,  0.32856923,  1.699771  ],
#        dtype=float32),
#  array([-1.3129662 ,  0.14457382, -0.32069314, -0.17164196, -0.28508827],
#        dtype=float32),
#  array([-1.2997153 , -0.45352858, -0.947408  , -0.43291602,  0.6790156 ],
#        dtype=float32),
#  array([-0.4209844 ,  1.4569099 , -0.9148581 ,  0.7378951 ,  0.37586838],
# ...

# %% [markdown]
# # Trouver Beta : Multi-Linear Regression
#
# U_ens x Beta = Lambda_ens

# %%
# Set the X and Y : Y = f(X)
X = PCs
#y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/files/npy/PPE2_EOF3pc_N.npy")
y = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/files/npy/Net_feedbacks.npy")
param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/files/npy/LHS_paramNames.npy")

# %%
# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, y)

print('Intercept: \n', regr.intercept_)
print('Coefficients: \n', regr.coef_)
print('Score: \n', regr.score(X, y))
# Out:
# Intercept:
#  -1.3653505
# Coefficients:
#  [ 0.09895604 -0.05809337 -0.02578742 -0.03705013 -0.00538544]
# Score:
#  0.38462982651130306

# %%
Coeffs =regr.coef_
Coeffs
#Coeffs_sorted = Coeffs.sort_values()
#Coeffs_sorted
# Out:
# array([ 0.09895604, -0.05809337, -0.02578742, -0.03705013, -0.00538544],
#       dtype=float32)

# %%
# Let's write the equation : 
X_df = pd.DataFrame(data=X)
R = regr.intercept_

N=len(X_df.values)
tmp = [0]*N
y_eq = [0]*N
i=0
Ycpt=0
while i<N:
    tmp[i] = Coeffs*X_df.iloc[i]
    y_eq[i] = tmp[i].sum()+R
    i+=1
    
len(y_eq)
# Out:
# 102

# %%
nb_p_list = ['p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412',
                    'p414','p416',
                    'p413','p419','p424','p426','p428','p421','p423',
                    'p425','p427','p429','p430','p436','p438','p431','p433',
                    'p442','p446','p443','p445','p447',
                    'p452','p454','p456','p458','p457','p459',
                    'p460','p465','p467','p469',
                    'p470','p471']

y_true = y

DFYeq = pd.DataFrame([y_true, y_eq], index=['y_true', 'y_eq']).transpose()
DFYeq['members'] = nb_p_list
DFYeq['members_0'] = range(0,102,1)
#DF=DFYeq.sort_values(by='y_true')
DFYeq
# Out:
#        y_true      y_eq members  members_0
# 0   -0.789073 -1.092774    p311          0
# 1   -1.666454 -1.440774    p312          1
# 2   -1.214114 -1.327558    p314          2
# 3   -1.292415 -1.325832    p316          3
# 4   -0.756525 -1.217121    p317          4
# ..        ...       ...     ...        ...
# 97  -1.496774 -1.468238    p465         97
# 98  -1.571997 -1.471194    p467         98
# 99  -1.489540 -1.479971    p469         99
# 100 -1.430751 -1.438954    p470        100
# 101 -1.699042 -1.614389    p471        101
#
# [102 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

ax = plt.gca()
title = 'Multi Linear Regression model vs global netfeedbacks : all parameters'
DFYeq.plot(kind='scatter', x='y_true', y='y_eq', color='black', figsize=(10, 7), 
                     style='.', ax = ax)
#plt.plot(X_test, y_pred, color='blue', linewidth=1.0)

plt.xlabel('y_true')
plt.ylabel('y_pred')
plt.title(title)
plt.xlim(-2,0)
plt.ylim(-2,0)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/PPE_MultiLinReg_all.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Split the data into training/testing sets
X_train = y_true[:50].reshape(-1, 1)
X_test = y_true[50:].reshape(-1, 1)

# Split the targets into training/testing sets
y_train = y_eq[:50]#.reshape(-1, 1) 
y_test = y_eq[50:]#.reshape(-1, 1)
#y_train

# Create linear regression object
regr = linear_model.LinearRegression()

# Train the model using the training sets
regr.fit(X_train, y_train)

# Make predictions using the testing set
y_pred = regr.predict(X_test)

# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
#print('Mean squared error: %.2f'
#      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f'
      % r2_score(y_test, y_pred))

# Plot outputs
plt.scatter(X_test, y_test,  color='black')
plt.plot(X_test, y_pred, color='blue', linewidth=2.0)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# Coefficients:
#  [0.40095393]
# Coefficient of determination: 0.23

# %%
# Plot y_pred and y_test  
fig, ax = plt.subplots(figsize=(15,10))
ax = sns.lineplot(x="members_0", y="y_eq", data=DFYeq, color='navy',ax=ax)
ax = sns.lineplot(x="members_0", y="y_true", data=DFYeq, color='red',ax=ax)
plt.title('Multi Linear Regression model prediction of feedbacks : 30 parameters', fontsize=20)
plt.legend(['y_eq','y_true'],fontsize=15)
plt.xlabel('members of test sampling',fontsize=20)
plt.ylabel('TOA net feedbacks',fontsize=20)
plt.ylim(-2, -0.3)
ax.tick_params(axis='both', labelsize=15)

# %% [markdown]
# # Trouver U_obs : Reconstruciton des données
#
# X_ens = U_ens(pc) * v_ens(eof)
#
# Compute anomaly : X_obs = X_obs - SW_mean_ens
#
# X_obs = U_obs * v_ens
#
# U_obs = X_obs * inv(v_ens)

# %% [markdown]
# ## Get the CERES datatset

# %%
def load_monthly_clim(path, filename, variables) :
    
    file = xr.open_mfdataset(path+filename,combine='by_coords')
    df=file[variables].to_dataframe()
    
    # Compute Climatological Annual Cycle :
    df1=df.reset_index(level=['time', 'lat', 'lon'])
    df1['month']=pd.DatetimeIndex(df1['time']).month # time in years
    df_mean=df1.groupby(['month', 'lat', 'lon']).mean()
    
    return df_mean

# %%
path_observation = '/data/home/globc/peatier/obs_data/'
filename = 'CERES_EBAF-TOA_Ed4.1_Subset_200003-201910_regrid.nc'
    
# Load data and compute Annual Cycle :
file = xr.open_mfdataset(path_observation+filename,combine='by_coords')
#file
variables = ['toa_sw_all_mon','toa_lw_all_mon', 'toa_net_all_mon']
df_obs = load_monthly_clim(path_observation, filename, variables)
df_obs
# Out:
#                             toa_sw_all_mon  toa_lw_all_mon  toa_net_all_mon
# month lat        lon
# 1     -88.927735 0.00000        344.953522      189.246185       -38.599289
#                  1.40625        344.953522      189.246185       -38.599289
#                  2.81250        344.953522      189.246185       -38.599289
#                  4.21875        344.992493      189.144440       -38.531315
#                  5.62500        345.007721      189.104630       -38.504715
# ...                                    ...             ...              ...
# 12     88.927735 352.96875        0.000000      171.476639      -171.476639
#                  354.37500        0.000000      171.476639      -171.476639
#                  355.78125        0.000000      171.500351      -171.500351
#                  357.18750        0.000000      171.560974      -171.560974
#                  358.59375        0.000000      171.560974      -171.560974
#
# [393216 rows x 3 columns]

# %%
obs = df_obs.groupby(['lat','lon']).mean().to_xarray()
obs
# Out:
# <xarray.Dataset>
# Dimensions:          (lat: 128, lon: 256)
# Coordinates:
#   * lat              (lat) float64 -88.93 -87.54 -86.14 ... 86.14 87.54 88.93
#   * lon              (lon) float64 0.0 1.406 2.812 4.219 ... 355.8 357.2 358.6
# Data variables:
#     toa_sw_all_mon   (lat, lon) float32 121.35958 121.35958 ... 103.85324
#     toa_lw_all_mon   (lat, lon) float32 142.8201 142.8201 ... 194.14125
#     toa_net_all_mon  (lat, lon) float32 -91.40278 -91.40278 ... -126.49493

# %% [markdown]
# ## Compute Anomaly

# %%
X_obs = obs['toa_sw_all_mon'] - SW_mean
X_obs
# Out:
# <xarray.DataArray (lat: 128, lon: 256)>
# array([[ -5.4103622,  -5.4103622,  -5.4103622, ...,  -5.4308243,
#          -5.4103622,  -5.4103622],
#        [ -1.431694 ,  -1.431694 ,  -1.431694 , ...,  -1.4539948,
#          -1.431694 ,  -1.431694 ],
#        [ -5.1653748,  -5.1653748,  -5.1653748, ...,  -5.2844696,
#          -5.1653748,  -5.1653748],
#        ...,
#        [-11.791405 , -11.791405 , -11.791405 , ..., -11.257378 ,
#         -11.791405 , -11.791405 ],
#        [-11.715775 , -11.715775 , -11.715775 , ..., -11.670265 ,
#         -11.715775 , -11.715775 ],
#        [-11.938881 , -11.938881 , -11.938881 , ..., -11.937378 ,
#         -11.938881 , -11.938881 ]], dtype=float32)
# Coordinates:
#   * lat      (lat) float64 -88.93 -87.54 -86.14 -84.74 ... 86.14 87.54 88.93
#   * lon      (lon) float64 0.0 1.406 2.812 4.219 ... 354.4 355.8 357.2 358.6
#     mode     <U7 'SW_mean'

# %% [markdown]
# ## Trouver U_obs

# %%
PCs = PC_df.to_xarray().to_array()
PCs
# Out:
# <xarray.DataArray (variable: 5, index: 102)>
# array([[ 2.04744840e+00,  8.95969346e-02,  1.16892546e-01,
#          1.85766116e-01,  7.15677619e-01, -2.03841671e-01,
#         -1.89866185e-01, -1.31296623e+00, -1.29971528e+00,
#         -4.20984387e-01, -9.30992782e-01,  6.28530383e-01,
#          5.79328060e-01,  4.30394560e-01, -1.51702702e-01,
#          5.90502679e-01, -2.00333416e-01, -1.73922372e+00,
#         -4.29312587e-01,  5.68803549e-01, -5.20754099e-01,
#          2.29457125e-01, -3.42221111e-01, -1.88630414e+00,
#          2.28427339e+00, -6.44246280e-01,  9.99127865e-01,
#         -1.79691482e+00,  5.17098248e-01,  4.12791707e-02,
#         -8.54181275e-02, -2.20953226e-01, -2.27060854e-01,
#         -4.05052572e-01,  1.86124951e-01, -9.22662437e-01,
#          5.76971471e-01, -7.72975326e-01, -1.38794279e+00,
#          1.93738413e+00,  6.24164581e-01,  2.64284277e+00,
#          1.17836809e+00,  1.11102760e+00,  1.96634269e+00,
# ...

# %%
X_ens = eof1*PCs[0]+eof2*PCs[1]+eof3*PCs[2]+eof4*PCs[3]+eof5*PCs[4]
#X_ens

# %%
X_ens_bis = np.dot(eofs_combined.transpose(),PCs)
X_ens_bis = xr.DataArray(X_ens_bis, dims=['lon','lat','index'])
X_ens_bis
# Out:
# <xarray.DataArray (lon: 256, lat: 128, index: 102)>
# array([[[-0.08756807, -0.10735533,  0.09681569, ...,  0.33108854,
#           0.39065456,  0.49940532],
#         [-0.05309536,  0.31255051,  0.08695421, ...,  0.37520605,
#           0.6893799 ,  0.3973984 ],
#         [-0.13562241,  0.11620404,  0.03103527, ...,  0.17693466,
#           0.24837063,  0.28707004],
#         ...,
#         [ 1.3842391 , -0.20871185,  0.38886213, ..., -0.6446038 ,
#          -0.49758276, -1.0022619 ],
#         [ 1.604886  , -0.25130844,  0.56084657, ..., -0.77139336,
#          -0.69139653, -1.0369016 ],
#         [ 1.3857127 ,  0.0591877 ,  0.7341521 , ..., -0.71385056,
#          -0.6972443 , -0.635515  ]],
#
#        [[-0.08756807, -0.10735533,  0.09681569, ...,  0.33108854,
#           0.39065456,  0.49940532],
#         [-0.05309536,  0.31255051,  0.08695421, ...,  0.37520605,
#           0.6893799 ,  0.3973984 ],
#         [-0.13562241,  0.11620404,  0.03103527, ...,  0.17693466,
# ...

# %%
eofs_inv = np.linalg.pinv(eofs_combined.transpose())
#eofs_inv = xr.DataArray(eofs_inv, dims=['eofs','lon','lat'])
eofs_inv
# Out:
# array([[[ 9.95205410e-05, -2.01782605e-04,  7.19191521e-05, ...,
#           6.70459063e-04,  7.32128043e-04,  6.42226310e-04],
#         [ 1.58580457e-04, -4.20564204e-04,  1.85125973e-04, ...,
#           1.37181836e-03,  1.51575671e-03,  1.46462384e-03],
#         [ 4.28988831e-04, -8.54313985e-05,  1.50993597e-04, ...,
#           6.35869161e-04,  6.71775488e-04,  4.28409519e-04],
#         [-1.15789881e-03,  4.68976243e-04, -8.86348716e-05, ...,
#          -9.91045847e-04, -9.62815946e-04,  2.53830862e-04],
#         [ 2.44234136e-04,  1.03246944e-03, -1.64161829e-04, ...,
#          -2.60828109e-03, -3.16742365e-03, -3.69101856e-03]],
#
#        [[ 6.24684908e-05, -2.08302648e-04,  8.25459138e-05, ...,
#           7.33522233e-04,  8.07532109e-04,  7.66611483e-04],
#         [ 1.26472660e-04, -4.40467265e-04,  2.05794029e-04, ...,
#           1.49680825e-03,  1.65431830e-03,  1.64540892e-03],
#         [ 3.79437901e-04, -8.28837074e-05,  1.59478135e-04, ...,
# ...

# %%
U_ens = np.dot(eofs_inv,X_ens.transpose('lon','lat','index'))
#U_ens = U_ens.mean(dim=['lat','lon'])#.transpose()
U_ens
# Out:
# array([[[[ 2.04744840e+00,  8.95969644e-02,  1.16892532e-01, ...,
#           -6.90952361e-01,  1.74499139e-01, -1.98323524e+00],
#          [ 2.11762619e+00,  2.20574923e-02,  1.07461095e-01, ...,
#           -7.11086094e-01,  1.58146590e-01, -2.06485987e+00],
#          [ 2.08567905e+00, -4.39279713e-02,  3.81879248e-02, ...,
#           -7.29347646e-01,  1.15755670e-01, -2.14352918e+00],
#          ...,
#          [ 2.16033792e+00,  1.95936024e-01,  1.91608012e-01, ...,
#           -6.95568919e-01,  2.45959193e-01, -1.99441063e+00],
#          [ 2.16169667e+00,  1.75431490e-01,  1.73516646e-01, ...,
#           -6.94679677e-01,  2.50781775e-01, -2.01141143e+00],
#          [ 2.13092637e+00,  1.33285657e-01,  1.50025815e-01, ...,
#           -6.92407846e-01,  2.27688327e-01, -2.01315546e+00]],
#
#         [[-1.88035393e+00,  4.96123374e-01, -1.04691792e+00, ...,
#            4.55629915e-01,  4.59448904e-01,  5.45524061e-01],
# ...

# %%
U_ens = xr.DataArray(U_ens, dims=['lon','eofs','lon2', 'index'])
#U_ens_avg = U_ens.mean(dim=['lon','lon2']).transpose()
U_ens_avg = U_ens[0,:,0,:].transpose()
U_ens_avg
# Out:
# <xarray.DataArray (index: 102, eofs: 5)>
# array([[ 2.04744840e+00, -1.88035393e+00,  6.95999146e-01,
#          4.11819845e-01,  1.12547386e+00],
#        [ 8.95969644e-02,  4.96123374e-01,  4.67095762e-01,
#          1.17899585e+00, -4.80619781e-02],
#        [ 1.16892532e-01, -1.04691792e+00,  6.90330923e-01,
#          5.20983577e-01, -4.66148913e-01],
#        [ 1.85766116e-01, -4.81640071e-01, -1.69032586e+00,
#          1.51675725e+00, -1.07010174e+00],
#        [ 7.15677619e-01, -2.26094484e+00,  7.54596591e-01,
#          8.66217613e-01,  4.42685008e-01],
#        [-2.03841671e-01, -4.62422341e-01,  1.20255005e+00,
#          5.92447519e-02, -1.50444768e-02],
#        [-1.89866140e-01, -7.87021518e-01, -8.82510006e-01,
#          3.28569233e-01,  1.69977093e+00],
#        [-1.31296611e+00,  1.44574016e-01, -3.20693046e-01,
#         -1.71642184e-01, -2.85088420e-01],
#        [-1.29971528e+00, -4.53528613e-01, -9.47408020e-01,
#         -4.32916045e-01,  6.79015458e-01],
# ...

# %%
df = PC_df
df["pc1_bis"] = U_ens_avg[:,0]
df["pc2_bis"] = U_ens_avg[:,1]
df["pc3_bis"] = U_ens_avg[:,2]
df["pc4_bis"] = U_ens_avg[:,3]
df["pc5_bis"] = U_ens_avg[:,4]
df
# Out:
#           pc1       pc2       pc3       pc4       pc5   pc1_bis   pc2_bis  \
# 0    2.047448 -1.880354  0.695999  0.411820  1.125474  2.047448 -1.880354
# 1    0.089597  0.496123  0.467096  1.178996 -0.048062  0.089597  0.496123
# 2    0.116893 -1.046918  0.690331  0.520984 -0.466149  0.116893 -1.046918
# 3    0.185766 -0.481640 -1.690326  1.516757 -1.070102  0.185766 -0.481640
# 4    0.715678 -2.260945  0.754597  0.866218  0.442685  0.715678 -2.260945
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.171422  1.157356  1.041254  0.640260  0.379373  0.171422  1.157356
# 98  -1.242337  0.038289  0.261865 -0.553909 -1.030117 -1.242337  0.038289
# 99  -0.690952  0.455630  0.653965  0.037837  0.280628 -0.690952  0.455630
# 100  0.174499  0.459449  1.376661  0.565957  1.431853  0.174499  0.459449
# 101 -1.983235  0.545524  0.910201  0.150772 -1.478715 -1.983235  0.545524
#
#       pc3_bis   pc4_bis   pc5_bis
# 0    0.695999  0.411820  1.125474
# ...

# %%
ax = plt.gca()
title = 'PC1 SW TOA fluxes'

df.plot(kind='scatter', x='pc1', y='pc1_bis', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)
#plt.xlabel('Feedbacks (W.m^2)', fontsize=18)
#plt.ylabel('PC1 SW TOA fluxes', fontsize=18)
#plt.legend(['models', 'CERES dataset'])
plt.title(title, fontsize=22)
plt.ylim(-2.0,2.0)
plt.xlim(-2.0,2.0)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
ax = plt.gca()
title = 'PC2 SW TOA fluxes'

df.plot(kind='scatter', x='pc2', y='pc2_bis', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)
#plt.xlabel('Feedbacks (W.m^2)', fontsize=18)
#plt.ylabel('PC1 SW TOA fluxes', fontsize=18)
#plt.legend(['models', 'CERES dataset'])
plt.title(title, fontsize=22)
plt.ylim(-10,10)
plt.xlim(-10,10)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
ax = plt.gca()
title = 'PC3 SW TOA fluxes'

df.plot(kind='scatter', x='pc3', y='pc3_bis', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)
#plt.xlabel('Feedbacks (W.m^2)', fontsize=18)
#plt.ylabel('PC1 SW TOA fluxes', fontsize=18)
#plt.legend(['models', 'CERES dataset'])
plt.title(title, fontsize=22)
plt.ylim(-10,10)
plt.xlim(-10,10)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
X_obs_bis = X_obs.expand_dims(dim={'dummy':range(0,102,1)})
X_obs_bis
# Out:
# <xarray.DataArray (dummy: 102, lat: 128, lon: 256)>
# array([[[ -5.4103622,  -5.4103622,  -5.4103622, ...,  -5.4308243,
#           -5.4103622,  -5.4103622],
#         [ -1.431694 ,  -1.431694 ,  -1.431694 , ...,  -1.4539948,
#           -1.431694 ,  -1.431694 ],
#         [ -5.1653748,  -5.1653748,  -5.1653748, ...,  -5.2844696,
#           -5.1653748,  -5.1653748],
#         ...,
#         [-11.791405 , -11.791405 , -11.791405 , ..., -11.257378 ,
#          -11.791405 , -11.791405 ],
#         [-11.715775 , -11.715775 , -11.715775 , ..., -11.670265 ,
#          -11.715775 , -11.715775 ],
#         [-11.938881 , -11.938881 , -11.938881 , ..., -11.937378 ,
#          -11.938881 , -11.938881 ]],
#
#        [[ -5.4103622,  -5.4103622,  -5.4103622, ...,  -5.4308243,
#           -5.4103622,  -5.4103622],
#         [ -1.431694 ,  -1.431694 ,  -1.431694 , ...,  -1.4539948,
#           -1.431694 ,  -1.431694 ],
#         [ -5.1653748,  -5.1653748,  -5.1653748, ...,  -5.2844696,
# ...

# %%
U_obs = np.dot(eofs_inv,X_obs_bis.transpose('lon','lat', 'dummy'))
#U_ens = U_ens.mean(dim=['lat','lon'])#.transpose()
U_obs
# Out:
# array([[[[-0.48952103, -0.48952103, -0.48952103, ..., -0.48952103,
#           -0.48952103, -0.48952103],
#          [-0.815118  , -0.815118  , -0.815118  , ..., -0.815118  ,
#           -0.815118  , -0.815118  ],
#          [-0.8326248 , -0.8326248 , -0.8326248 , ..., -0.8326248 ,
#           -0.8326248 , -0.8326248 ],
#          ...,
#          [-0.7597671 , -0.7597671 , -0.7597671 , ..., -0.7597671 ,
#           -0.7597671 , -0.7597671 ],
#          [-0.61824566, -0.61824566, -0.61824566, ..., -0.61824566,
#           -0.61824566, -0.61824566],
#          [-0.62834096, -0.62834096, -0.62834096, ..., -0.62834096,
#           -0.62834096, -0.62834096]],
#
#         [[-3.1625543 , -3.1625543 , -3.1625543 , ..., -3.1625543 ,
#           -3.1625543 , -3.1625543 ],
#          [-4.067488  , -4.067488  , -4.067488  , ..., -4.067488  ,
#           -4.067488  , -4.067488  ],
#          [-4.406661  , -4.406661  , -4.406661  , ..., -4.406661  ,
#           -4.406661  , -4.406661  ],
# ...

# %%
U_obs = xr.DataArray(U_obs, dims=['lon','eofs','lon2', 'dummy'])
U_obs_avg = U_obs[0,:,0,0].transpose()
U_obs_avg
# Out:
# <xarray.DataArray (eofs: 5)>
# array([-0.48952103, -3.1625543 ,  0.57233983,  0.7200181 ,  1.3985839 ],
#       dtype=float32)
# Dimensions without coordinates: eofs

# %% [markdown]
# ## Trouver les feedbacks des observations

# %%
Beta = Coeffs
Beta
# Out:
# array([ 0.09895604, -0.05809337, -0.02578742, -0.03705013, -0.00538544],
#       dtype=float32)

# %%
Lambda_obs = Beta*U_obs_avg
Lambda_obs = Lambda_obs.sum()
Lambda_obs
# Out:
# <xarray.DataArray ()>
# array(0.08631442, dtype=float32)

# %%
Lambda_obs = 0
for i in range(0,5,1) :
    tmp = Beta[i]*U_obs_avg[i]
    Lambda_obs = Lambda_obs + tmp

Lambda_obs
# Out:
# <xarray.DataArray ()>
# array(0.08631443)

# %% [markdown]
# # Create Plot

# %%
official_NetFdbck = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/files/npy/Net_feedbacks_official.npy")
p1_NetFdbck = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/files/npy/Net_feedbacks_p1.npy")

# %%
df = PC_df
df['Fdbck'] = y

# %%
plt.subplots(figsize=(8,20))

#########################
plt.subplot(311)
ax0 = plt.gca()

title = 'PC1 SW TOA fluxes vs Net Feedbacks'

df.plot(kind='scatter', x='Fdbck', y='pc1', color='black',  
                     marker="o", ax = ax0)
plt.hlines(U_obs_avg[0],xmin = -2.0,xmax = 1.0, colors='green', 
           linestyles='solid')
plt.hlines(pc1_official,xmin = -2.0,xmax = 1.0, colors='blue', 
           linestyles='solid')
#plt.hlines(pc1_p1,xmin = -2.0,xmax = 1.0, colors='coral', 
#           linestyles='solid')
plt.vlines(official_NetFdbck, ymin = -10,ymax = 10, colors='blue', 
           linestyles='solid')
#plt.vlines(p1_NetFdbck, ymin = -10,ymax = 10, colors='coral', 
#           linestyles='solid')

plt.xlabel('Net feedbacks (W.m^2)', fontsize=18)
plt.ylabel('PC1 SW TOA fluxes', fontsize=18)
plt.legend(['models', 'CERES dataset', 'default model'])
plt.title(title, fontsize=18)
plt.ylim(-10,10)
plt.xlim(-0.5,-2.0)

#########################
plt.subplot(312)
ax1 = plt.gca()

title = 'PC2 SW TOA fluxes vs Net Feedbacks'

df.plot(kind='scatter', x='Fdbck', y='pc2', color='black', 
                     marker="o", ax = ax1)
plt.hlines(U_obs_avg[1],xmin = -2.0,xmax = 1.0, colors='green', 
           linestyles='solid')
plt.hlines(pc2_official,xmin = -2.0,xmax = 1.0, colors='blue', 
           linestyles='solid')
#plt.hlines(pc2_p1,xmin = -2.0,xmax = 1.0, colors='coral', 
#           linestyles='solid')
plt.vlines(official_NetFdbck, ymin = -10,ymax = 10, colors='blue', 
           linestyles='solid')
#plt.vlines(p1_NetFdbck, ymin = -10,ymax = 10, colors='coral', 
#           linestyles='solid')

plt.xlabel('Net feedbacks (W.m^2)', fontsize=18)
plt.ylabel('PC2 SW TOA fluxes', fontsize=18)
plt.legend(['models', 'CERES dataset', 'default model'])
plt.title(title, fontsize=18)
plt.ylim(-10,10)
plt.xlim(-0.5,-2.0)

#########################
plt.subplot(313)
ax2 = plt.gca()

title = 'PC3 SW TOA fluxes vs Net Feedbacks'

df.plot(kind='scatter', x='Fdbck', y='pc3', color='black',  
                     marker="o", ax = ax2)
plt.hlines(U_obs_avg[2],xmin = -2.0,xmax = 1.0, colors='green', 
           linestyles='solid')
plt.hlines(pc3_official,xmin = -2.0,xmax = 1.0, colors='blue', 
           linestyles='solid')
#plt.hlines(pc3_p1,xmin = -2.0,xmax = 1.0, colors='coral', 
#           linestyles='solid')
plt.vlines(official_NetFdbck, ymin = -10,ymax = 10, colors='blue', 
           linestyles='solid')
#plt.vlines(p1_NetFdbck, ymin = -10,ymax = 10, colors='coral', 
#           linestyles='solid')

plt.xlabel('Net feedbacks (W.m^2)', fontsize=18)
plt.ylabel('PC3 SW TOA fluxes', fontsize=18)
plt.legend(['models', 'CERES dataset', 'default model'])
plt.title(title, fontsize=18)
plt.ylim(-10,10)
plt.xlim(-0.5,-2.0)

#########################

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
official_Fdbck_SW = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/files/npy/SW_feedbacks_official.npy")
p1_Fdbck_SW = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/files/npy/SW_feedbacks_p1.npy")
Fdbck_SW =  np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/files/npy/SW_feedbacks.npy")

# %%
df['Fdbck_SW'] = Fdbck_SW
df
# Out:
#           pc1       pc2       pc3       pc4       pc5   pc1_bis   pc2_bis  \
# 0    2.047448 -1.880354  0.695999  0.411820  1.125474  2.047448 -1.880354
# 1    0.089597  0.496123  0.467096  1.178996 -0.048062  0.089597  0.496123
# 2    0.116893 -1.046918  0.690331  0.520984 -0.466149  0.116893 -1.046918
# 3    0.185766 -0.481640 -1.690326  1.516757 -1.070102  0.185766 -0.481640
# 4    0.715678 -2.260945  0.754597  0.866218  0.442685  0.715678 -2.260945
# ..        ...       ...       ...       ...       ...       ...       ...
# 97   0.171422  1.157356  1.041254  0.640260  0.379373  0.171422  1.157356
# 98  -1.242337  0.038289  0.261865 -0.553909 -1.030117 -1.242337  0.038289
# 99  -0.690952  0.455630  0.653965  0.037837  0.280628 -0.690952  0.455630
# 100  0.174499  0.459449  1.376661  0.565957  1.431853  0.174499  0.459449
# 101 -1.983235  0.545524  0.910201  0.150772 -1.478715 -1.983235  0.545524
#
#       pc3_bis   pc4_bis   pc5_bis     Fdbck  Fdbck_SW
# ...

# %%
plt.subplots(figsize=(8,20))

#########################
plt.subplot(311)
ax0 = plt.gca()

title = 'PC1 SW TOA fluxes vs SW Feedbacks'

df.plot(kind='scatter', x='Fdbck_SW', y='pc1', color='black',  
                     marker="o", ax = ax0)
plt.hlines(U_obs_avg[0],xmin = -2.0,xmax = 1.0, colors='green', 
           linestyles='solid')
plt.hlines(pc1_official,xmin = -2.0,xmax = 1.0, colors='blue', 
           linestyles='solid')
#plt.hlines(pc1_p1,xmin = -2.0,xmax = 1.0, colors='coral', 
#           linestyles='solid')
plt.vlines(official_Fdbck_SW, ymin = -10,ymax = 10, colors='blue', 
           linestyles='solid')
#plt.vlines(p1_NetFdbck, ymin = -10,ymax = 10, colors='coral', 
#           linestyles='solid')

plt.xlabel('SW feedbacks (W.m^2)', fontsize=18)
plt.ylabel('PC1 SW TOA fluxes', fontsize=18)
plt.legend(['models', 'CERES dataset', 'default model'])
plt.title(title, fontsize=18)
plt.ylim(-10,10)
plt.xlim(0.0,-1.6)

#########################
plt.subplot(312)
ax1 = plt.gca()

title = 'PC2 SW TOA fluxes vs SW Feedbacks'

df.plot(kind='scatter', x='Fdbck_SW', y='pc2', color='black', 
                     marker="o", ax = ax1)
plt.hlines(U_obs_avg[1],xmin = -2.0,xmax = 1.0, colors='green', 
           linestyles='solid')
plt.hlines(pc2_official,xmin = -2.0,xmax = 1.0, colors='blue', 
           linestyles='solid')
#plt.hlines(pc2_p1,xmin = -2.0,xmax = 1.0, colors='coral', 
#           linestyles='solid')
plt.vlines(official_Fdbck_SW, ymin = -10,ymax = 10, colors='blue', 
           linestyles='solid')
#plt.vlines(p1_NetFdbck, ymin = -10,ymax = 10, colors='coral', 
#           linestyles='solid')

plt.xlabel('SW feedbacks (W.m^2)', fontsize=18)
plt.ylabel('PC2 SW TOA fluxes', fontsize=18)
plt.legend(['models', 'CERES dataset', 'default model'])
plt.title(title, fontsize=18)
plt.ylim(-10,10)
plt.xlim(0.0,-1.6)

#########################
plt.subplot(313)
ax2 = plt.gca()

title = 'PC3 SW TOA fluxes vs SW Feedbacks'

df.plot(kind='scatter', x='Fdbck_SW', y='pc3', color='black',  
                     marker="o", ax = ax2)
plt.hlines(U_obs_avg[2],xmin = -2.0,xmax = 1.0, colors='green', 
           linestyles='solid')
plt.hlines(pc3_official,xmin = -2.0,xmax = 1.0, colors='blue', 
           linestyles='solid')
#plt.hlines(pc3_p1,xmin = -2.0,xmax = 1.0, colors='coral', 
#           linestyles='solid')
plt.vlines(official_Fdbck_SW, ymin = -10,ymax = 10, colors='blue', 
           linestyles='solid')
#plt.vlines(p1_NetFdbck, ymin = -10,ymax = 10, colors='coral', 
#           linestyles='solid')

plt.xlabel('SW feedbacks (W.m^2)', fontsize=18)
plt.ylabel('PC3 SW TOA fluxes', fontsize=18)
plt.legend(['models', 'CERES dataset', 'default model'])
plt.title(title, fontsize=18)
plt.ylim(-10,10)
plt.xlim(0.0,-1.6)

#########################

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

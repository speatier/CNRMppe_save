# %% [markdown]
# # Importe modules

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas
from eofs.xarray import Eof
from eofs.multivariate.standard import MultivariateEof

# Plotting modules 
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import BoundaryNorm

# %% [markdown]
# # Functions definition

# %%
import sys
sys.path.append('/data/home/globc/peatier/CNRMppe')
import Fonctions
from Fonctions import get_wavg_budget_df
from Fonctions import wavg 
from Fonctions import plotlines_Xdf
from Fonctions import plotlines_1df
from Fonctions import Deltas_Lambda
from Fonctions import get_3D_budget_xarr
from Fonctions import get_3D_xarr
from Fonctions import get_3D_SW_xarr
from Fonctions import get_3D_LW_xarr

# %% [markdown]
# # Récupérer U_obs

# %%
U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_LW.npy')
U_obs
# Out:
# array([-0.90530056,  2.34117   , -1.7348833 ,  1.7361926 ,  0.22081728],
#       dtype=float32)

# %%
pc1_obs = U_obs[0]
pc2_obs = U_obs[1]
pc3_obs = U_obs[2]
pc4_obs = U_obs[3]
pc5_obs = U_obs[4]

# %% [markdown]
# # official, membre p1

# %% [markdown]
# # PPE

# %%
eof1 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOFmap1_LW.npy').to_xarray().to_array()
eof2 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOFmap2_LW.npy').to_xarray().to_array()
eof3 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOFmap3_LW.npy').to_xarray().to_array()
eof4 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOFmap4_LW.npy').to_xarray().to_array()
eof5 = pd.read_pickle('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOFmap5_LW.npy').to_xarray().to_array()

eof1 = eof1[0,:,:].rename({'variable':'mode'})
eof2 = eof2[0,:,:].rename({'variable':'mode'})
eof3 = eof3[0,:,:].rename({'variable':'mode'})
eof4 = eof4[0,:,:].rename({'variable':'mode'})
eof5 = eof5[0,:,:].rename({'variable':'mode'})

# %%
pc1_PPE = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF1pc_LW.npy')
pc2_PPE = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF2pc_LW.npy')
pc3_PPE = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF3pc_LW.npy')
pc4_PPE = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF4pc_LW.npy')
pc5_PPE = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF5pc_LW.npy')

PC_df_PPE = pd.DataFrame(pc1_PPE)
PC_df_PPE['pc1'] = pc1_PPE
PC_df_PPE['pc2'] = pc2_PPE
PC_df_PPE['pc3'] = pc3_PPE
PC_df_PPE['pc4'] = pc4_PPE
PC_df_PPE['pc5'] = pc5_PPE
PC_df_PPE = PC_df_PPE.drop(labels = 0, axis=1)
PC_df_PPE
# Out:
#           pc1       pc2       pc3       pc4       pc5
# 0   -0.739219  0.068012  0.231087 -0.114967 -2.073620
# 1    0.336901 -0.589367  1.022992  0.410326  0.460474
# 2    1.772028  0.713022  0.389880  0.341204 -0.621712
# 3    0.602520 -1.191535  1.601341 -0.169788  0.693402
# 4    0.675742 -0.056017 -0.160190  1.804740 -0.257126
# ..        ...       ...       ...       ...       ...
# 97  -0.303779 -0.121118  1.087760  0.318875  0.982107
# 98  -0.210095 -1.715702 -1.029760  1.346775  1.742032
# 99   0.184986 -0.692581 -0.455570  0.427989  0.221776
# 100  0.761945 -0.390530  0.032001  0.808282 -0.055405
# 101 -0.043378  1.843108 -1.143706 -0.705269  2.396010
#
# [102 rows x 5 columns]

# %% [markdown]
# ## Calcul de biais CERES

# %%
E_pc1 = []
E_pc2 = []
E_pc3 = []
E_pc4 = []
E_pc5 = []
E_tmp = []

for i in pc1_PPE:
    tmp = (i-pc1_obs)**2
    E_pc1.append(tmp)
    
for j in pc2_PPE:
    tmp = (j-pc2_obs)**2
    E_pc2.append(tmp)

for k in pc3_PPE:
    tmp = (k-pc3_obs)**2
    E_pc3.append(tmp)
    
for l in pc4_PPE:
    tmp = (l-pc4_obs)**2
    E_pc4.append(tmp)
    
for m in pc5_PPE:
    tmp = (m-pc5_obs)**2
    E_pc5.append(tmp)

for n in range(0,len(E_pc1),1) :    
    tmp = E_pc1[n]+E_pc2[n]+E_pc3[n]+E_pc4[n]+E_pc5[n]
    E_tmp.append(tmp)

    
E_PPE = sqrt(E_tmp)
    
    
E_PPE
# Out:
# array([4.21320574, 4.42180403, 4.12182283, 5.45344081, 3.31043581,
#        3.16701905, 4.9547053 , 3.75425397, 4.72200545, 4.63757487,
#        4.27399874, 5.70766908, 3.34232845, 4.30889126, 4.07744941,
#        3.5370038 , 3.21615701, 3.38310196, 3.93285436, 3.03293924,
#        4.33459168, 4.49783913, 2.72417105, 3.23451306, 2.5950956 ,
#        4.04763098, 2.93097573, 3.68496418, 4.14443844, 5.33522333,
#        3.79042939, 4.90257905, 2.6919032 , 3.83780357, 2.99853928,
#        4.1244076 , 4.68229675, 3.45336569, 3.29657748, 4.3301511 ,
#        4.02891724, 4.54036163, 4.81072823, 4.20973273, 5.20339167,
#        4.98375018, 4.51348467, 5.48404565, 5.05661955, 5.23003839,
#        4.1288197 , 2.28080301, 5.13618355, 5.34206199, 4.34580207,
#        4.25491491, 3.50610254, 4.92155551, 4.01331505, 4.05006624,
#        3.62221943, 3.89185255, 5.82744156, 3.9050971 , 3.46942194,
#        5.77871266, 3.95299974, 3.77375138, 3.22239679, 3.57003965,
# ...

# %% [markdown]
# # Multi-Linear Regression predictions

# %% [markdown]
# ## Import PCs and EOFs

# %%
pc1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof1_LW.npy')
pc2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof2_LW.npy')
pc3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof3_LW.npy')
pc4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof4_LW.npy')
pc5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof5_LW.npy')

PC_df = pd.DataFrame(pc1)
PC_df['pc1'] = pc1
PC_df['pc2'] = pc2
PC_df['pc3'] = pc3
PC_df['pc4'] = pc4
PC_df['pc5'] = pc5
PC_df = PC_df.drop(labels = 0, axis=1)
#PC_df

pc1 = PC_df['pc1'].to_xarray().rename({'index':'mode'})
pc2 = PC_df['pc2'].to_xarray().rename({'index':'mode'})
pc3 = PC_df['pc3'].to_xarray().rename({'index':'mode'})
pc4 = PC_df['pc4'].to_xarray().rename({'index':'mode'})
pc5 = PC_df['pc5'].to_xarray().rename({'index':'mode'})

# %%
pc1_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_validation_eof1_LW.npy')
pc2_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_validation_eof2_LW.npy')
pc3_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_validation_eof3_LW.npy')
pc4_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_validation_eof4_LW.npy')
pc5_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_validation_eof5_LW.npy')

PC_val_df = pd.DataFrame(pc1_val)
PC_val_df['pc1'] = pc1_val
PC_val_df['pc2'] = pc2_val
PC_val_df['pc3'] = pc3_val
PC_val_df['pc4'] = pc4_val
PC_val_df['pc5'] = pc5_val
PC_val_df = PC_val_df.drop(labels = 0, axis=1)
#PC_df

pc1_val = PC_val_df['pc1'].to_xarray().rename({'index':'mode'})
pc2_val = PC_val_df['pc2'].to_xarray().rename({'index':'mode'})
pc3_val = PC_val_df['pc3'].to_xarray().rename({'index':'mode'})
pc4_val = PC_val_df['pc4'].to_xarray().rename({'index':'mode'})
pc5_val = PC_val_df['pc5'].to_xarray().rename({'index':'mode'})

# %% [markdown]
# ## Calcul de biais CERES

# %%
E_pc1_val = []
E_pc2_val = []
E_pc3_val = []
E_pc4_val = []
E_pc5_val = []
E_tmp_val = []

for i in pc1_val:
    tmp = (i-pc1_obs)**2
    E_pc1_val.append(tmp)
    
for j in pc2_val:
    tmp = (j-pc2_obs)**2
    E_pc2_val.append(tmp)

for k in pc3_val:
    tmp = (k-pc3_obs)**2
    E_pc3_val.append(tmp)
    
for l in pc4_val:
    tmp = (l-pc4_obs)**2
    E_pc4_val.append(tmp)
    
for m in pc5_val:
    tmp = (m-pc5_obs)**2
    E_pc5_val.append(tmp)

for n in range(0,len(E_pc1_val),1) :    
    tmp = E_pc1_val[n]+E_pc2_val[n]+E_pc3_val[n]+E_pc4_val[n]+E_pc5_val[n]
    E_tmp_val.append(tmp)

    
E_multilinreg_val = sqrt(E_tmp_val)
    
    
E_multilinreg_val
# Out:
# array([3.81301509, 4.40184153, 4.14018973, 5.00391581, 3.66304995,
#        2.46241823, 4.23921193, 2.75397868, 4.26733273, 4.06746612,
#        4.12107163, 5.29009039, 4.12234887, 3.855789  , 4.50478476,
#        3.77237219, 4.04294442, 3.59588843, 3.95644395, 2.95921364,
#        4.47803469, 4.47368299, 2.98221816, 2.47206752, 2.9288388 ,
#        3.87166621, 2.85334596, 3.65060261, 3.88937462, 5.55381191,
#        3.52515156, 5.04939948, 3.02001154, 3.89720834, 2.65475577,
#        4.54323192, 4.18402878, 2.51527537, 2.92269639, 4.0486056 ,
#        3.93927563, 5.08921628, 4.61244459, 3.95236618, 4.61367574,
#        4.31913825, 4.28844185, 4.60642953, 4.10015823, 4.73047579,
#        3.96152256, 2.98088007, 5.3341674 , 5.2531064 , 4.49244807,
#        3.23676369, 3.65032718, 4.00948583, 4.00264255, 4.09994736,
#        2.5016638 , 3.7519165 , 5.25200792, 4.10161736, 3.30307725,
#        4.86966822, 4.04071948, 3.07952506, 3.71231866, 3.65268547,
# ...

# %%
E_pc1_pred = []
E_pc2_pred = []
E_pc3_pred = []
E_pc4_pred = []
E_pc5_pred = []
E_tmp_pred = []

for i in pc1:
    tmp = (i-pc1_obs)**2
    E_pc1_pred.append(tmp)
    
for j in pc2:
    tmp = (j-pc2_obs)**2
    E_pc2_pred.append(tmp)

for k in pc3:
    tmp = (k-pc3_obs)**2
    E_pc3_pred.append(tmp)
    
for l in pc4:
    tmp = (l-pc4_obs)**2
    E_pc4_pred.append(tmp)
    
for m in pc5:
    tmp = (m-pc5_obs)**2
    E_pc5_pred.append(tmp)

for n in range(0,len(E_pc1_pred),1) :    
    tmp = E_pc1_pred[n]+E_pc2_pred[n]+E_pc3_pred[n]+E_pc4_pred[n]+E_pc5_pred[n]
    E_tmp_pred.append(tmp)

    
E_multilinreg_pred = sqrt(E_tmp_pred)
    
    
E_multilinreg_pred
# Out:
# array([3.83770676, 4.63397706, 3.23687426, 5.93940076, 3.7916873 ,
#        2.40250971, 4.94405479, 3.86427953, 6.27169466, 5.11204996,
#        5.33813545, 3.42839378, 3.47480767, 5.03415094, 4.66913092,
#        3.67161521, 3.17547844, 5.49136197, 3.26626148, 2.3627937 ,
#        1.45866219, 3.33993572, 4.5932912 , 3.98156142, 3.34152659,
#        4.08421021, 3.04250569, 3.2647777 , 3.83099877, 3.69605102,
#        4.33289363, 5.14020098, 4.09823622, 2.79845944, 3.75473947,
#        3.32392294, 5.56249102, 5.87214077, 3.17991284, 0.85313571,
#        4.64706214, 2.10736757, 4.06686154, 3.18895557, 4.43792501,
#        4.77994113, 2.80599665, 3.09157404, 3.42580989, 3.26166204,
#        3.62540472, 3.21788887, 3.48881557, 3.15927363, 4.65633212,
#        3.67043665, 2.6021364 , 2.47479569, 4.13101133, 4.66167274,
#        5.54834046, 3.82067138, 3.96634189, 4.59145948, 3.92068662,
#        2.37557626, 2.72660713, 3.21045757, 3.38709401, 4.49740541,
# ...

# %%
pc1.shape
# Out:
# (1000,)

# %% [markdown]
# # LASSO predictions

# %%
pc1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_prediction_eof1_LW.npy')
pc2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_prediction_eof2_LW.npy')
pc3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_prediction_eof3_LW.npy')
pc4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_prediction_eof4_LW.npy')
pc5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_prediction_eof5_LW.npy')

PC_df = pd.DataFrame(pc1)
PC_df['pc1'] = pc1
PC_df['pc2'] = pc2
PC_df['pc3'] = pc3
PC_df['pc4'] = pc4
PC_df['pc5'] = pc5
PC_df = PC_df.drop(labels = 0, axis=1)
#PC_df

pc1 = PC_df['pc1'].to_xarray().rename({'index':'mode'})
pc2 = PC_df['pc2'].to_xarray().rename({'index':'mode'})
pc3 = PC_df['pc3'].to_xarray().rename({'index':'mode'})
pc4 = PC_df['pc4'].to_xarray().rename({'index':'mode'})
pc5 = PC_df['pc5'].to_xarray().rename({'index':'mode'})

# %%
pc1_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_validation_eof1_LW.npy')
pc2_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_validation_eof2_LW.npy')
pc3_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_validation_eof3_LW.npy')
pc4_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_validation_eof4_LW.npy')
pc5_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_validation_eof5_LW.npy')

PC_val_df_LASSO = pd.DataFrame(pc1_val)
PC_val_df_LASSO['pc1'] = pc1_val
PC_val_df_LASSO['pc2'] = pc2_val
PC_val_df_LASSO['pc3'] = pc3_val
PC_val_df_LASSO['pc4'] = pc4_val
PC_val_df_LASSO['pc5'] = pc5_val
PC_val_df_LASSO = PC_val_df_LASSO.drop(labels = 0, axis=1)
#PC_df

pc1_val = PC_val_df_LASSO['pc1'].to_xarray().rename({'index':'mode'})
pc2_val = PC_val_df_LASSO['pc2'].to_xarray().rename({'index':'mode'})
pc3_val = PC_val_df_LASSO['pc3'].to_xarray().rename({'index':'mode'})
pc4_val = PC_val_df_LASSO['pc4'].to_xarray().rename({'index':'mode'})
pc5_val = PC_val_df_LASSO['pc5'].to_xarray().rename({'index':'mode'})

# %% [markdown]
# ## Calcul de biais CERES

# %%
E_pc1_lasso_val = []
E_pc2_lasso_val = []
E_pc3_lasso_val = []
E_pc4_lasso_val = []
E_pc5_lasso_val = []
E_tmp_lasso_val = []

for i in pc1_val:
    tmp = (i-pc1_obs)**2
    E_pc1_lasso_val.append(tmp)
    
for j in pc2_val:
    tmp = (j-pc2_obs)**2
    E_pc2_lasso_val.append(tmp)

for k in pc3_val:
    tmp = (k-pc3_obs)**2
    E_pc3_lasso_val.append(tmp)
    
for l in pc4_val:
    tmp = (l-pc4_obs)**2
    E_pc4_lasso_val.append(tmp)
    
for m in pc5_val:
    tmp = (m-pc5_obs)**2
    E_pc5_lasso_val.append(tmp)

for n in range(0,len(E_pc1_lasso_val),1) :    
    tmp = E_pc1_lasso_val[n]+E_pc2_lasso_val[n]+E_pc3_lasso_val[n]+E_pc4_lasso_val[n]+E_pc5_lasso_val[n]
    E_tmp_lasso_val.append(tmp)

    
E_lasso_val = sqrt(E_tmp_lasso_val)
    
    
E_lasso_val
# Out:
# array([3.64910315, 4.06088073, 3.58689042, 4.36151717, 3.29513528,
#        2.85529206, 3.78948924, 3.24283169, 3.67355768, 3.96045292,
#        3.82735211, 4.55814091, 3.66023163, 3.98838092, 3.73989584,
#        3.64790364, 3.46530842, 3.3143101 , 3.61864004, 3.21778509,
#        4.09897212, 4.39129206, 3.62846414, 3.15095657, 3.01957345,
#        3.52152551, 2.85891524, 3.33765657, 3.66439509, 4.64175928,
#        3.63099314, 4.15928153, 3.46784146, 3.82259898, 2.97233667,
#        3.99640659, 4.1006623 , 3.010634  , 3.18660543, 3.79743957,
#        3.99500527, 4.53196848, 4.18820878, 3.98450606, 4.11203032,
#        3.97754857, 3.73343067, 4.56129483, 3.8878593 , 4.37827091,
#        3.40224358, 3.54381787, 4.50041055, 4.16487372, 4.13253649,
#        3.29604279, 3.64526172, 3.69466171, 3.86784986, 3.90461509,
#        2.80778396, 3.233985  , 4.41217913, 3.88696636, 3.70083144,
#        4.29887129, 3.79048799, 3.5810996 , 3.5453788 , 3.91521493,
# ...

# %%
E_pc1_lasso_pred = []
E_pc2_lasso_pred = []
E_pc3_lasso_pred = []
E_pc4_lasso_pred = []
E_pc5_lasso_pred = []
E_tmp_lasso_pred = []

for i in pc1:
    tmp = (i-pc1_obs)**2
    E_pc1_lasso_pred.append(tmp)
    
for j in pc2:
    tmp = (j-pc2_obs)**2
    E_pc2_lasso_pred.append(tmp)

for k in pc3:
    tmp = (k-pc3_obs)**2
    E_pc3_lasso_pred.append(tmp)
    
for l in pc4:
    tmp = (l-pc4_obs)**2
    E_pc4_lasso_pred.append(tmp)
    
for m in pc5:
    tmp = (m-pc5_obs)**2
    E_pc5_lasso_pred.append(tmp)

for n in range(0,len(E_pc1_lasso_pred),1) :    
    tmp = E_pc1_lasso_pred[n]+E_pc2_lasso_pred[n]+E_pc3_lasso_pred[n]+E_pc4_lasso_pred[n]+E_pc5_lasso_pred[n]
    E_tmp_lasso_pred.append(tmp)

    
E_lasso_pred = sqrt(E_tmp_lasso_pred)
    
    
E_lasso_pred
# Out:
# array([3.74327262, 4.42399097, 3.39478613, 4.79351913, 3.81567249,
#        2.78752036, 4.19037825, 3.7689442 , 4.77970233, 3.93155447,
#        4.32096958, 3.58650898, 3.5590887 , 4.04489164, 4.00330961,
#        3.89311178, 3.48087783, 4.76522952, 3.29444937, 3.16335264,
#        2.55668649, 3.66368878, 4.20218605, 4.05926191, 3.50271269,
#        3.7249787 , 3.4638521 , 3.57255087, 3.73371433, 3.57593112,
#        3.9917342 , 4.39626551, 3.75702708, 3.35969906, 3.59182834,
#        2.9904722 , 4.45292223, 4.79085053, 3.18807677, 2.05801359,
#        4.15009364, 2.56847091, 3.48384067, 3.46938096, 3.81605133,
#        4.06984367, 3.29755878, 3.38504938, 3.67685755, 3.4108601 ,
#        3.45932874, 3.32298902, 3.48652932, 3.2414683 , 4.06535691,
#        3.6070056 , 3.00481749, 2.96625473, 3.92589314, 3.93619359,
#        4.5722748 , 3.90452533, 3.79839985, 4.10001507, 3.59332899,
#        2.92636295, 3.21039271, 3.28712314, 3.59828165, 4.01328918,
# ...

# %% [markdown]
# # Neural Network predictions

# %%
pc1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_prediction_eof1_LW.npy')
pc2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_prediction_eof2_LW.npy')
pc3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_prediction_eof3_LW.npy')
pc4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_prediction_eof4_LW.npy')
pc5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_prediction_eof5_LW.npy')

PC_df = pd.DataFrame(pc1)
PC_df['pc1'] = pc1
PC_df['pc2'] = pc2
PC_df['pc3'] = pc3
PC_df['pc4'] = pc4
PC_df['pc5'] = pc5
PC_df = PC_df.drop(labels = 0, axis=1)
#PC_df

pc1 = PC_df['pc1'].to_xarray().rename({'index':'mode'})
pc2 = PC_df['pc2'].to_xarray().rename({'index':'mode'})
pc3 = PC_df['pc3'].to_xarray().rename({'index':'mode'})
pc4 = PC_df['pc4'].to_xarray().rename({'index':'mode'})
pc5 = PC_df['pc5'].to_xarray().rename({'index':'mode'})

# %%
pc1_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_validation_eof1_LW.npy')
pc2_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_validation_eof2_LW.npy')
pc3_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_validation_eof3_LW.npy')
pc4_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_validation_eof4_LW.npy')
pc5_val = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_validation_eof5_LW.npy')

PC_val_df_NN = pd.DataFrame(pc1_val)
PC_val_df_NN['pc1'] = pc1_val
PC_val_df_NN['pc2'] = pc2_val
PC_val_df_NN['pc3'] = pc3_val
PC_val_df_NN['pc4'] = pc4_val
PC_val_df_NN['pc5'] = pc5_val
PC_val_df_NN = PC_val_df_NN.drop(labels = 0, axis=1)
#PC_val_df

pc1_val = PC_val_df_NN['pc1'].to_xarray().rename({'index':'mode'})
pc2_val = PC_val_df_NN['pc2'].to_xarray().rename({'index':'mode'})
pc3_val = PC_val_df_NN['pc3'].to_xarray().rename({'index':'mode'})
pc4_val = PC_val_df_NN['pc4'].to_xarray().rename({'index':'mode'})
pc5_val = PC_val_df_NN['pc5'].to_xarray().rename({'index':'mode'})

# %% [markdown]
# ## Calcul de biais CERES

# %%
E_pc1_NN_val = []
E_pc2_NN_val = []
E_pc3_NN_val = []
E_pc4_NN_val = []
E_pc5_NN_val = []
E_tmp_NN_val = []

for i in pc1_val:
    tmp = (i-pc1_obs)**2
    E_pc1_NN_val.append(tmp)
    
for j in pc2_val:
    tmp = (j-pc2_obs)**2
    E_pc2_NN_val.append(tmp)

for k in pc3_val:
    tmp = (k-pc3_obs)**2
    E_pc3_NN_val.append(tmp)
    
for l in pc4_val:
    tmp = (l-pc4_obs)**2
    E_pc4_NN_val.append(tmp)
    
for m in pc5_val:
    tmp = (m-pc5_obs)**2
    E_pc5_NN_val.append(tmp)

for n in range(0,len(E_pc1_NN_val),1) :    
    tmp = E_pc1_NN_val[n]+E_pc2_NN_val[n]+E_pc3_NN_val[n]+E_pc4_NN_val[n]+E_pc5_NN_val[n]
    E_tmp_NN_val.append(tmp)

    
E_NN_val = sqrt(E_tmp_NN_val)
    
    
E_NN_val
# Out:
# array([4.2160027 , 3.6315969 , 4.04547821, 4.67721057, 5.1972912 ,
#        5.06649695, 3.35213315, 4.10254103, 4.61717254, 4.28862596,
#        5.16192958, 4.15371754, 5.01448611, 4.15584975, 4.65271533,
#        3.88590395, 3.23898851, 3.61306107, 4.27631131, 3.78931859,
#        3.3399722 , 2.37685   ])

# %%
E_pc1_NN_pred = []
E_pc2_NN_pred = []
E_pc3_NN_pred = []
E_pc4_NN_pred = []
E_pc5_NN_pred = []
E_tmp_NN_pred = []

for i in pc1:
    tmp = (i-pc1_obs)**2
    E_pc1_NN_pred.append(tmp)
    
for j in pc2:
    tmp = (j-pc2_obs)**2
    E_pc2_NN_pred.append(tmp)

for k in pc3:
    tmp = (k-pc3_obs)**2
    E_pc3_NN_pred.append(tmp)
    
for l in pc4:
    tmp = (l-pc4_obs)**2
    E_pc4_NN_pred.append(tmp)
    
for m in pc5:
    tmp = (m-pc5_obs)**2
    E_pc5_NN_pred.append(tmp)

for n in range(0,len(E_pc1_lasso_pred),1) :    
    tmp = E_pc1_NN_pred[n]+E_pc2_NN_pred[n]+E_pc3_NN_pred[n]+E_pc4_NN_pred[n]+E_pc5_NN_pred[n]
    E_tmp_NN_pred.append(tmp)

    
E_NN_pred = sqrt(E_tmp_NN_pred)
    
    
E_NN_pred
# Out:
# array([4.53716434, 5.21560523, 4.25136652, 4.64129728, 4.24281929,
#        3.66272354, 5.06153811, 2.87227282, 5.17421862, 4.5503745 ,
#        4.42805987, 3.01026708, 3.75681093, 4.34141561, 4.47828549,
#        3.23508342, 4.09368311, 4.01849557, 3.0588876 , 3.14960333,
#        2.39411214, 3.33333246, 4.74323849, 4.15825148, 3.67051897,
#        3.12471355, 2.92146625, 5.27192545, 3.91996303, 3.76482278,
#        4.19301072, 3.39371684, 2.14994451, 4.38829079, 3.70756584,
#        5.53504859, 3.99445199, 5.262964  , 3.89041875, 1.76702646,
#        4.68227648, 3.56744469, 4.22862772, 5.27412588, 4.65857727,
#        5.37563382, 3.41455931, 4.64332059, 3.77870657, 3.67018971,
#        3.26085692, 3.0192446 , 4.76343577, 4.65738581, 4.24360731,
#        3.8490439 , 4.28865841, 3.22976402, 4.52142164, 4.84844157,
#        4.43183022, 4.11504774, 3.6980717 , 3.72293744, 4.76264847,
#        3.43115319, 3.10094598, 3.80485341, 4.43946255, 4.98941929,
# ...

# %% [markdown]
# # Feedbacks + creation DataFrame

# %%
Fdbck_PPE = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LW_feedbacks.npy")
Fdbck_multilinreg_val = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_validation_FdbckLW.npy")
Fdbck_multilinreg_pred = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_FdbckLW.npy")
Fdbck_lasso_val = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_validation_FdbckLW.npy")
Fdbck_lasso_pred = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LASSO_prediction_FdbckLW.npy")
Fdbck_NN_val = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_validation_FdbckLW.npy")
Fdbck_NN_pred = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/NN_prediction_FdbckLW.npy")

# %%
E_PPE_df = pd.DataFrame(E_PPE, columns=['E_PPE'])
E_PPE_df['Fdbck'] = Fdbck_PPE
#E_PPE_df

# %%
E_multilinreg_val_df = pd.DataFrame(E_multilinreg_val, columns=['E_multilinreg_val'])
E_multilinreg_val_df['Fdbck_val'] = Fdbck_multilinreg_val
#E_multilinreg_val_df

E_multilinreg_pred_df = pd.DataFrame(E_multilinreg_pred, columns=['E_multilinreg_pred'])
E_multilinreg_pred_df['Fdbck_pred'] = Fdbck_multilinreg_pred
#E_multilinreg_pred_df

# %%
E_lasso_val_df = pd.DataFrame(E_lasso_val, columns=['E_lasso_val'])
E_lasso_val_df['Fdbck_val'] = Fdbck_lasso_val
#E_lasso_val_df

E_lasso_pred_df = pd.DataFrame(E_lasso_pred, columns=['E_lasso_pred'])
E_lasso_pred_df['Fdbck_pred'] = Fdbck_lasso_pred
#E_lasso_pred_df

# %%
E_NN_val_df = pd.DataFrame(E_NN_val, columns=['E_NN_val'])
E_NN_val_df['Fdbck_val'] = Fdbck_NN_val
#E_NN_val_df

E_NN_pred_df = pd.DataFrame(E_NN_pred, columns=['E_NN_pred'])
E_NN_pred_df['Fdbck_pred'] = Fdbck_NN_pred
#E_NN_pred_df

# %% [markdown]
# # Create Plot

# %%
ax = plt.gca()
title = 'LW TOA fluxes error [PPE - CERES] vs Feedbacks'

E_PPE_df.plot(kind='scatter', x='Fdbck', y='E_PPE', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)
#plt.hlines(Biases_official_LW,xmin = -2.0,xmax = -0.5,label='official simulation', colors='gray', 
#           linestyles='solid')
#plt.vlines(Feedbacks_official,ymin = 0,ymax = 25,label='official simulation', colors='gray', 
#           linestyles='solid')

plt.xlabel('Feedbacks (W.m^2)', fontsize=18)
plt.ylabel('LW TOA fluxes error', fontsize=18)
plt.legend(['models', 'default model'])
plt.title(title, fontsize=22)
plt.ylim(1,8)
plt.xlim(1.2,2.6)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
ax = plt.gca()
title = 'LW TOA fluxes error [PPE - CERES] vs Feedbacks'

E_multilinreg_val_df.plot(kind='scatter', x='Fdbck_val', y='E_multilinreg_val', color='red', alpha=1, figsize=(15, 12), 
                     marker='x', ax = ax)
E_lasso_val_df.plot(kind='scatter', x='Fdbck_val', y='E_lasso_val', color='blue', alpha=1, figsize=(15, 12), 
                     marker='x', ax = ax)
E_NN_val_df.plot(kind='scatter', x='Fdbck_val', y='E_NN_val', color='green', figsize=(15, 12), 
                     marker="x", ax = ax)

E_PPE_df.plot(kind='scatter', x='Fdbck', y='E_PPE', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)

#plt.hlines(Biases_official_LW,xmin = -2.0,xmax = -0.5,label='official simulation', colors='gray', 
#           linestyles='solid')
#plt.vlines(Feedbacks_official,ymin = 0,ymax = 25,label='official simulation', colors='gray', 
#           linestyles='solid')

plt.xlabel('Feedbacks (W.m^2)', fontsize=18)
plt.ylabel('LW TOA fluxes error', fontsize=18)
plt.legend(['MultiLinreg validation','LASSO validation','NN validation', 'models', 'default model'])
plt.title(title, fontsize=22)
plt.ylim(1,8)
plt.xlim(1.2,2.6)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/Biases_VS_feedbacks.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
ax = plt.gca()
title = 'LW TOA fluxes error [PPE - CERES] vs Feedbacks'

E_multilinreg_val_df.plot(kind='scatter', x='Fdbck_val', y='E_multilinreg_val', color='red', alpha=1, figsize=(15, 12), 
                     marker='x', ax = ax)
E_lasso_val_df.plot(kind='scatter', x='Fdbck_val', y='E_lasso_val', color='blue', alpha=1, figsize=(15, 12), 
                     marker='x', ax = ax)
E_NN_val_df.plot(kind='scatter', x='Fdbck_val', y='E_NN_val', color='green', figsize=(15, 12), 
                     marker="x", ax = ax)

E_multilinreg_pred_df.plot(kind='scatter', x='Fdbck_pred', y='E_multilinreg_pred', 
                           color='coral', alpha=0.4, figsize=(15, 12), marker='.', ax = ax)
E_lasso_pred_df.plot(kind='scatter', x='Fdbck_pred', y='E_lasso_pred', 
                    color='blue', alpha=0.2, figsize=(15, 12), marker='.', ax = ax)
E_NN_pred_df.plot(kind='scatter', x='Fdbck_pred', y='E_NN_pred', 
                 color='green', alpha=0.2, figsize=(15, 12), marker='.', ax = ax)


E_PPE_df.plot(kind='scatter', x='Fdbck', y='E_PPE', color='black', figsize=(15, 12), 
                     marker="o", ax = ax)
#plt.hlines(Biases_official_LW,xmin = -2.0,xmax = -0.5,label='official simulation', colors='gray', 
#           linestyles='solid')
#plt.vlines(Feedbacks_official,ymin = 0,ymax = 25,label='official simulation', colors='gray', 
#           linestyles='solid')
ax.tick_params(axis='both', which='major', labelsize=14)
plt.xlabel('LW Feedbacks [$W.m^2$]', fontsize=18)
plt.ylabel('RMSE LW fluxes', fontsize=18)
plt.legend(['MultiLinreg validation','LASSO validation','NN validation', 'MultiLinreg predictions',
            'LASSO predictions', 'NN predictions',
            'PPE', 'default model'], fontsize=12)
#plt.title(title, fontsize=22)
plt.ylim(1,8)
plt.xlim(1.2,2.6)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/Biases_LW_VS_feedbacks_LW.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

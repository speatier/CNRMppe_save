# %% [markdown]
# # Importe modules

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas
from eofs.xarray import Eof
from eofs.multivariate.standard import MultivariateEof

# Plotting modules 
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from matplotlib.colors import BoundaryNorm

# Scikit-learn
from sklearn import linear_model
from sklearn.linear_model import LassoCV, LassoLarsCV, LassoLarsIC
from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn import preprocessing
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from scipy.optimize import minimize
from scipy.optimize import dual_annealing

# %% [markdown]
# # Functions definition

# %%
import sys
sys.path.append('/data/home/globc/peatier/CNRMppe')
import Fonctions
from Fonctions import get_wavg_budget_df
from Fonctions import wavg 
from Fonctions import plotlines_Xdf
from Fonctions import plotlines_1df
from Fonctions import Deltas_Lambda
from Fonctions import get_3D_budget_xarr
from Fonctions import get_3D_xarr
from Fonctions import get_3D_SW_xarr
from Fonctions import get_3D_LW_xarr

# %%
def Error(path, filename, U_obs):
    
    U = np.load(path+filename)

    pc1 = U[0]
    pc2 = U[1]
    pc3 = U[2]
    pc4 = U[3]
    pc5 = U[4]

    E_tmp = (pc1-U_obs[0])**2 + (pc2-U_obs[1])**2 + (pc3-U_obs[2])**2 + (pc4-U_obs[3])**2 + (pc5-U_obs[4])**2
    E = sqrt(E_tmp/5)
    return E

# %%
def RMSE_emulator(pc1, pc2, pc3, pc4, pc5) : 
    
    U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_SW.npy')
    
    E_pc1 = []
    E_pc2 = []
    E_pc3 = []
    E_pc4 = []
    E_pc5 = []
    E_tmp = []

    for i in pc1:
        tmp = (i-U_obs[0])**2
        E_pc1.append(tmp)
    
    for j in pc2:
        tmp = (j-U_obs[1])**2
        E_pc2.append(tmp)

    for k in pc3:
        tmp = (k-U_obs[2])**2
        E_pc3.append(tmp)
    
    for l in pc4:
        tmp = (l-U_obs[3])**2
        E_pc4.append(tmp)
    
    for m in pc5:
        tmp = (m-U_obs[4])**2
        E_pc5.append(tmp)

    for n in range(0,len(E_pc1),1) :    
        tmp = E_pc1[n]+E_pc2[n]+E_pc3[n]+E_pc4[n]+E_pc5[n]
        E_tmp.append(tmp/5)

    
    E = sqrt(E_tmp)
    
    
    return E

# %%
def Error_emulator(pc1, pc2, pc3, pc4, pc5):
    U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_SW.npy')
    E_tmp = (pc1-U_obs[0])**2 + (pc2-U_obs[1])**2 + (pc3-U_obs[2])**2 + (pc4-U_obs[3])**2 + (pc5-U_obs[4])**2
    E = sqrt(E_tmp/5)
    return E

# %%
def MultiLinReg_pred_eof1(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF1pc_SW.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    regr = linear_model.LinearRegression()
    regr.fit(X, y)

    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]
    
    # Let's use the model equation : 
    
    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %%
def MultiLinReg_pred_eof2(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF2pc_SW.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %%
def MultiLinReg_pred_eof3(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF3pc_SW.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %%
def MultiLinReg_pred_eof4(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF4pc_SW.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %%
def MultiLinReg_pred_eof5(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF5pc_SW.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %%
def MultiLinReg_pred(x, EOF_nb) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/PPE2_EOF"+str(EOF_nb)+"pc_SW.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
    
    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

# %% [markdown]
# # Draw bottom line by selecting the best model for each feedback value

# %%
E_multilinreg_pred = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/RMSE_multilinreg_pred.npy")
Fdbck_multilinreg_pred = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_FdbckN.npy")
multilinreg_pc1 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof1_SW.npy')
multilinreg_pc2 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof2_SW.npy')
multilinreg_pc3 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof3_SW.npy')
multilinreg_pc4 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof4_SW.npy')
multilinreg_pc5 = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/MultiLinReg_prediction_eof5_SW.npy')


E_multilinreg_pred_df = pd.DataFrame(E_multilinreg_pred)
E_multilinreg_pred_df['E_multilinreg_pred'] = E_multilinreg_pred
E_multilinreg_pred_df['Fdbck_pred'] = Fdbck_multilinreg_pred[0:100000]
E_multilinreg_pred_df['pc1'] = multilinreg_pc1[0:100000]
E_multilinreg_pred_df['pc2'] = multilinreg_pc2[0:100000]
E_multilinreg_pred_df['pc3'] = multilinreg_pc3[0:100000]
E_multilinreg_pred_df['pc4'] = multilinreg_pc4[0:100000]
E_multilinreg_pred_df['pc5'] = multilinreg_pc5[0:100000]
E_multilinreg_pred_df = E_multilinreg_pred_df.drop([0], axis=1)
E_multilinreg_pred_df
# Out:
#        E_multilinreg_pred  Fdbck_pred       pc1       pc2       pc3       pc4  \
# 0                1.436409   -1.512419 -0.469895 -0.881113  0.183923 -0.965226
# 1                2.077970   -1.334161 -0.287664  0.721091  0.058447 -1.769222
# 2                1.716970   -1.344134  0.601063 -1.060303  0.358952  0.797624
# 3                1.551983   -1.528166 -0.172273  0.156534  0.829543 -0.142481
# 4                1.646350   -1.358046 -0.481003 -0.273733 -1.327620 -0.049229
# ...                   ...         ...       ...       ...       ...       ...
# 99995            2.573791   -1.466209 -0.484470  1.675971 -0.500782 -0.832964
# 99996            2.077757   -1.415162  0.501305  0.973048  0.499152 -0.432323
# 99997            1.273864   -1.302962  0.593773 -1.293726  0.469873 -0.075640
# 99998            1.351313   -1.311885  0.707075 -1.305159  1.995649 -0.768929
# 99999            1.779608   -1.191455  1.132781  0.256708  0.664573 -0.434492
#
#             pc5
# 0     -0.057466
# 1      1.475733
# 2     -1.614642
# 3      1.057699
# 4      0.395888
# ...         ...
# 99995 -1.080794
# 99996 -0.073548
# 99997 -0.275940
# 99998  1.323026
# 99999  0.985786
#
# [100000 rows x 7 columns]

# %%
E_multilinreg_pred_df['Fdbck_pred_round'] = E_multilinreg_pred_df['Fdbck_pred'].round(decimals=2)
E_multilinreg_pred_df = E_multilinreg_pred_df.set_index('Fdbck_pred_round')
E_multilinreg_pred_df['members'] = range(0,100000,1) 
E_multilinreg_pred_df
# Out:
#                   E_multilinreg_pred  Fdbck_pred       pc1       pc2  \
# Fdbck_pred_round
# -1.51                       1.436409   -1.512419 -0.469895 -0.881113
# -1.33                       2.077970   -1.334161 -0.287664  0.721091
# -1.34                       1.716970   -1.344134  0.601063 -1.060303
# -1.53                       1.551983   -1.528166 -0.172273  0.156534
# -1.36                       1.646350   -1.358046 -0.481003 -0.273733
# ...                              ...         ...       ...       ...
# -1.47                       2.573791   -1.466209 -0.484470  1.675971
# -1.42                       2.077757   -1.415162  0.501305  0.973048
# -1.30                       1.273864   -1.302962  0.593773 -1.293726
# -1.31                       1.351313   -1.311885  0.707075 -1.305159
# -1.19                       1.779608   -1.191455  1.132781  0.256708
#
#                        pc3       pc4       pc5  members
# Fdbck_pred_round
# -1.51             0.183923 -0.965226 -0.057466        0
# -1.33             0.058447 -1.769222  1.475733        1
# -1.34             0.358952  0.797624 -1.614642        2
# -1.53             0.829543 -0.142481  1.057699        3
# -1.36            -1.327620 -0.049229  0.395888        4
# ...                    ...       ...       ...      ...
# -1.47            -0.500782 -0.832964 -1.080794    99995
# -1.42             0.499152 -0.432323 -0.073548    99996
# -1.30             0.469873 -0.075640 -0.275940    99997
# -1.31             1.995649 -0.768929  1.323026    99998
# -1.19             0.664573 -0.434492  0.985786    99999
#
# [100000 rows x 8 columns]

# %%
new_df=pd.DataFrame()
new_df['E_multilinreg_pred_best'] = E_multilinreg_pred_df['E_multilinreg_pred'].groupby('Fdbck_pred_round').min()
new_df = new_df.reset_index()
new_df
# Out:
#      Fdbck_pred_round  E_multilinreg_pred_best
# 0               -1.99                 2.100588
# 1               -1.97                 2.032247
# 2               -1.95                 1.917816
# 3               -1.94                 2.803443
# 4               -1.93                 2.605183
# ..                ...                      ...
# 113             -0.84                 1.363844
# 114             -0.83                 1.677334
# 115             -0.82                 2.954600
# 116             -0.80                 2.326778
# 117             -0.78                 1.862335
#
# [118 rows x 2 columns]

# %%
list_RMSE = new_df['E_multilinreg_pred_best']
n = len(list_RMSE)

tmp_fdbck = []
tmp_member = []
tmp_pc1 = []
cpt=0
ind=0
cpt_other=0
for i in E_multilinreg_pred_df['E_multilinreg_pred'] :
    for j in list_RMSE :
        if i==j:
            #print(cpt)
            tmp_fdbck.append(E_multilinreg_pred_df['Fdbck_pred'].iloc[cpt])
            tmp_member.append(E_multilinreg_pred_df['members'].iloc[cpt])
            tmp_pc1.append(E_multilinreg_pred_df['pc1'].iloc[cpt])
        else :
            cpt_other+=1
    cpt+=1

fdbck = [k for k in tmp_fdbck if k != 0]
members = [l for l in tmp_member if l != 0]
pc1 = [l for l in tmp_pc1 if l != 0]

df = pd.DataFrame()
df['fdbck'] = fdbck
df['members'] = members
df['pc1'] = pc1
df_sort = df.sort_values(by=['fdbck']).reset_index().drop('index', axis=1)
df_sort

new_df['Fdbck_pred'] = df_sort['fdbck']
new_df['members'] = df_sort['members']
new_df['pc1'] = df_sort['pc1']
new_df
# Out:
#      Fdbck_pred_round  E_multilinreg_pred_best  Fdbck_pred  members       pc1
# 0               -1.99                 2.100588   -1.990932    35649 -2.062817
# 1               -1.97                 2.032247   -1.970898    47523 -0.658163
# 2               -1.95                 1.917816   -1.945517    30599 -2.358642
# 3               -1.94                 2.803443   -1.943607    74150 -3.265444
# 4               -1.93                 2.605183   -1.928892     2836  0.211747
# ..                ...                      ...         ...      ...       ...
# 113             -0.84                 1.363844   -0.843261    58900  0.755841
# 114             -0.83                 1.677334   -0.831340    60906  1.912342
# 115             -0.82                 2.954600   -0.820404    57260  2.344520
# 116             -0.80                 2.326778   -0.800862    76973  2.683386
# 117             -0.78                 1.862335   -0.779245    77082  2.044257
#
# [118 rows x 5 columns]

# %%
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param.npy")
#LHS_df = pd.DataFrame(LHS)

pc1_pred=[]
pc1_true=[]
cpt=0
for i in LHS[0:10] :
    pc1_pred.append(function_RMSE_emulator(i))
    pc1_true.append(E_multilinreg_pred_df['E_multilinreg_pred'].iloc[cpt])
    cpt+=1

DF = pd.DataFrame()
DF['pc1_pred'] = pc1_pred
DF['pc1_true'] = pc1_true
DF['diff'] = DF['pc1_pred'] - DF['pc1_true']
DF
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-48d86a5f468c> in <module>
#       6 cpt=0
#       7 for i in LHS[0:10] :
# ----> 8     pc1_pred.append(function_RMSE_emulator(i))
#       9     pc1_true.append(E_multilinreg_pred_df['E_multilinreg_pred'].iloc[cpt])
#      10     cpt+=1
#
# NameError: name 'function_RMSE_emulator' is not defined

# %%
# FONCTIONS RMSE

def function_RMSE_emulator_std(x): 
    #mean = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_mean.npy')
    #std = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_std.npy')
    #x_std = (x-mean)/std
    pc1 = MultiLinReg_pred_eof1(x)
    pc2 = MultiLinReg_pred_eof2(x)
    pc3 = MultiLinReg_pred_eof3(x)
    pc4 = MultiLinReg_pred_eof4(x)
    pc5 = MultiLinReg_pred_eof5(x)
    
    E = Error_emulator(pc1, pc2, pc3, pc4, pc5)
    
    #E = sqrt(tmp_E)
    
    return E

def function_RMSE_emulator(x): 
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    E = function_RMSE_emulator_std(x_std)
    return E

# FONCTIONS FEEDBACKS

def em_fdb_std(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = tmp.sum()+R
    
    return y_pred

def em_fdb(x) :
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    y_pred = em_fdb_std(x_std)
    return y_pred

# %%
LHS = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_param.npy")

x_best = []
for i in new_df['members']:
    #print(i)
    x_best.append(LHS[i])

x_best=np.array(x_best)
#x_best

# %%
param = pd.read_csv("/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/csv/param.csv",sep=' ', header=None)
param_int = param.set_index(0).transpose()
param_names = param[0]

N=len(param_names)
xlimits=[[1,1]]*N
i=0
while i<N:
    name = param_names[i]
    xmin = param_int[name].iloc[0]
    xmax = param_int[name].iloc[1]
    if xmin<xmax:
        limit = [xmin, xmax]
    else:
        limit = [xmax, xmin]
    xlimits[i] = limit
    i+=1
    
xlim = np.array(xlimits)
xlim
# Out:
# array([[ 6.0e-02,  2.8e-01],
#        [ 5.0e-01,  3.0e+00],
#        [ 5.0e-01,  3.0e+00],
#        [ 0.0e+00,  3.0e+01],
#        [-5.0e-01, -1.0e-02],
#        [ 0.0e+00,  1.0e+01],
#        [ 0.0e+00,  1.0e+01],
#        [ 5.0e-04,  1.0e-02],
#        [ 5.0e-05,  1.0e-03],
#        [ 5.0e-04,  1.0e-02],
#        [ 1.0e-08,  1.0e-06],
#        [ 5.0e-06,  1.0e-04],
#        [ 1.0e-03,  2.0e-01],
#        [ 1.0e-03,  2.0e-01],
#        [ 1.0e-01,  6.0e+00],
#        [ 1.0e-01,  6.0e+00],
#        [ 3.0e-05,  7.0e-05],
#        [ 8.0e-05,  6.0e-04],
#        [ 2.0e-06,  1.0e-05],
#        [ 3.0e-05,  1.2e-04],
#        [-5.0e+00, -1.0e+00],
#        [-5.0e+01, -2.5e+01],
#        [ 1.0e-02,  1.0e-01],
#        [ 0.0e+00,  2.0e+01],
#        [ 1.0e-05,  1.0e-04],
#        [ 5.0e-01,  1.0e+00],
#        [ 5.0e-01,  1.0e+00],
#        [ 5.0e-01,  1.0e+00],
#        [ 5.0e-01,  1.0e+00],
#        [ 2.0e-01,  1.0e+01]])

# %%
sol_list=[]
sol_fdbck=[]


n = len(x_best)
cpt=0


def objective(x, x0):
    fdb = em_fdb(x)
    fdb_x0 = em_fdb(x0)
    RMSE = function_RMSE_emulator(x)
    E_tmp = 1+(fdb-fdb_x0)**2
    E = E_tmp*RMSE
    return E

def constraint(x, fdb_low, fdb_hi):
    test=0
    tmp = (em_fdb(x))
    low = (fdb_low)
    hi = (fdb_hi)
    if tmp<low or tmp>hi:
        test = -1
    return test


for i in range(0, n, 5) :
    x0 = x_best[i]
    fdb_low = em_fdb(x0)-0.08
    print('low = '+str(fdb_low))
    fdb_hi = em_fdb(x0)+0.08
    print('hi = '+str(fdb_hi))

    fdb_x0 = em_fdb(x0)
    print('fdb_x0 = '+str(fdb_x0))
    fun_x0 = function_RMSE_emulator(x0)
    print('fun_x0 = '+str(fun_x0))

    cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}
    
    sol = minimize(objective,  x0,args=(x0), method='SLSQP',  bounds=xlim,
                        constraints=cons, options={'disp': True, 'ftol' : 1e-20, 'eps' : 1e-10})    
    

    tmp_fun = function_RMSE_emulator(sol.x)
    tmp_fdbck = em_fdb(sol.x)
    print('fdb_x = '+str(tmp_fdbck))
    
    sol_list.append(tmp_fun)
    sol_fdbck.append(tmp_fdbck)
    
    #if tmp_fun<=fun_x0 and fdb_low<=tmp_fdbck<=fdb_hi:  
    #    sol_list.append(tmp_fun)
    #    sol_fdbck.append(tmp_fdbck)
    #else :
    #    print('\n ERROR \n')
# Out:
# low = -2.070931555303165
# hi = -1.910931555303165
# fdb_x0 = -1.990931555303165
# fun_x0 = 2.100587885370506
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.23991975970955848
#             Iterations: 28
#             Function evaluations: 810
#             Gradient evaluations: 24
# fdb_x = -1.584609668943895
# low = -1.9959818978965207
# hi = -1.8359818978965206
# fdb_x0 = -1.9159818978965206
# fun_x0 = 1.9293458814771247
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.3196749641923962
#             Iterations: 6
#             Function evaluations: 64
#             Gradient evaluations: 2
# fdb_x = -1.820001268060408
# low = -1.9458579253491246
# hi = -1.7858579253491245
# fdb_x0 = -1.8658579253491245
# fun_x0 = 1.457280178517555
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.7673520716139084
#             Iterations: 11
#             Function evaluations: 230
#             Gradient evaluations: 7
# fdb_x = -1.7088689372344517
# low = -1.9006818964125787
# hi = -1.7406818964125785
# fdb_x0 = -1.8206818964125786
# fun_x0 = 1.6998305330186954
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2191922996499565
#             Iterations: 17
#             Function evaluations: 442
#             Gradient evaluations: 13
# fdb_x = -1.7407615117557276
# low = -1.853594270574556
# hi = -1.693594270574556
# fdb_x0 = -1.773594270574556
# fun_x0 = 1.2551138852615977
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.2386263467557725
#             Iterations: 13
#             Function evaluations: 299
#             Gradient evaluations: 9
# fdb_x = -1.6950447837115148
# low = -1.801981066110732
# hi = -1.641981066110732
# fdb_x0 = -1.721981066110732
# fun_x0 = 1.1476217280989387
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.958165527910169
#             Iterations: 6
#             Function evaluations: 65
#             Gradient evaluations: 2
# fdb_x = -1.4634445874635806
# low = -1.7460847452684387
# hi = -1.5860847452684386
# fdb_x0 = -1.6660847452684386
# fun_x0 = 1.030572691722278
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.7751033646042591
#             Iterations: 18
#             Function evaluations: 468
#             Gradient evaluations: 14
# fdb_x = -1.5882301152679517
# low = -1.7026455490134151
# hi = -1.542645549013415
# fdb_x0 = -1.622645549013415
# fun_x0 = 0.8647857034328015
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.8441993581512571
#             Iterations: 7
#             Function evaluations: 99
#             Gradient evaluations: 3
# fdb_x = -1.6881322490391124
# low = -1.647280520996254
# hi = -1.4872805209962539
# fdb_x0 = -1.567280520996254
# fun_x0 = 0.7699433539609701
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.11641171217481647
#             Iterations: 15
#             Function evaluations: 367
#             Gradient evaluations: 11
# fdb_x = -1.5698105628973016
# low = -1.5974597964256991
# hi = -1.437459796425699
# fdb_x0 = -1.517459796425699
# fun_x0 = 0.7062515232520684
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.18997347508347204
#             Iterations: 13
#             Function evaluations: 301
#             Gradient evaluations: 9
# fdb_x = -1.352577545567716
# low = -1.5528861392198456
# hi = -1.3928861392198455
# fdb_x0 = -1.4728861392198456
# fun_x0 = 0.585623070888264
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.5931857124433547
#             Iterations: 19
#             Function evaluations: 514
#             Gradient evaluations: 15
# fdb_x = -1.3928938501396144
# low = -1.4951597641755774
# hi = -1.3351597641755772
# fdb_x0 = -1.4151597641755773
# fun_x0 = 0.6501493158806132
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.1688549185586105
#             Iterations: 7
#             Function evaluations: 99
#             Gradient evaluations: 3
# fdb_x = -1.3711436699068311
# low = -1.4475643909970326
# hi = -1.2875643909970325
# fdb_x0 = -1.3675643909970325
# fun_x0 = 0.5651259832367027
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.22594398594632975
#             Iterations: 13
#             Function evaluations: 299
#             Gradient evaluations: 9
# fdb_x = -1.3928994395159406
# low = -1.4010822276167454
# hi = -1.2410822276167452
# fdb_x0 = -1.3210822276167453
# fun_x0 = 0.6770830626191908
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.11774150008041111
#             Iterations: 15
#             Function evaluations: 366
#             Gradient evaluations: 11
# fdb_x = -1.320851283270616
# low = -1.3461190080772583
# hi = -1.1861190080772581
# fdb_x0 = -1.2661190080772582
# fun_x0 = 0.35280161714663594
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.22634960415965533
#             Iterations: 11
#             Function evaluations: 231
#             Gradient evaluations: 7
# fdb_x = -1.2990927575600912
# low = -1.3046634402390302
# hi = -1.14466344023903
# fdb_x0 = -1.2246634402390302
# fun_x0 = 0.6232180481973117
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.6232180481973117
#             Iterations: 5
#             Function evaluations: 32
#             Gradient evaluations: 1
# fdb_x = -1.2246634402390302
# low = -1.254248352889781
# hi = -1.0942483528897808
# fdb_x0 = -1.174248352889781
# fun_x0 = 0.6403851701386392
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.5209212503534816
#             Iterations: 8
#             Function evaluations: 132
#             Gradient evaluations: 4
# fdb_x = -1.312506534048293
# low = -1.201248023179246
# hi = -1.0412480231792458
# fdb_x0 = -1.1212480231792459
# fun_x0 = 0.6260966374814644
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.14767479793049385
#             Iterations: 12
#             Function evaluations: 265
#             Gradient evaluations: 8
# fdb_x = -1.3516977695382912
# low = -1.1521416653149203
# hi = -0.9921416653149203
# fdb_x0 = -1.0721416653149203
# fun_x0 = 0.7324831303991151
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.1391027476774895
#             Iterations: 12
#             Function evaluations: 269
#             Gradient evaluations: 8
# fdb_x = -1.1271023876401887
# low = -1.0973418331795772
# hi = -0.9373418331795772
# fdb_x0 = -1.0173418331795772
# fun_x0 = 0.8239472960755426
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.21183729970848028
#             Iterations: 12
#             Function evaluations: 264
#             Gradient evaluations: 8
# fdb_x = -1.1999067247119162
# low = -1.048507654079948
# hi = -0.888507654079948
# fdb_x0 = -0.968507654079948
# fun_x0 = 1.0641253250758729
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.2268401337555771
#             Iterations: 14
#             Function evaluations: 331
#             Gradient evaluations: 10
# fdb_x = -1.0449754296490181
# low = -1.0019662168850207
# hi = -0.8419662168850207
# fdb_x0 = -0.9219662168850207
# fun_x0 = 1.2200981307287728
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.2800642412012713
#             Iterations: 9
#             Function evaluations: 165
#             Gradient evaluations: 5
# fdb_x = -1.274440397580331
# low = -0.949335801502278
# hi = -0.7893358015022781
# fdb_x0 = -0.8693358015022781
# fun_x0 = 1.3483898701387296
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.41373298764626765
#             Iterations: 12
#             Function evaluations: 263
#             Gradient evaluations: 8
# fdb_x = -1.2659156616383782
# low = -0.9004037452804796
# hi = -0.7404037452804797
# fdb_x0 = -0.8204037452804797
# fun_x0 = 2.9545996667337695
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.6198245381324933
#             Iterations: 34
#             Function evaluations: 1071
#             Gradient evaluations: 30
# fdb_x = -1.2856688685540232

# %%
sol_list=[]
sol_fdbck=[]


def objective(x, fdb_low):
    fdb = em_fdb(x)
    RMSE = function_RMSE_emulator(x)
    E_tmp = 1+(fdb-fdb_low)**2
    E = E_tmp*RMSE
    return E

def constraint(x, fdb_low, fdb_hi):
    test=0
    tmp = (em_fdb(x))
    low = (fdb_low)
    hi = (fdb_hi)
    if tmp<low or tmp>hi:
        test = -1
    return test

bins = arange(-20, -6, 1)
print(bins)
n = len(bins)-1
cpt=0
j=0
for i in range(0, n, 1) :
    fdb_low = bins[i]/10
    print('low = '+str(fdb_low))
    fdb_hi = bins[i + 1]/10
    print('hi = '+str(fdb_hi))
    x0 = x_best[j]
    fdb_x0 = em_fdb(x0)
    fun_x0 = function_RMSE_emulator(x0)
    print('fun_x0 = '+str(fun_x0))
    print('fdb_x0 = '+str(fdb_x0))


    cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}
    
    sol = minimize(function_RMSE_emulator,  x0, method='SLSQP',  bounds=xlim,
                        constraints=cons, options={'disp': True, 'ftol' : 1e-06, 'eps' : 1e-10})    
    

    j = i+10
    tmp_fun = function_RMSE_emulator(sol.x)
    tmp_fdbck = em_fdb(sol.x)
    print('fdb_x = '+str(tmp_fdbck))
    
    sol_list.append(tmp_fun)
    sol_fdbck.append(tmp_fdbck)
    
    #if tmp_fun<=fun_x0 and fdb_low<=tmp_fdbck<=fdb_hi:  
    #    sol_list.append(tmp_fun)
    #    sol_fdbck.append(tmp_fdbck)
    #else :
    #    print('\n ERROR \n')
# Out:
# [-20 -19 -18 -17 -16 -15 -14 -13 -12 -11 -10  -9  -8  -7]
# low = -2.0
# hi = -1.9
# fun_x0 = 2.100587885370506
# fdb_x0 = -1.990931555303165
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.38539154312855994
#             Iterations: 14
#             Function evaluations: 330
#             Gradient evaluations: 10
# fdb_x = -1.4957500291659216
# low = -1.9
# hi = -1.8
# fun_x0 = 1.457280178517555
# fdb_x0 = -1.8658579253491245
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.150638478699641
#             Iterations: 13
#             Function evaluations: 308
#             Gradient evaluations: 9
# fdb_x = -1.5193329754290736
# low = -1.8
# hi = -1.7
# fun_x0 = 1.8171694870758064
# fdb_x0 = -1.8603494477545703
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 1.3120623612443343
#             Iterations: 19
#             Function evaluations: 501
#             Gradient evaluations: 15
# fdb_x = -1.7066503988373076
# low = -1.7
# hi = -1.6
# fun_x0 = 1.8046945010575046
# fdb_x0 = -1.8488725862433353
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.4043558392908935
#             Iterations: 19
#             Function evaluations: 502
#             Gradient evaluations: 15
# fdb_x = -1.4354344613363594
# low = -1.6
# hi = -1.5
# fun_x0 = 1.9875433510583422
# fdb_x0 = -1.8417910375497408
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.24438919508346543
#             Iterations: 11
#             Function evaluations: 230
#             Gradient evaluations: 7
# fdb_x = -1.319016305883746
# low = -1.5
# hi = -1.4
# fun_x0 = 1.4447024330509475
# fdb_x0 = -1.8298046927750296
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.44948549426884404
#             Iterations: 11
#             Function evaluations: 227
#             Gradient evaluations: 7
# fdb_x = -1.6130679061946276
# low = -1.4
# hi = -1.3
# fun_x0 = 1.6998305330186954
# fdb_x0 = -1.8206818964125786
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 1.2683767016480816
#             Iterations: 10
#             Function evaluations: 194
#             Gradient evaluations: 6
# fdb_x = -1.6638640875096145
# low = -1.3
# hi = -1.2
# fun_x0 = 1.4770290261437788
# fdb_x0 = -1.8117012158890746
# Optimization terminated successfully.    (Exit mode 0)
#             Current function value: 0.39852088238355793
#             Iterations: 7
#             Function evaluations: 193
#             Gradient evaluations: 6
# fdb_x = -1.297468460332682
# low = -1.2
# hi = -1.1
# fun_x0 = 1.6866706793459865
# fdb_x0 = -1.798187175633661
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.4557648527277992
#             Iterations: 10
#             Function evaluations: 195
#             Gradient evaluations: 6
# fdb_x = -1.5590546096712419
# low = -1.1
# hi = -1.0
# fun_x0 = 1.5583999900817416
# fdb_x0 = -1.7853329736768977
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.903602619225153
#             Iterations: 6
#             Function evaluations: 64
#             Gradient evaluations: 2
# fdb_x = -1.7126615992902718
# low = -1.0
# hi = -0.9
# fun_x0 = 1.4017956665594475
# fdb_x0 = -1.7784551541284315
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.563452335054975
#             Iterations: 11
#             Function evaluations: 237
#             Gradient evaluations: 7
# fdb_x = -1.2621819638785736
# low = -0.9
# hi = -0.8
# fun_x0 = 1.2551138852615977
# fdb_x0 = -1.773594270574556
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.11046962453314207
#             Iterations: 18
#             Function evaluations: 469
#             Gradient evaluations: 14
# fdb_x = -1.5134446638914492
# low = -0.8
# hi = -0.7
# fun_x0 = 1.370907286979796
# fdb_x0 = -1.7592578969592885
# Positive directional derivative for linesearch    (Exit mode 8)
#             Current function value: 0.3969455126787662
#             Iterations: 13
#             Function evaluations: 298
#             Gradient evaluations: 9
# fdb_x = -1.3873124049019585

# %%
sol_list=[]
sol_fdbck=[]

#def constraint(x, fdb_low, fdb_hi):
#    fdb = em_fdb(x)
#    test = -(fdb-fdb_low)*(fdb-fdb_hi)
#    return test

#cons = {'type': 'ineq', 'fun' : constraint}

#bins = arange(-20, -7, 1)
#print(bins)
n = len(x_best)
cpt=0


#i=0
#fdb_low = bins[i]/10
#print('low = '+str(fdb_low))
#fdb_hi = bins[i + 1]/10
#print('hi = '+str(fdb_hi))
#x0 = x_best[cpt]
#fdb_x0 = em_fdb(x0)
#fun_x0 = function_RMSE_emulator(x0)
#print('fun_x0 = '+str(fun_x0))
#print('fdb_x0 = '+str(fdb_x0))

def objective(x, fdb_low, fdb_hi, xlim, x0) :
    RMSE = function_RMSE_emulator(x)
    fdb = em_fdb(x)
    fdb_x0 = em_fdb(x0)
    E_tmp = 1+(fdb-fdb_x0)**2
    E_def = E_tmp*RMSE
    #RMSE = (1+(fdb-fdb_low)**2)*RMSE_tmp
    
    if fdb_low<=fdb and fdb<=fdb_hi:
        E=E_def
    else : 
        E=10000
        
    n=30
    for cpt in range(0,n,1) :
        i = x[cpt]
        j = xlim[cpt]
        low = j [0]
        hi = j[1]
    
        if low<=i and i<=hi:
            E=E_def
        else : 
            E=10000
    
    return E

def constraint(x, fdb_low, fdb_hi):
    test=0
    tmp = (em_fdb(x))
    low = (fdb_low)
    hi = (fdb_hi)
    if tmp<low or tmp>hi:
        test = -1
    return test

#cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}

#sol = minimize(function_RMSE_emulator,  x0,  method='SLSQP', bounds=xlim, 
#                        constraints = cons, options={'disp': True})

#tmp_fun = function_RMSE_emulator(sol.x)
#tmp_fdbck = em_fdb(sol.x)
#print('fun = '+str(tmp_fun))
#print('fdb_x = '+str(tmp_fdbck))

for i in range(0, n, 5) :
    x0 = x_best[i]
    fdb_low = em_fdb(x0)-0.1
    print('low = '+str(fdb_low))
    fdb_hi = em_fdb(x0)+0.1
    print('hi = '+str(fdb_hi))

    fdb_x0 = em_fdb(x0)
    print('fdb_x0 = '+str(fdb_x0))
    fun_x0 = function_RMSE_emulator(x0)
    print('fun_x0 = '+str(fun_x0))

    cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}
    
    sol = minimize(objective, x0, args=(fdb_low, fdb_hi, xlim, x0), method='Nelder-Mead', 
                   options={'disp': True})    
    

    tmp_fun = function_RMSE_emulator(sol.x)
    tmp_fdbck = em_fdb(sol.x)
    print('fdb_x = '+str(tmp_fdbck))
    
    sol_list.append(tmp_fun)
    sol_fdbck.append(tmp_fdbck)
    
    #if tmp_fun<=fun_x0 and fdb_low<=tmp_fdbck<=fdb_hi:  
    #    sol_list.append(tmp_fun)
    #    sol_fdbck.append(tmp_fdbck)
    #else :
    #    print('\n ERROR \n')
# Out:
# low = -2.090931555303165
# hi = -1.890931555303165
# fdb_x0 = -1.990931555303165
# fun_x0 = 2.100587885370506
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 1318
#          Function evaluations: 1889
# fdb_x = -2.0472673333911526
# low = -2.0159818978965207
# hi = -1.8159818978965205
# fdb_x0 = -1.9159818978965206
# fun_x0 = 1.9293458814771247
# Optimization terminated successfully.
#          Current function value: 0.000004
#          Iterations: 1232
#          Function evaluations: 1756
# fdb_x = -1.7189106473006617
# low = -1.9658579253491246
# hi = -1.7658579253491244
# fdb_x0 = -1.8658579253491245
# fun_x0 = 1.457280178517555
# Optimization terminated successfully.
#          Current function value: 0.000000
#          Iterations: 1191
#          Function evaluations: 1796
# fdb_x = -1.7531356910845606
# low = -1.9206818964125787
# hi = -1.7206818964125785
# fdb_x0 = -1.8206818964125786
# fun_x0 = 1.6998305330186954
# Optimization terminated successfully.
#          Current function value: 0.000003
#          Iterations: 1275
#          Function evaluations: 1810
# fdb_x = -1.52545555150713
# low = -1.873594270574556
# hi = -1.673594270574556
# fdb_x0 = -1.773594270574556
# fun_x0 = 1.2551138852615977
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 1100
#          Function evaluations: 1635
# fdb_x = -1.4721567031930312
# low = -1.821981066110732
# hi = -1.621981066110732
# fdb_x0 = -1.721981066110732
# fun_x0 = 1.1476217280989387
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 1254
#          Function evaluations: 1816
# fdb_x = -1.5763270784066945
# low = -1.7660847452684387
# hi = -1.5660847452684385
# fdb_x0 = -1.6660847452684386
# fun_x0 = 1.030572691722278
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 1105
#          Function evaluations: 1663
# fdb_x = -1.5783463044977162
# low = -1.7226455490134152
# hi = -1.522645549013415
# fdb_x0 = -1.622645549013415
# fun_x0 = 0.8647857034328015
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 944
#          Function evaluations: 1441
# fdb_x = -1.429366015240768
# low = -1.667280520996254
# hi = -1.4672805209962538
# fdb_x0 = -1.567280520996254
# fun_x0 = 0.7699433539609701
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 1032
#          Function evaluations: 1542
# fdb_x = -1.3623243491050356
# low = -1.6174597964256991
# hi = -1.417459796425699
# fdb_x0 = -1.517459796425699
# fun_x0 = 0.7062515232520684
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 877
#          Function evaluations: 1355
# fdb_x = -1.5018252310350668
# low = -1.5728861392198457
# hi = -1.3728861392198455
# fdb_x0 = -1.4728861392198456
# fun_x0 = 0.585623070888264
# Optimization terminated successfully.
#          Current function value: 0.000001
#          Iterations: 979
#          Function evaluations: 1498
# fdb_x = -1.4269471971735612
# low = -1.5151597641755774
# hi = -1.3151597641755772
# fdb_x0 = -1.4151597641755773
# fun_x0 = 0.6501493158806132
# Optimization terminated successfully.
#          Current function value: 0.000002
#          Iterations: 1006
#          Function evaluations: 1495
# fdb_x = -1.295850320191784
# low = -1.4675643909970326
# hi = -1.2675643909970324
# fdb_x0 = -1.3675643909970325
# fun_x0 = 0.5651259832367027
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-0c6d5003ad9e> in <module>
#      87
#      88     sol = minimize(objective, x0, args=(fdb_low, fdb_hi, xlim, x0), method='Nelder-Mead',
# ---> 89                    options={'disp': True})
#      90
#      91
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     596
#     597     if meth == 'nelder-mead':
# --> 598         return _minimize_neldermead(fun, x0, args, callback, **options)
#     599     elif meth == 'powell':
#     600         return _minimize_powell(fun, x0, args, callback, **options)
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py in _minimize_neldermead(func, x0, args, callback, maxiter, maxfev, disp, return_all, initial_simplex, xatol, fatol, adaptive, **unknown_options)
#     600         xbar = numpy.add.reduce(sim[:-1], 0) / N
#     601         xr = (1 + rho) * xbar - rho * sim[-1]
# --> 602         fxr = func(xr)
#     603         doshrink = 0
#     604
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# <ipython-input-40-0c6d5003ad9e> in objective(x, fdb_low, fdb_hi, xlim, x0)
#      28 def objective(x, fdb_low, fdb_hi, xlim, x0) :
#      29     RMSE = function_RMSE_emulator(x)
# ---> 30     fdb = em_fdb(x)
#      31     fdb_x0 = em_fdb(x0)
#      32     E_tmp = 1+(fdb-fdb_x0)**2
#
# <ipython-input-17-916b92e36366> in em_fdb(x)
#      55     x_std = toto/STD
#      56
# ---> 57     y_pred = em_fdb_std(x_std)
#      58     return y_pred
#      59
#
# <ipython-input-17-916b92e36366> in em_fdb_std(x)
#      33     X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
#      34     y = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy")
# ---> 35     param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")
#      36
#      37     # Let's use the model equation :
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     451             else:
#     452                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 453                                          pickle_kwargs=pickle_kwargs)
#     454         else:
#     455             # Try a pickle
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     727     version = read_magic(fp)
#     728     _check_version(version)
# --> 729     shape, fortran_order, dtype = _read_array_header(fp, version)
#     730     if len(shape) == 0:
#     731         count = 1
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/numpy/lib/format.py in _read_array_header(fp, version)
#     591     #   "fortran_order" : bool
#     592     #   "descr" : dtype.descr
# --> 593     header = _filter_header(header)
#     594     try:
#     595         d = safe_eval(header)
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/numpy/lib/format.py in _filter_header(s)
#     554     # adding newline as python 2.7.5 workaround
#     555     string = s + "\n"
# --> 556     for token in tokenize.generate_tokens(StringIO(string).readline):
#     557         token_type = token[0]
#     558         token_string = token[1]
#
# /data/scratch/globc/peatier/conda/lib/python3.7/tokenize.py in _tokenize(readline, encoding)
#     602                     yield TokenInfo(COMMENT, token, spos, epos, line)
#     603
# --> 604                 elif token in triple_quoted:
#     605                     endprog = _compile(endpats[token])
#     606                     endmatch = endprog.match(line, pos)
#
# KeyboardInterrupt:

# %%
sol_list=[]
sol_fdbck=[]

#def constraint(x, fdb_low, fdb_hi):
#    fdb = em_fdb(x)
#    test = -(fdb-fdb_low)*(fdb-fdb_hi)
#    return test

#cons = {'type': 'ineq', 'fun' : constraint}

#bins = arange(-20, -7, 1)
#print(bins)
n = len(x_best)
cpt=0


#i=0
#fdb_low = bins[i]/10
#print('low = '+str(fdb_low))
#fdb_hi = bins[i + 1]/10
#print('hi = '+str(fdb_hi))
#x0 = x_best[cpt]
#fdb_x0 = em_fdb(x0)
#fun_x0 = function_RMSE_emulator(x0)
#print('fun_x0 = '+str(fun_x0))
#print('fdb_x0 = '+str(fdb_x0))

def constraint(x, fdb_low, fdb_hi):
    test=0
    tmp = (em_fdb(x))
    low = (fdb_low)
    hi = (fdb_hi)
    if tmp<low or tmp>hi:
        test = -1
    return test

#cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}

#sol = minimize(function_RMSE_emulator,  x0,  method='SLSQP', bounds=xlim, 
#                        constraints = cons, options={'disp': True})

#tmp_fun = function_RMSE_emulator(sol.x)
#tmp_fdbck = em_fdb(sol.x)
#print('fun = '+str(tmp_fun))
#print('fdb_x = '+str(tmp_fdbck))

#for i in range(0, n, 5) :
x0 = x_best[0]
fdb_low = em_fdb(x0)-0.1
print('low = '+str(fdb_low))
fdb_hi = em_fdb(x0)+0.1
print('hi = '+str(fdb_hi))

fdb_x0 = em_fdb(x0)
print('fdb_x0 = '+str(fdb_x0))
fun_x0 = function_RMSE_emulator(x0)
print('fun_x0 = '+str(fun_x0))

cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}
    
sol = dual_annealing(function_RMSE_emulator, x0=x0, bounds=XLIM)
print(sol)    

tmp_fun = function_RMSE_emulator(sol.x)
tmp_fdbck = em_fdb(sol.x)
print('fdb_x = '+str(tmp_fdbck))
    
#sol_list.append(tmp_fun)
#sol_fdbck.append(tmp_fdbck)
    
#if tmp_fun<=fun_x0 and fdb_low<=tmp_fdbck<=fdb_hi:  
#    sol_list.append(tmp_fun)
#    sol_fdbck.append(tmp_fdbck)
#else :
#    print('\n ERROR \n')
# Out:
# low = -2.090931555303165
# hi = -1.890931555303165
# fdb_x0 = -1.990931555303165
# fun_x0 = 2.100587885370506
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-dba0c7f6f979> in <module>
#      59 cons = {'type': 'ineq', 'fun' : constraint, 'args' : [fdb_low, fdb_hi]}
#      60
# ---> 61 sol = dual_annealing(function_RMSE_emulator, x0=x0, bounds=XLIM)
#      62 print(sol)
#      63
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/_dual_annealing.py in dual_annealing(func, bounds, args, maxiter, local_search_options, initial_temp, restart_temp_ratio, visit, accept, maxfun, seed, no_local_search, callback, x0)
#     671             # Possible local search at the end of the strategy chain
#     672             if not no_local_search:
# --> 673                 val = strategy_chain.local_search()
#     674                 if val is not None:
#     675                     message.append(val)
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/_dual_annealing.py in local_search(self)
#     316             # Global energy has improved, let's see if LS improves further
#     317             e, x = self.minimizer_wrapper.local_search(self.energy_state.xbest,
# --> 318                                                        self.energy_state.ebest)
#     319             if e < self.energy_state.ebest:
#     320                 self.not_improved_idx = 0
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/_dual_annealing.py in local_search(self, x, e)
#     408         # Run local search from the given x location where energy value is e
#     409         x_tmp = np.copy(x)
# --> 410         mres = self.minimizer(self.func_wrapper.fun, x, **self.kwargs)
#     411         if 'njev' in mres.keys():
#     412             self.func_wrapper.ngev += mres.njev
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     608     elif meth == 'l-bfgs-b':
#     609         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
# --> 610                                 callback=callback, **options)
#     611     elif meth == 'tnc':
#     612         return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     343             # until the completion of the current minimization iteration.
#     344             # Overwrite f and g:
# --> 345             f, g = func_and_grad(x)
#     346         elif task_str.startswith(b'NEW_X'):
#     347             # new iteration
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     288     if jac is None:
#     289         def func_and_grad(x):
# --> 290             f = fun(x, *args)
#     291             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     292             return f, g
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/scipy/optimize/_dual_annealing.py in fun(self, x)
#     372     def fun(self, x):
#     373         self.nfev += 1
# --> 374         return self.func(x, *self.args)
#     375
#     376
#
# <ipython-input-95-916b92e36366> in function_RMSE_emulator(x)
#      24     x_std = toto/STD
#      25
# ---> 26     E = function_RMSE_emulator_std(x_std)
#      27     return E
#      28
#
# <ipython-input-95-916b92e36366> in function_RMSE_emulator_std(x)
#       9     pc3 = MultiLinReg_pred_eof3(x)
#      10     pc4 = MultiLinReg_pred_eof4(x)
# ---> 11     pc5 = MultiLinReg_pred_eof5(x)
#      12
#      13     E = Error_emulator(pc1, pc2, pc3, pc4, pc5)
#
# <ipython-input-86-14ec6873293e> in MultiLinReg_pred_eof5(x)
#      11     regr.fit(X, y)
#      12     R = regr.intercept_
# ---> 13     Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]
#      14
#      15     tmp = Coeffs.values*x
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     449                         columns = data[0]._fields
#     450                     arrays, columns = to_arrays(data, columns, dtype=dtype)
# --> 451                     columns = ensure_index(columns)
#     452
#     453                     # set the index
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in ensure_index(index_like, copy)
#    5769             index_like = copy(index_like)
#    5770
# -> 5771     return Index(index_like)
#    5772
#    5773
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     443
#     444             # maybe coerce to a sub-class
# --> 445             from pandas.core.indexes.period import PeriodIndex, IncompatibleFrequency
#     446
#     447             if is_signed_integer_dtype(data.dtype):
#
# /data/scratch/globc/peatier/conda/lib/python3.7/importlib/_bootstrap.py in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
XLIM = np.array(xlim)
shape(XLIM)
# Out:
# (30, 2)

# %%
import cvxpy as cvp

def Error_emulator(pc1, pc2, pc3, pc4, pc5):
    U_obs = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/U_obs_SW.npy')
    tmp = [0]*5
    tmp[0] = (pc1-U_obs[0])
    tmp[1] = (pc1-U_obs[1])
    tmp[2] = (pc1-U_obs[2])
    tmp[3] = (pc1-U_obs[3])
    tmp[4] = (pc1-U_obs[4])
    
    tmp_cvp = cvp.vstack(tmp)
    
    E = cvp.norm(tmp_cvp/5)
    return E

def function_RMSE_emulator_std(x): 
    #mean = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_mean.npy')
    #std = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS1000_std.npy')
    #x_std = (x-mean)/std
    pc1 = MultiLinReg_pred_eof1(x)
    pc2 = MultiLinReg_pred_eof2(x)
    pc3 = MultiLinReg_pred_eof3(x)
    pc4 = MultiLinReg_pred_eof4(x)
    pc5 = MultiLinReg_pred_eof5(x)
    
    E = Error_emulator(pc1, pc2, pc3, pc4, pc5)
    return E

def function_RMSE_emulator(x): 
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    E = function_RMSE_emulator_std(x_std)
    return E

def em_fdb_std(x) :

    X = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/X_EmulateurFeedbacksN.npy")
    y = np.load(file = "/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/Net_feedbacks.npy")
    param_names = np.load(file="/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS_paramNames.npy")

    # Let's use the model equation : 

    X_df = pd.DataFrame(data=X)
    regr = linear_model.LinearRegression()
    regr.fit(X, y)
    R = regr.intercept_
    Coeffs = pd.DataFrame([regr.coef_]*30, columns=param_names).iloc[0]

    tmp = Coeffs.values*x
    y_pred = cvp.norm(tmp, 1)+R
    
    return y_pred

def em_fdb(x) :
    MEAN = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_mean.npy')
    STD = np.load('/data/home/globc/peatier/CNRMppe/PPE/ENSEMBLE2/files/npy/LHS100000_std.npy')
    
    toto = x - MEAN
    x_std = toto/STD
    
    y_pred = em_fdb_std(x_std)
    return y_pred

def constraint_fdb_low(x, fdb_low, fdb_hi):
    test=0
    fdb_x = em_fdb(x)
    test = fdb_low-fdb_x
    return test

def constraint_fdb_hi(x, fdb_low, fdb_hi):
    test=0
    fdb_x = em_fdb(x)
    test = fdb_x-fdb_hi
    return test

def constraint_x_low(x, xlim) :
    test=0
    n = 30
    for cpt in range(0,n,1) :
        i = x[cpt]
        j = xlim[cpt]
        low = j [0]
        test = low-i
    return test

def constraint_x_hi(x, xlim) :
    test=0
    n = 30
    for cpt in range(0,n,1) :
        i=x[cpt]
        j = xlim[cpt]
        test = j[1]-i
    return test



sol_list=[]
sol_fdbck=[]
for i in range(0, n, 5) :
    x0 = x_best[i]
    fdb_low = em_fdb(x0)-0.2
    print('low = '+str(fdb_low))
    fdb_hi = em_fdb(x0)+0.2
    print('hi = '+str(fdb_hi))

    n=len(x0)
    x = cvp.Variable(n)
    C_fdb_low = constraint_fdb_low(x, fdb_low, fdb_hi)
    C_fdb_hi = constraint_fdb_hi(x, fdb_low, fdb_hi)
    C_x_low = constraint_x_low(x, xlim)
    C_x_hi = constraint_x_hi(x, xlim)
    constraints=[C_x_low>=0, C_x_hi>=0, C_fdb_low<=0, C_fdb_hi<=0]
    quadratic_fct = (1+cvp.power((em_fdb(x)-fdb_low), 2)*function_RMSE_emulator(x))
    objective=cvp.Minimize(quadratic_fct)
    prob=cvp.Problem(objective, constraints)
    prob.solve()

    # Print result.
    print("\nThe optimal value is", prob.value)
    print("The optimal x is")
    print(x.value)
    
    #save result 
    tmp_fun = function_RMSE_emulator(x.value)
    tmp_fdbck = em_fdb(x.value)
    
    sol_list.append(tmp_fun)
    sol_fdbck.append(tmp_fdbck)
# Out:
# low = norm1([-0.04168117 -0.05675999 -0.01342019 -0.01378422 -0.02096709 -0.04639209
#   0.00109255 -0.0001559  -0.00441725 -0.02059429 -0.00985637 -0.0769067
#  -0.00356818 -0.01822911  0.0120812  -0.04814801 -0.04132098  0.00059666
#  -0.01859128 -0.0107859   0.00150137 -0.03257224 -0.05997294 -0.01084137
#  -0.0066892  -0.02028034  0.00602214 -0.01912647 -0.05534847  0.00321998]) + -1.365035703564002 + -0.2
# hi = norm1([-0.04168117 -0.05675999 -0.01342019 -0.01378422 -0.02096709 -0.04639209
#   0.00109255 -0.0001559  -0.00441725 -0.02059429 -0.00985637 -0.0769067
#  -0.00356818 -0.01822911  0.0120812  -0.04814801 -0.04132098  0.00059666
#  -0.01859128 -0.0107859   0.00150137 -0.03257224 -0.05997294 -0.01084137
#  -0.0066892  -0.02028034  0.00602214 -0.01912647 -0.05534847  0.00321998]) + -1.365035703564002 + 0.2
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/expressions/expression.py:550: UserWarning:
# This use of ``*`` has resulted in matrix multiplication.
# Using ``*`` for matrix multiplication has been deprecated since CVXPY 1.1.
#     Use ``*`` for matrix-scalar and vector-scalar multiplication.
#     Use ``@`` for matrix-matrix and matrix-vector multiplication.
#     Use ``multiply`` for elementwise multiplication.
#
#   warnings.warn(__STAR_MATMUL_WARNING__, UserWarning)
# ---------------------------------------------------------------------------
# DCPError                                  Traceback (most recent call last)
# <ipython-input-31-495d4aaaadc7> in <module>
#     119     objective=cvp.Minimize(quadratic_fct)
#     120     prob=cvp.Problem(objective, constraints)
# --> 121     prob.solve()
#     122
#     123     # Print result.
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/problems/problem.py in solve(self, *args, **kwargs)
#     394         else:
#     395             solve_func = Problem._solve
# --> 396         return solve_func(self, *args, **kwargs)
#     397
#     398     @classmethod
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/problems/problem.py in _solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, **kwargs)
#     749
#     750         data, solving_chain, inverse_data = self.get_problem_data(
# --> 751             solver, gp, enforce_dpp)
#     752         solution = solving_chain.solve_via_data(
#     753             self, data, warm_start, verbose, kwargs)
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/problems/problem.py in get_problem_data(self, solver, gp, enforce_dpp)
#     498             self._cache.invalidate()
#     499             solving_chain = self._construct_chain(
# --> 500                 solver=solver, gp=gp, enforce_dpp=enforce_dpp)
#     501             self._cache.key = key
#     502             self._cache.solving_chain = solving_chain
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/problems/problem.py in _construct_chain(self, solver, gp, enforce_dpp)
#     657         candidate_solvers = self._find_candidate_solvers(solver=solver, gp=gp)
#     658         return construct_solving_chain(self, candidate_solvers, gp=gp,
# --> 659                                        enforce_dpp=enforce_dpp)
#     660
#     661     def _invalidate_cache(self):
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/reductions/solvers/solving_chain.py in construct_solving_chain(problem, candidates, gp, enforce_dpp)
#     149     if len(problem.variables()) == 0:
#     150         return SolvingChain(reductions=[ConstantSolver()])
# --> 151     reductions = _reductions_for_problem_class(problem, candidates, gp)
#     152
#     153     dpp_context = 'dcp' if not gp else 'dgp'
#
# /data/scratch/globc/peatier/conda/lib/python3.7/site-packages/cvxpy/reductions/solvers/solving_chain.py in _reductions_for_problem_class(problem, candidates, gp)
#      88                        "Consider calling solve() with `qcp=True`.")
#      89         raise DCPError(
# ---> 90             "Problem does not follow DCP rules. Specifically:\n" + append)
#      91     elif gp and not problem.is_dgp():
#      92         append = build_non_disciplined_error_msg(problem, 'DGP')
#
# DCPError: Problem does not follow DCP rules. Specifically:
# The objective is not DCP. Its following subexpressions are not:
# power(norm1([ 0.03847749  0.0502766  -0.01734912 -0.00804528 -0.01691706 -0.03403901
#  -0.00162956  0.0033209  -0.00664972 -0.02602384  0.01229661  0.04602391
#  -0.01859279 -0.01828244  0.01813825 -0.05202418 -0.03342469  0.00113848
#  -0.01883585  0.01788228  0.00353349 -0.01928315 -0.07804344 -0.01530645
#   0.01619802 -0.01814975 -0.00896795  0.01136166  0.03710728  0.00881924] @ ((var240 + -[ 1.70000002e-01  1.74999997e+00  1.74999999e+00  1.50000000e+01
#  -2.54999997e-01  5.00000009e+00  4.99999993e+00  5.24999992e-03
#   5.24999999e-04  5.24999991e-03  2.14975756e-07  5.24999992e-05
#   1.00500000e-01  1.00500002e-01  3.05000002e+00  3.05000003e+00
#   4.99999993e-05  3.39999996e-04  6.00000002e-06  7.49999990e-05
#  -3.00000001e+00 -3.74999998e+01  5.50000002e-02  9.99999975e+00
#   5.50000000e-05  7.49999996e-01  7.49999996e-01  7.49999998e-01
#   7.49999997e-01  5.10000005e+00]) / [6.35088493e-02 7.21691424e-01 7.21691465e-01 8.66029704e+00
#  1.41451527e-01 2.88676595e+00 2.88676567e+00 2.74242739e-03
#  2.74242730e-04 2.74242759e-03 2.49697422e-07 2.74242749e-05
#  5.74466393e-02 5.74466398e-02 1.70319186e+00 1.70319194e+00
#  1.15470636e-05 1.50111817e-04 2.30941269e-06 2.59808925e-05
#  1.15470632e+00 7.21691457e+00 2.59808920e-02 5.77353161e+00
#  2.59808914e-05 1.44338287e-01 1.44338296e-01 1.44338289e-01
#  1.44338294e-01 2.82903040e+00])) + -1.365035703564002 + -norm1([-0.04168117 -0.05675999 -0.01342019 -0.01378422 -0.02096709 -0.04639209
#   0.00109255 -0.0001559  -0.00441725 -0.02059429 -0.00985637 -0.0769067
#  -0.00356818 -0.01822911  0.0120812  -0.04814801 -0.04132098  0.00059666
#  -0.01859128 -0.0107859   0.00150137 -0.03257224 -0.05997294 -0.01084137
#  -0.0066892  -0.02028034  0.00602214 -0.01912647 -0.05534847  0.00321998]) + -1.365035703564002 + -0.2, 2.0)

# %%
#sol_list.append(0)
#sol_list.append(0)
#sol_list.append(0)
#sol_list.append(0)
#sol_list.append(0)
sol_df = pd.DataFrame()
sol_df['sol_fun'] = sol_list[:]
#sol_df['RMSE'] = new_df['E_multilinreg_pred_best']
sol_df['Fdbck'] = sol_fdbck[:]
#sol_df = sol_df.sort_values(by=['Fdbck'])
sol_df
# Out:
#          sol_fun     Fdbck
# 0   1.343381e-06 -2.047267
# 1   3.561750e-06 -1.718911
# 2   3.536372e-07 -1.753136
# 3   2.478201e-06 -1.525456
# 4   1.264069e-06 -1.472157
# 5   1.588653e-06 -1.576327
# 6   5.167152e-07 -1.578346
# 7   1.424550e-06 -1.429366
# 8   1.493806e-06 -1.362324
# 9   2.249972e-06 -1.501825
# 10  8.611493e-07 -1.426947
# 11  2.437636e-06 -1.295850

# %%
ax = plt.gca()


#plt.plot(Fdbck_MRI, E_MRI, color='orange', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_CAN, E_CAN, color='navy', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_MIROC, E_MIROC, color='darkred', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_HadGEM3, E_HadGEM3, color='darkgray', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_IPSL, E_IPSL, color='pink', marker='^', linewidth=0, markersize=12)
#plt.plot(Fdbck_BCC, E_BCC, color='blue', marker='^', linewidth=0, markersize=12)

#E_multilinreg_val_df.plot(kind='scatter', x='Fdbck_val', y='E_multilinreg_val', color='black', alpha=1, figsize=(15, 12), 
#                     marker='x', ax = ax)

new_df.plot(kind='scatter', x='Fdbck_pred', y='E_multilinreg_pred_best', color = 'blue', 
         marker = '^', linewidth=8,  ax = ax)

sol_df.plot(kind='scatter', x='Fdbck', y='sol_fun', color = 'black', 
         marker = '^', linewidth=8, ax = ax)

E_multilinreg_pred_df.plot(kind='scatter', x='Fdbck_pred', y='E_multilinreg_pred', 
                           color='gray', alpha=0.4, figsize=(15, 12), marker='o', ax = ax)

#E_lasso_pred_df.plot(kind='scatter', x='Fdbck_pred', y='E_lasso_pred', 
#                           color='lightblue', alpha=0.4, figsize=(15, 12), marker='o', ax = ax)

#E_PPE_df.plot(kind='scatter', x='Fdbck', y='E_PPE', color='black', figsize=(15, 12), 
#                     marker="o", ax = ax)



#plt.hlines(E_p1,xmin = -4.0,xmax = 2.0,label='default simulation', colors='black', 
#           linestyles='dashed')
#plt.vlines(p1_feedbacks,ymin = 0,ymax = 25,label='default simulation', colors='black', 
#           linestyles='dashed')



legend = ['By hand', 'Minimization function', 'PPE']

title = 'Short Wave fluxes ($W.m^{-2}$)'
plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel('RMSE [PPE - CERES]', fontsize=22)
plt.legend(legend, fontsize=15)
plt.title(title, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(-0.5,4)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/RMSE_SW_PPE_pred.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %% [markdown]
# # Likelihood

# %%
std_PPE = E_PPE_df['E_PPE'].std()
std_multilinreg = E_multilinreg_pred_df['E_multilinreg_pred'].std() 
std_lasso = E_lasso_pred_df['E_lasso_pred'].std() 
std_multilinreg
# Out:
# 0.37128055596307924

# %%
OSE_multilinreg = sqrt((fluxes_biases['OSE_multilinreg']**2).mean())
tmp_multilinreg = (Likelihood_multilinreg['E_multilinreg_pred'])/(OSE_multilinreg)
toto = 1/(sqrt(2*pi*(OSE_multilinreg)))
Likelihood_multilinreg['likelihood_OSE'] = toto*e**(-tmp_multilinreg)

OSE_lasso = sqrt((fluxes_biases['OSE_lasso']**2).mean())
tmp_lasso = (Likelihood_lasso['E_lasso_pred'])/(OSE_lasso)
toto = 1/(sqrt(2*pi*(OSE_lasso)))
Likelihood_lasso['likelihood_OSE'] = toto*e**(-tmp_lasso)
Likelihood_lasso
# Out:
#    Fdbck_pred_round  E_lasso_pred  Fdbck_pred  likelihood_OSE
# 0              -1.8      1.739437   -1.799139        0.000965
# 1              -1.7      1.259936   -1.745091        0.006118
# 2              -1.6      0.952399   -1.649941        0.019995
# 3              -1.5      0.684269   -1.549999        0.056149
# 4              -1.4      0.649492   -1.449998        0.064195
# 5              -1.3      0.731298   -1.349999        0.046848
# 6              -1.2      0.737225   -1.249996        0.045791
# 7              -1.1      0.839962   -1.149988        0.030829
# 8              -1.0      1.271067   -1.049543        0.005861

# %%
ax = plt.gca()

plt.vlines(Fdbck_MRI, ymin = 0,ymax = 25, color='orange', linestyles='solid', linewidth = 1)
plt.vlines(Fdbck_CAN, ymin = 0,ymax = 25, color='navy', linestyles='solid', linewidth = 1)
plt.vlines(Fdbck_MIROC, ymin = 0,ymax = 25, color='darkred', linestyles='solid', linewidth = 1)
plt.vlines(Fdbck_HadGEM3, ymin = 0,ymax = 25, color='darkgray', linestyles='solid', linewidth = 1)
plt.vlines(Fdbck_IPSL, ymin = 0,ymax = 25, color='pink', linestyles='solid', linewidth = 1)
plt.vlines(Fdbck_BCC, ymin = 0,ymax = 25, color='blue', linestyles='solid', linewidth = 1)

#Likelihood_multilinreg.plot(kind='line', x='Fdbck_pred_round', y='likelihood_std', color = 'black',figsize=(15, 12), 
#         linewidth = 3.5, ax = ax)
Likelihood_multilinreg.plot(kind='line', x='Fdbck_pred_round', y='likelihood_OSE', color = 'black',
         linewidth = 3.5, ax = ax)

#Likelihood_lasso.plot(kind='line', x='Fdbck_pred_round', y='likelihood_std', color = 'blue', alpha = 0.6,
#                      figsize=(15, 12), linewidth = 3.5, ax = ax)
Likelihood_lasso.plot(kind='line', x='Fdbck_pred_round', y='likelihood_OSE', color = 'blue', alpha = 0.6,
                      figsize=(15, 12), linewidth = 3.5, ax = ax)

plt.vlines(p1_feedbacks,ymin = 0,ymax = 25,label='default simulation', colors='black', 
           linestyles='dashed', linewidth = 2)



legend = ['MultiLinreg likelihood', 'LASSO likelihood','MRI model', 'CAN model', 'MIROC model', 'HadGEM3 model', 'IPSL model',
          'BCC model',  'CNRM default model']

title = 'Short wave fluxes ($W.m^{-2}$) - Likelihood'
plt.xlabel('Global Net Feedbacks ($W.m^2.K^{-1}$)', fontsize=22)
plt.ylabel('$L \sim e^{-\ RMSE\ /\ emulator\ error}$', fontsize=22)
plt.legend(legend, fontsize=15, framealpha=1)
plt.title(title, fontsize=30)
ax.tick_params(axis='both', which='major', labelsize=15)
plt.ylim(0,0.25)
plt.xlim(-2.2,-0.5)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/likelihood_SW_PPE_pred.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

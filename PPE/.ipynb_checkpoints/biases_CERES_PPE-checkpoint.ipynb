# %% [markdown]
# # Global feedbacks analysis in CNRM-CM6-1 PPE
# Here we want to read the global annual mean of the radiative budget and air surface temperature in the amip and amip-futre4K PPE. We then compute the global feedbacks over the five years simulated, and plot a linegraph of the results across the ensemble.

# %% [markdown]
# # Importe modules

# %%
# Computational modules 
# %matplotlib inline
import xarray as xr
import glob
import os
import numpy as np
import netCDF4
from netCDF4 import Dataset
import pandas as pd
import re
from array import array
from pylab import *
#import geopandas

# Plotting modules 
import matplotlib.pyplot as plt
#from mpl_toolkits.basemap import Basemap
import pandas.plotting
import matplotlib.ticker as ticker
import seaborn as sns

# %% [markdown]
# # Functions definition

# %%
import sys
sys.path.append('/data/home/globc/peatier/CNRMppe')
import Fonctions
from Fonctions import get_wavg_budget_df
from Fonctions import wavg 
from Fonctions import plotlines_Xdf
from Fonctions import plotlines_1df
from Fonctions import Deltas_Lambda

# %% [markdown]
# # Read files : radiative budget, tas

# %% [markdown]
# ## First PPE : amip and future4K

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# The amip experiment : 

path=path_official
filename='*_amip_*.nc'
start_yr=1979
drop=True
year_list=range(1984,2015,1)
official_amip = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)

path=path_PPE+'CNRM-CM6-1_amip_PPE/CNRM-CM6-1_amip_r1i1p1f2/'
start_yr=1979
drop=False
year_list=None
p1_amip = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)


nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
            'p133',  'p193', 'p13',  'p195',  'p93', 'p140',    'p57', 'p142',   'p58', \
            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
            'p297', 'p2', 'p4']

N=len(nb_p_list)
start_yr=1979
amip={}
i = 0
while i<N:
    nb_p = nb_p_list[i]
    print(nb_p)
    path=path_PPE+'CNRM-CM6-1_amip_PPE/CNRM-CM6-1_amip_r1i1'+str(nb_p)+'f2/'
    amip[str(nb_p) + "_amip"] = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
    i=i+1
# Out:
# p105
# p30
# p65
# p15
# p109
# p160
# p34
# p111
# p36
# p122
# p39
# p83
# p123
# p88
# p184
# p131
# p49
# p133
# p193
# p13
# p195
# p93
# p140
# p57
# p142
# p58
# p144
# p148
# p14
# p209
# p216
# p218
# p222
# p227
# p244
# p245
# p249
# p254
# p255
# p262
# p269
# p279
# p281
# p287
# p294
# p297
# p2
# p4

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# The amip-future4K experiment : 

path=path_official
filename='*_amip-future4K_*.nc'
start_yr=1979
drop=True
year_list=range(1984,2015,1)
official_future4K = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)

path=path_PPE+'CNRM-CM6-1_amip-future4K_PPE/CNRM-CM6-1_amip-future4K_r1i1p1f2/'
start_yr=1951
drop=False
year_list=None
p1_future4K = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)


nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
            'p133',  'p193', 'p13',  'p195',  'p93', 'p140',    'p57', 'p142',   'p58', \
            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
            'p297', 'p2', 'p4']
N=len(nb_p_list)
start_yr=1979
future4K={}
i = 0
while i<N:
    nb_p = nb_p_list[i]
    print(nb_p)
    path=path_PPE+'CNRM-CM6-1_amip-future4K_PPE/CNRM-CM6-1_amip-future4K_r1i1'+str(nb_p)+'f2/'
    future4K[str(nb_p) + "_future4k"] = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
    i=i+1
# Out:
# p105
# p30
# p65
# p15
# p109
# p160
# p34
# p111
# p36
# p122
# p39
# p83
# p123
# p88
# p184
# p131
# p49
# p133
# p193
# p13
# p195
# p93
# p140
# p57
# p142
# p58
# p144
# p148
# p14
# p209
# p216
# p218
# p222
# p227
# p244
# p245
# p249
# p254
# p255
# p262
# p269
# p279
# p281
# p287
# p294
# p297
# p2
# p4

# %% [markdown]
# ## First PPE without out of limits ALFX/RKDN : amip and future4K

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# The amip experiment, without the out-of-limits ALFX/RKDN simulations: 

path=path_official
filename='*_amip_*.nc'
start_yr=1979
drop=True
year_list=range(1984,2015,1)
official_amip = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)

path=path_PPE+'CNRM-CM6-1_amip_PPE/CNRM-CM6-1_amip_r1i1p1f2/'
start_yr=1979
drop=False
year_list=None
p1_amip = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)


nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
            'p133',  'p193', 'p13',  'p195', 'p140', 'p142', 'p58', \
            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p294', \
            'p297', 'p2', 'p4']

N=len(nb_p_list)
start_yr=1979
amip={}
i = 0
while i<N:
    nb_p = nb_p_list[i]
    print(nb_p)
    path=path_PPE+'CNRM-CM6-1_amip_PPE/CNRM-CM6-1_amip_r1i1'+str(nb_p)+'f2/'
    amip[str(nb_p) + "_amip"] = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
    i=i+1
# Out:
# p105
# p30
# p65
# p15
# p109
# p160
# p34
# p111
# p36
# p122
# p39
# p83
# p123
# p88
# p184
# p131
# p49
# p133
# p193
# p13
# p195
# p140
# p142
# p58
# p144
# p148
# p14
# p209
# p216
# p218
# p222
# p227
# p244
# p245
# p249
# p254
# p255
# p262
# p269
# p279
# p281
# p294
# p297
# p2
# p4

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# The amip-future4K experiment, without the out-of-limits ALFX/RKDN simulations:

path=path_official
filename='*_amip-future4K_*.nc'
start_yr=1979
drop=True
year_list=range(1984,2015,1)
official_future4K = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)

path=path_PPE+'CNRM-CM6-1_amip-future4K_PPE/CNRM-CM6-1_amip-future4K_r1i1p1f2/'
start_yr=1951
drop=False
year_list=None
p1_future4K = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)


nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
            'p133',  'p193', 'p13',  'p195', 'p140', 'p142', 'p58', \
            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p294', \
            'p297', 'p2', 'p4']

N=len(nb_p_list)
start_yr=1979
future4K={}
i = 0
while i<N:
    nb_p = nb_p_list[i]
    print(nb_p)
    path=path_PPE+'CNRM-CM6-1_amip-future4K_PPE/CNRM-CM6-1_amip-future4K_r1i1'+str(nb_p)+'f2/'
    future4K[str(nb_p) + "_future4k"] = get_wavg_budget_df(path, filename, variables, start_yr, drop, year_list)
    i=i+1
# Out:
# p105
# p30
# p65
# p15
# p109
# p160
# p34
# p111
# p36
# p122
# p39
# p83
# p123
# p88
# p184
# p131
# p49
# p133
# p193
# p13
# p195
# p140
# p142
# p58
# p144
# p148
# p14
# p209
# p216
# p218
# p222
# p227
# p244
# p245
# p249
# p254
# p255
# p262
# p269
# p279
# p281
# p294
# p297
# p2
# p4

# %% [markdown]
# ## Second PPE : amip and amip-future4K

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
nb_p_list_LHS500 =['p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412']
N=len(nb_p_list_LHS500)
amip_LHS500={}
i = 0
while i<N:
    nb_p_LHS500 = nb_p_list_LHS500[i]
    print(nb_p_LHS500)
    path=path_PPE+'CNRM-CM6-1_amip_LHS500_PPE/CNRM-CM6-1_amip_r1i1'+nb_p_LHS500+'f2/'
    filename = '*_CNRM-CM6-1_amip_r1i1'+nb_p_LHS500+'f2*.nc'
    amip_LHS500[str(nb_p_LHS500) + "_amip"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# p311
# p312
# p314
# p316
# p317
# p319
# p320
# p321
# p322
# p324
# p325
# p326
# p329
# p330
# p331
# p332
# p335
# p336
# p337
# p338
# p340
# p341
# p343
# p344
# p346
# p347
# p348
# p349
# p350
# p353
# p355
# p357
# p359
# p360
# p361
# p363
# p365
# p367
# p368
# p369
# p372
# p373
# p374
# p375
# p376
# p378
# p381
# p382
# p384
# p386
# p388
# p389
# p391
# p392
# p393
# p394
# p395
# p396
# p398
# p399
# p400
# p404
# p406
# p407
# p409
# p410
# p411
# p412

# %%
path_official='/data/scratch/globc/peatier/CMIP6/CNRM-CM6-1/CFMIP/amip/'
path_PPE='/data/scratch/globc/peatier/CNRM-CM6-1_PPE/'
variables = ['rlut', 'rsut','rsdt','tas']

# The amip experiments, new ensemble LHS500 : 

start_yr=1979
drop=False
year_list=None
nb_p_list_LHS500 = ['p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412']
N=len(nb_p_list_LHS500)
future4K_LHS500={}
i = 0
while i<N:
    nb_p_LHS500 = nb_p_list_LHS500[i]
    print(nb_p_LHS500)
    path=path_PPE+'CNRM-CM6-1_amip-future4K_LHS500_PPE/CNRM-CM6-1_amip-future4K_r1i1'+nb_p_LHS500+'f2/'
    filename = '*_CNRM-CM6-1_amip-future4K_r1i1'+nb_p_LHS500+'f2*.nc'
    future4K_LHS500[str(nb_p_LHS500) + "_future4K"] = get_wavg_budget_df(path, filename, variables, \
                                                                start_yr, drop, year_list)
    i=i+1
# Out:
# p311
# p312
# p314
# p316
# p317
# p319
# p320
# p321
# p322
# p324
# p325
# p326
# p329
# p330
# p331
# p332
# p335
# p336
# p337
# p338
# p340
# p341
# p343
# p344
# p346
# p347
# p348
# p349
# p350
# p353
# p355
# p357
# p359
# p360
# p361
# p363
# p365
# p367
# p368
# p369
# p372
# p373
# p374
# p375
# p376
# p378
# p381
# p382
# p384
# p386
# p388
# p389
# p391
# p392
# p393
# p394
# p395
# p396
# p398
# p399
# p400
# p404
# p406
# p407
# p409
# p410
# p411
# p412

# %% [markdown]
# ## Create plot

# %%
# PARAMETERS :
n=len(future4K)+2
df=[None]*n
df[0] = official_future4K
df[1] = p1_future4K
df[2:] = [future4K[i+"_future4k"] for i in nb_p_list]
df[(n+1):] = [future4K_LHS500[i+"_future4K"] for i in nb_p_list_LHS500]
cmap1 = plt.get_cmap('ocean')
cmap2 = plt.get_cmap('Reds')
colors = [cmap1(i) for i in np.linspace(0, 1, (len(future4K)+2))]
colors[(n+1):] = [cmap2(i) for i in np.linspace(0, 1, len(nb_p_list_LHS500))]
linewidth = [4.0, 4.0]
i=0
N=len(df)
while i<N:
    linewidth.append(1.5)
    i=i+1
    
xlabel = 'years'
xmin = 0
xmax = 2
legend = ['official', 'p1', 'Other perturbations']

# Plot of lines from different dataframes
plt.subplots(figsize=(10,10)) 

plt.subplot(211)
title = 'CNRM-CM6-1 amip-future4 : TOA net downward radiative flux, N [W.m^2]'
y = 'N'
ymin = -40.0
ymax = 20.0
plotlines_Xdf(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)

plt.subplot(212)
title='CNRM-CM6-1 amip-future4 : air surface temperature, tas [K]'
y = 'tas'
ymin = 290.0
ymax = 293.5
plotlines_Xdf(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure .....................

#plt.savefig("/data/home/globc/peatier/figures/longPPE_N_tas_future4K.png", 
#        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %%
# PARAMETERS :
n=len(amip)+2
df=[None]*n
df[0] = official_amip
df[1] = p1_amip
df[2:] = [amip[i+"_amip"] for i in nb_p_list]
df[(n+1):] = [amip_LHS500[i+"_amip"] for i in nb_p_list_LHS500]
cmap1 = plt.get_cmap('ocean')
cmap2 = plt.get_cmap('Reds')
colors = [cmap1(i) for i in np.linspace(0, 1, len(future4K)+2)]
colors[(n+1):] = [cmap2(i) for i in np.linspace(0, 1, len(nb_p_list_LHS500))]
linewidth = [4.0]
i=0
N=len(df)
while i<N:
    linewidth.append(1.5)
    i=i+1
    
xlabel = 'years'
xmin = 0
xmax = 2
legend = ['official', 'p1', 'Other perturbations']

# Plot of lines from different dataframes
plt.subplots(figsize=(10,10)) 

plt.subplot(211)
title = 'CNRM-CM6-1 amip : TOA net downward radiative flux, N [W.m^2]'
y = 'N'
ymin = -30.0
ymax = 20.0
plotlines_Xdf(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)

plt.subplot(212)
title='CNRM-CM6-1 amip : air surface temperature, tas [K]'
y = 'tas'
ymin = 285.5
ymax = 288.5
plotlines_Xdf(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure .....................

plt.savefig("/data/home/globc/peatier/figures/longPPE_N_tas_amip.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Show la figure .................
plt.show()

# %% [markdown]
# # Compute : Delta(TOA), Delta(tas), Lambda

# %%
# We want to compute the Deltas and the feedbacks of each perturbations (amip - amip-future4K)
result= pd.DataFrame()
#df_CTL = official_amip
#df = official_future4K
#expe_name = 'official_future4K'
n = len(amip_LHS500["p311_amip"])
#result = Deltas_Lambda(result, df_CTL, df, expe_name, n)

#df_CTL = p1_amip
#df=p1_future4K
#expe_name='p1_future4K'
#n=len(p1_future4K)
#result = Deltas_Lambda(result, df_CTL, df, expe_name, n)

#for i in nb_p_list:
#    df_CTL = amip[i+"_amip"]
#    df = future4K[i+"_future4k"]
#    expe_name=str(i+"_future4k")
#    result = Deltas_Lambda(result, df_CTL, df, expe_name, n)

for j in nb_p_list_LHS500:
    df_CTL = amip_LHS500[j+"_amip"]
    df = future4K_LHS500[j+"_future4K"]
    expe_name=str(j+"_future4k")
    result = Deltas_Lambda(result, df_CTL, df, expe_name, n)
    
result
# Out:
#    Delta_N_p311_future4k  Delta_tas_p311_future4k  Lambda_p311_future4k  \
# 0              -3.211578                 4.470459             -0.718400
# 1              -3.755661                 4.568604             -0.822059
# 2              -3.805644                 4.603088             -0.826759
#
#    Delta_N_p312_future4k  Delta_tas_p312_future4k  Lambda_p312_future4k  \
# 0              -7.642731                 4.529877             -1.687183
# 1              -7.616730                 4.608215             -1.652859
# 2              -7.686340                 4.632223             -1.659320
#
#    Delta_N_p314_future4k  Delta_tas_p314_future4k  Lambda_p314_future4k  \
# 0              -5.525848                 4.514954             -1.223899
# 1              -5.546112                 4.607910             -1.203607
# 2              -5.623830                 4.629293             -1.214836
#
#    Delta_N_p316_future4k  ...  Lambda_p409_future4k  Delta_N_p410_future4k  \
# ...

# %% [markdown]
# ## To store feedbacks and Delta T values in numpy arrays

# %%
# List sans les outliers
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p122',  'p39', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

# List avec les outliers 
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140',    'p57', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

# List avec les outliers, sans les out of limits ALFX/RKDN
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195', 'p140', 'p142', 'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p294', \
#            'p297', 'p2', 'p4']

# List nouvel ensemble LHS500
nb_p_list_LHS500 = ['p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412']
#N1=len(nb_p_list)
N2=len(nb_p_list_LHS500) 
NetFdbck = [1]*(N2)
i=0
while i<N2:
    nb_p = nb_p_list_LHS500[i]
    #print(nb_p)
    NetFdbck[i] = result['Lambda_'+str(nb_p)+'_future4k'].mean()
    i=(i+1)

# %%
#j=0
#while j<N2:
#    nb_p = nb_p_list_LHS500[j]
#    #print(nb_p)
#    NetFdbck[j+i] = result['Lambda_'+str(nb_p)+'_future4k'].mean()
#    j=(j+1)
    
NetFdbck
# Out:
# [-0.789072593053182,
#  -1.6664539575576782,
#  -1.2141139109929402,
#  -1.2924147844314575,
#  -0.7565249999364217,
#  -1.4373774925867717,
#  -1.4397347370783489,
#  -1.4202063083648682,
#  -1.4801061948140461,
#  -1.376619021097819,
#  -1.487390677134196,
#  -1.2240698337554932,
#  -1.597002387046814,
#  -1.2837746540705364,
#  -1.339022119839986,
#  -1.0393349726994832,
#  -1.2973190148671467,
#  -1.240178902943929,
#  -1.344469944636027,
#  -1.0133037964502971,
#  -1.6102404197057087,
#  -1.5873286724090576,
#  -1.3167645931243896,
#  -1.334736744562785,
#  -0.7188581824302673,
#  -1.390901764233907,
#  -1.6958694060643513,
#  -1.5308719873428345,
#  -1.4534247318903606,
#  -1.4798837105433147,
#  -1.2322567701339722,
#  -1.4927332798639934,
#  -1.3301920493443806,
#  -1.4101204474767048,
#  -1.444406270980835,
#  -1.5286922852198284,
#  -1.5675355990727742,
#  -1.5165267785390217,
#  -1.5076420307159424,
#  -0.8460754950841268,
#  -1.093109369277954,
#  -1.1694682836532593,
# ...

# %%
# Save the numpy array in a file   
np.save('/data/home/globc/peatier/CNRMppe/PPE/Net_feedbacks.npy', NetFdbck)

# %%
# List sans les outliers
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p122',  'p39', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

# List avec les outliers 
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140',    'p57', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

# List avec les outliers, sans les out of limits ALFX/RKDN
nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
            'p133',  'p193', 'p13',  'p195', 'p140', 'p142', 'p58', \
            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p294', \
            'p297', 'p2', 'p4']

# List nouvel ensemble LHS500
nb_p_list_LHS500 = ['p301',  'p302',  'p304',  'p308', 'p309', 'p311', 'p312', 'p314', 'p316',
                    'p317', 'p319', 'p320', 'p321', 'p322', 'p324', 'p325', 'p326', 
                    'p329', 'p330', 'p331', 'p332', 'p335', 'p336', 'p337' ,'p338', 
                    'p340', 'p341', 'p343', 'p344', 'p346', 'p347', 'p348', 'p349', 
                    'p350', 'p353', 'p355', 'p357', 'p359', 'p360', 
                    'p361', 'p363', 'p365', 'p367', 'p368', 'p369', 
                    'p372', 'p373', 'p374', 'p375', 'p376', 'p378', 'p381', 'p382', 
                    'p384', 'p386', 'p388', 'p389', 'p391', 'p392', 'p393', 
                    'p394', 'p395', 'p396', 'p398', 'p399', 'p400', 'p404', 
                    'p406', 'p407', 'p409', 'p410', 'p411', 'p412']

N1=len(nb_p_list)
N2=len(nb_p_list_LHS500)
DeltaT_global_mean = [1]*(N1 + N2)
i=0
while i<N1:
    nb_p = nb_p_list[i]
    #print(nb_p)
    DeltaT_global_mean[i] = result['Delta_tas_'+str(nb_p)+'_future4k'].mean()
    i=(i+1)
    

j=0
while j<N2:
    nb_p = nb_p_list_LHS500[j]
    #print(nb_p)
    DeltaT_global_mean[j+i] = result['Delta_tas_'+str(nb_p)+'_future4k'].mean()
    j=(j+1)
    
DeltaT_global_mean
# Out:
# [4.490231513977051,
#  5.003962135314941,
#  5.718410778045654,
#  5.1604866027832035,
#  4.410923957824707,
#  4.6235052108764645,
#  4.532820701599121,
#  4.698164558410644,
#  5.034015083312989,
#  4.53431806564331,
#  4.579755592346191,
#  5.138950347900391,
#  4.560984516143799,
#  4.592790222167968,
#  4.700156879425049,
#  4.529298496246338,
#  5.099740695953369,
#  4.748343658447266,
#  4.52826509475708,
#  5.376479053497315,
#  4.486078929901123,
#  4.610182666778565,
#  4.877181529998779,
#  4.766880226135254,
#  4.545875358581543,
#  4.64040174484253,
#  5.4845436096191404,
#  4.675168895721436,
#  4.3999251365661625,
#  4.621820640563965,
#  4.587301445007324,
#  4.632019519805908,
#  4.569245624542236,
#  4.870308208465576,
#  4.567762851715088,
#  4.562679481506348,
#  4.533415794372559,
#  4.544083881378174,
#  4.802361297607422,
#  4.572002696990967,
#  4.716209602355957,
#  4.4720690727233885,
#  4.645647621154785,
#  5.5567240715026855,
#  4.9648027420043945,
# ...

# %%
# Save the numpy array in a file
np.save('/data/home/globc/peatier/CNRMppe/PPE/DeltaT_global_mean.npy', DeltaT_global_mean)

# %%
# List sans les outliers
nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
            'p122',  'p39', 'p123', 'p88', 'p184', 'p131',  'p49', \
            'p133',  'p193', 'p13',  'p195',  'p93', 'p140', 'p142',   'p58', \
            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
            'p297', 'p2', 'p4']

# List avec les outliers 
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140',    'p57', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

N=len(nb_p_list)
DeltaT_NoOut_global_mean = [1]*N
i=0
while i<N:
    nb_p = nb_p_list[i]
    #print(nb_p)
    DeltaT_NoOut_global_mean[i] = result['Delta_tas_'+str(nb_p)+'_future4k'].mean()
    i=(i+1)
    
DeltaT_NoOut_global_mean
# Out:
# [4.490231513977051,
#  5.003962135314941,
#  5.718410778045654,
#  5.1604866027832035,
#  4.410923957824707,
#  4.6235052108764645,
#  4.532820701599121,
#  4.698164558410644,
#  4.53431806564331,
#  4.579755592346191,
#  4.560984516143799,
#  4.592790222167968,
#  4.700156879425049,
#  4.529298496246338,
#  5.099740695953369,
#  4.748343658447266,
#  4.52826509475708,
#  5.376479053497315,
#  4.486078929901123,
#  4.651389789581299,
#  4.610182666778565,
#  4.877181529998779,
#  4.766880226135254,
#  4.545875358581543,
#  4.64040174484253,
#  5.4845436096191404,
#  4.675168895721436,
#  4.3999251365661625,
#  4.621820640563965,
#  4.587301445007324,
#  4.632019519805908,
#  4.569245624542236,
#  4.870308208465576,
#  4.567762851715088,
#  4.562679481506348,
#  4.533415794372559,
#  4.544083881378174,
#  4.802361297607422,
#  4.572002696990967,
#  4.716209602355957,
#  4.7042341232299805,
#  4.4720690727233885,
#  4.645647621154785,
#  5.5567240715026855,
#  4.9648027420043945]

# %%
# Save the numpy array PCs in a file for the Multi Linear Regression   
np.save('/data/home/globc/peatier/CNRMppe/PPE/DeltaT_NoOut_global_mean.npy', DeltaT_NoOut_global_mean)

# %%
# List sans les outliers
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p122',  'p39', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

# List avec les outliers 
#nb_p_list = ['p105',  'p30',  'p65', 'p15', 'p109',  'p160',  'p34', 'p111', \
#            'p36', 'p122',  'p39',  'p83', 'p123', 'p88', 'p184', 'p131',  'p49', \
#            'p133',  'p193', 'p13',  'p195',  'p93', 'p140',    'p57', 'p142',   'p58', \
#            'p144', 'p148', 'p14', 'p209', 'p216', 'p218', 'p222', 'p227', 'p244', \
#            'p245', 'p249', 'p254', 'p255', 'p262', 'p269', 'p279', 'p281', 'p287', 'p294', \
#            'p297', 'p2', 'p4']

# List des outliers 
nb_p_list = ['p36',  'p57',  'p83']


N=len(nb_p_list)
DeltaT_Out_global_mean = [1]*N
i=0
while i<N:
    nb_p = nb_p_list[i]
    #print(nb_p)
    DeltaT_Out_global_mean[i] = result['Delta_tas_'+str(nb_p)+'_future4k'].mean()
    i=(i+1)
    
DeltaT_Out_global_mean
# Out:
# [5.034015083312989, 5.422612285614013, 5.138950347900391]

# %%
# Save the numpy array PCs in a file for the Multi Linear Regression   
np.save('/data/home/globc/peatier/CNRMppe/PPE/DeltaT_Out_global_mean.npy', DeltaT_Out_global_mean)

# %% [markdown]
# # Create plot

# %%
# PARAMETERS
df = result
cmap1 = plt.get_cmap('ocean')
cmap2 = plt.get_cmap('Reds')
xlabel='years'
xmin = 0
xmax = 2
legend=['official', 'p1', 'Other perturbations']
linewidth = [4.0, 4.0]
i=0
N=len(amip)+1
while i<N:
    linewidth.append(1.5)
    i=i+1

N=len(amip_LHS500)+1
j=0
while j<N:
    linewidth.append(1.5)
    j=j+1
#--------------------------- Plot result : future4K --------------------------------------
plt.subplots(figsize=(8,10))

#########################
plt.subplot(311)
title="CRM-CM6-1 PPE amip-future4K / amip : Feedbacks"
ymin = -2.0
ymax = -0.5

n=len(amip)+2
colors = [cmap1(0)]*(n+len(amip_LHS500))
y=[None]*N
y[0] = 'Lambda_official_future4K'
y[1] = 'Lambda_p1_future4K'
y[2:] = ['Lambda_'+i+'_future4k' for i in nb_p_list]
y[(n):] = ['Lambda_'+j+'_future4k' for j in nb_p_list_LHS500]
colors[:n-1] = [cmap1(i) for i in np.linspace(0, 1, len(amip))]
colors[(n):] = [cmap2(j) for j in np.linspace(0, 1, len(amip_LHS500))]

plotlines_1df(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)
plt.ylabel('Feedbacks (W.m^-2 / K)')
plt.xlim(1, 3)
plt.xticks([1, 2, 3])

#########################
plt.subplot(312)
title='CRM-CM6-1 PPE amip-future4K / amip : Delta T'
ymin = 4.2
ymax = 5.8

y[0] = 'Delta_tas_official_future4K'
y[1] = 'Delta_tas_p1_future4K'
y[2:] = ['Delta_tas_'+i+'_future4k' for i in nb_p_list]
y[(n):] = ['Delta_tas_'+j+'_future4k' for j in nb_p_list_LHS500]
colors[:n-1] = [cmap1(i) for i in np.linspace(0, 1, len(amip))]
colors[(n):] = [cmap2(j) for j in np.linspace(0, 1, len(amip_LHS500))]

plotlines_1df(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)
plt.ylabel('Delta T (K)')
plt.xlim(1, 3)
plt.xticks([1, 2, 3])

#########################
plt.subplot(313)
title='CRM-CM6-1 PPE amip-future4K / amip : Delta N'
ymin = -9.0
ymax = -3.0

y[0] = 'Delta_N_official_future4K'
y[1] = 'Delta_N_p1_future4K'
y[2:] = ['Delta_N_'+i+'_future4k' for i in nb_p_list]
y[(n):] = ['Delta_N_'+j+'_future4k' for j in nb_p_list_LHS500]
colors[:n-1] = [cmap1(i) for i in np.linspace(0, 1, len(amip))]
colors[(n):] = [cmap2(j) for j in np.linspace(0, 1, len(amip_LHS500))]

plotlines_1df(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)
plt.ylabel('Delta N (W.m^-2)')
plt.xlim(1, 3)
plt.xticks([1, 2, 3])

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure ...........

plt.savefig("/data/home/globc/peatier/figures/PPE_feedbacks_DT_DN.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Display the figure 
plt.show()

# %%
# PARAMETERS
df = result
cmap1 = plt.get_cmap('ocean')
cmap2 = plt.get_cmap('Reds')
xlabel='years'
xmin = 0
xmax = 2
legend=['official', 'p1', 'Other perturbations']
linewidth = [4.0, 4.0]
i=0
N=len(amip)+1
while i<N:
    linewidth.append(1.5)
    i=i+1

N=len(amip_LHS500)+1
j=0
while j<N:
    linewidth.append(1.5)
    j=j+1
#--------------------------- Plot result : future4K --------------------------------------
plt.subplots(figsize=(8,10))

#########################
plt.subplot(311)
title="CRM-CM6-1 PPE amip-future4K / amip : Feedbacks"
ymin = -2.0
ymax = -0.5

n=len(amip)+2
colors = [cmap1(0)]*(n+len(amip_LHS500))
y=[None]*N
y[0] = 'Lambda_official_future4K'
y[1] = 'Lambda_p1_future4K'
y[2:] = ['Lambda_'+i+'_future4k' for i in nb_p_list]
y[(n):] = ['Lambda_'+j+'_future4k' for j in nb_p_list_LHS500]
colors[:n-1] = [cmap1(i) for i in np.linspace(0, 1, len(amip))]
colors[(n):] = [cmap2(j) for j in np.linspace(0, 1, len(amip_LHS500))]

plotlines_1df(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)
plt.ylabel('Feedbacks (W.m^-2 / K)')
plt.xlim(1, 3)
plt.xticks([1, 2, 3])

#########################
plt.subplot(312)
title='CRM-CM6-1 PPE amip-future4K / amip : Delta T'
ymin = 4.2
ymax = 5.8

y[0] = 'Delta_tas_official_future4K'
y[1] = 'Delta_tas_p1_future4K'
y[2:] = ['Delta_tas_'+i+'_future4k' for i in nb_p_list]
y[(n):] = ['Delta_tas_'+j+'_future4k' for j in nb_p_list_LHS500]
colors[:n-1] = [cmap1(i) for i in np.linspace(0, 1, len(amip))]
colors[(n):] = [cmap2(j) for j in np.linspace(0, 1, len(amip_LHS500))]

plotlines_1df(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)
plt.ylabel('Delta T (K)')
plt.xlim(1, 3)
plt.xticks([1, 2, 3])

#########################
plt.subplot(313)
title='CRM-CM6-1 PPE amip-future4K / amip : Delta N'
ymin = -9.0
ymax = -3.0

y[0] = 'Delta_N_official_future4K'
y[1] = 'Delta_N_p1_future4K'
y[2:] = ['Delta_N_'+i+'_future4k' for i in nb_p_list]
y[(n):] = ['Delta_N_'+j+'_future4k' for j in nb_p_list_LHS500]
colors[:n-1] = [cmap1(i) for i in np.linspace(0, 1, len(amip))]
colors[(n):] = [cmap2(j) for j in np.linspace(0, 1, len(amip_LHS500))]

plotlines_1df(df, y, title, colors, linewidth, xlabel, xmin, xmax, ymin, ymax, legend)
plt.ylabel('Delta N (W.m^-2)')
plt.xlim(1, 3)
plt.xticks([1, 2, 3])

#Ajustement des subplots
plt.tight_layout()
plt.subplots_adjust(hspace = 0.30)

# Enregistrer la figure ...........

plt.savefig("/data/home/globc/peatier/figures/PPEcroped_feedbacks_DT_DN.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Display the figure 
plt.show()

# %%
CMIP6 = np.load(file="CMIP6_NetFeedbcks.npy") 
emulated = np.load(file="emulated_NetFdbck.npy")

# Create plot of PDF of net feedbacks emulated by neural network 

fig, ax = plt.subplots(figsize=(15,10))
ax = sns.distplot(NetFdbck, norm_hist= True, kde = False, 
                  hist_kws={"alpha": 0.8, "color" : 'steelblue'}, label = 'PPE', ax=ax)
ax = sns.distplot(CMIP6, norm_hist=True, kde = False,
                  hist_kws={"alpha": 0.2, "color" : 'darkgreen'}, label= 'CMIP6 7 models', ax=ax)
ax = sns.distplot(emulated, norm_hist=True, kde = False, 
                 hist_kws={"alpha": 0.2, "color" : 'darkred'}, label= 'random forest', ax=ax)
plt.title("PdF of net global feedbacks",
          fontsize=20)
plt.legend(fontsize=18)
plt.xlabel('Globale Net Feedbacks [W.m^-2.K^1]',fontsize=20)
plt.ylabel('Density',fontsize=20)

# Enregistrer la figure ...........

plt.savefig("/data/home/globc/peatier/figures/normed_PDF_feedbacks.png", 
        orientation='portrait', bbox_inches='tight', pad_inches=0.1)

# Display the figure 
plt.show()
